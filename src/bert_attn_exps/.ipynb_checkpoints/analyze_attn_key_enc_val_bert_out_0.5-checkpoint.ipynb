# %%
from transformer.Models import Transformer

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
import time
import yaml
from argparse import ArgumentParser


# from transformer.Models import Transformer, Encoder, Decoder
# from datasets.quora_bert_mask_predict_prob_dataset import QuoraBertMaskPredictProbDataset
from transformer.Optim import ScheduledOptim

# %%
from tqdm import tqdm
import re
import numpy as np
from transformers import BertTokenizer, BertForMaskedLM
import os
import random

class QuoraBertMaskPredictProbDataset(Dataset):
    def __init__(self, mode, train_size=5000, val_size=1000, test_size=1000, 
                 text_path='../data/quora_train.txt', pretrained_model_name='bert-base-cased', preprocessed_folder=None):
        assert mode in ["train", "val", "test"]
        self.mode = mode
        self.train_size = train_size
        self.val_size = val_size
        self.test_size = test_size
        
        self.tokenizer = self.init_tokenizer(pretrained_model_name)
        self.mask_predict_model = BertForMaskedLM.from_pretrained(pretrained_model_name)
        self.sentences = self.read_text(text_path)
        self.init_constants()
        self.softmax = torch.nn.Softmax(dim=1)
        
        self.n_words = len(self.tokenizer)
        
        if preprocessed_folder is not None and os.path.exists(preprocessed_folder):
            self.preprocessed_folder = preprocessed_folder
        else:
            self.preprocessed_folder = None
            self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
            self.mask_predict_model = self.mask_predict_model.to(self.device)

    def __getitem__(self, idx):
        sentence = self.sentences[idx]
        seq1, seq2 = sentence.split('\t')
        
        tokens1 = self.tokenizer.tokenize(seq1)
        word_pieces1 =  [self.SOS_token] + tokens1 + [self.EOS_token]
        idxes1 = self.tokenizer.convert_tokens_to_ids(word_pieces1)
        
        tokens2 = self.tokenizer.tokenize(seq2)
        word_pieces2 = [self.SOS_token] + tokens2 + [self.EOS_token]
        idxes2 = self.tokenizer.convert_tokens_to_ids(word_pieces2)
        
        seq1_tensor = torch.tensor(idxes1, dtype=torch.long)
        seq2_tensor = torch.tensor(idxes2, dtype=torch.long)
        
        if self.preprocessed_folder is not None:
            if self.mode == 'train':
                pretrained_idx = idx
            elif self.mode == 'val':
                pretrained_idx = self.train_size + idx
            else:
                pretrained_idx = self.train_size + self.val_size + idx
            preprocessed_file = "{}/{}.npy".format(self.preprocessed_folder, pretrained_idx)
            mask_probs = np.load(preprocessed_file, allow_pickle=True)
            mask_probs = torch.tensor(mask_probs)
        else:
            # mask each word from the begining to the end
            # get the probability distribution of the mask tokens
            pred = self.get_mask_pred_probs(seq1_tensor)
            mask_probs = self.get_stack_probs(pred)
        
        return seq1_tensor, seq2_tensor, mask_probs

    def __len__(self):
        if self.mode == 'train':
            return self.train_size
        elif self.mode == 'val':
            return self.val_size
        else:
            return self.test_size
        
    # [CLS]  [M]  w2  w3  [SEP]        
    # [CLS]  w1  [M]  w3  [SEP]        
    # [CLS]  w1 w2  [M]  [SEP]        
    # get the probability of [M] for each mask-prediction case
    # mask for (number of words) times and every time get (number of words + 2) probability
    # TODO: get the pred for only once
    def get_mask_pred_probs(self, seq1):
        mask_sentences = []
        
        for i in range(1, len(seq1) - 1):
            mask_seq = seq1.detach().clone()
            mask_seq[i] = self.MASK_token_id
            mask_sentences.append(mask_seq)

        mask_stack = torch.stack(mask_sentences)
        mask_stack = mask_stack.to(self.device)
        
        self.mask_predict_model.eval()

        with torch.no_grad():
            pred = self.mask_predict_model(mask_stack)[0]
        pred = pred.cpu()
        return pred
    
    def get_stack_probs(self, pred):
        bos_prob = torch.zeros(self.n_words)
        bos_prob[self.SOS_token_id] = 1

        eos_prob = torch.zeros(self.n_words)
        eos_prob[self.EOS_token_id] = 1

        mask_preds = []
        for idx in range(pred.shape[0]):
            mask_preds.append(pred[idx][idx+1])
        mask_stack = torch.stack(mask_preds)
        mask_stack = torch.cat((bos_prob.reshape(1,-1), mask_stack, eos_prob.reshape(1,-1)))
        return mask_stack
    
    def init_tokenizer(self, pretrained_model_name):
        tokenizer = BertTokenizer.from_pretrained(pretrained_model_name)
        return tokenizer
    
    def init_constants(self):
        PAD_id,  SOS_id, EOS_id, UNK_id = self.tokenizer.convert_tokens_to_ids(["[PAD]", "[CLS]", "[SEP]", "[UNK]"])
        self.PAD_token_id = PAD_id
        self.SOS_token_id = SOS_id
        self.EOS_token_id = EOS_id
        self.UNK_token_id = UNK_id
        
        self.PAD_token = '[PAD]'
        self.SOS_token = '[CLS]'
        self.EOS_token = '[SEP]'
        self.UNK_token = '[UNK]'
        
        self.MASK_token = '[MASK]'
        self.MASK_token_id = self.tokenizer.convert_tokens_to_ids(["[MASK]"])[0]

        
    def read_text(self, text_path):
        # add words to dictionary
        f = open(text_path, 'r')
        lines = f.readlines()
        # shuffle
        np.random.shuffle(lines)
        if self.mode == "train":
            lines = lines[:self.train_size]
        elif self.mode == 'val':
            lines = lines[self.train_size:self.train_size+self.val_size]
        else:
            lines = lines[self.train_size+self.val_size:self.train_size+self.val_size+self.test_size]
        
        return lines

# %%
seed = 0
# seed = 777
# seed = 33333

# fix seed
def same_seeds(seed):
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)  
    np.random.seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

same_seeds(seed)

# %%
##### Read Arguments from Config File #####

config_path = '../../configs/dpng_transformer_bert_attention.yaml'

with open(config_path) as f:
    config = yaml.load(f, Loader=yaml.FullLoader)
print(config)

# save_model_path = config['save_model_path']
# log_file = config['log_file']
# preprocessed_folder = config['preprocessed_folder']
save_model_path = '../../models/tune/transformer_key_enc_bert_val_attention_alpha0.5.pth'
log_file = '../../logs/tune/transformer_key_enc_bert_val_attention_alpha0.5.txt'
output_file = '../../outputs/tune/transformer_key_enc_bert_val_attention_alpha0.5.txt'

# set model and log path
seed_model_root = '../../models/fixseed/seed{}/'.format(seed)
seed_log_root = '../../logs/fixseed/seed{}/'.format(seed)
seed_output_root = '../../outputs/fixseed/seed{}/'.format(seed)

if not os.path.exists(seed_model_root):
    os.makedirs(seed_model_root)

if not os.path.exists(seed_log_root):
    os.makedirs(seed_log_root)

save_model_path = seed_model_root + save_model_path.split('/')[-1]
log_file = seed_log_root + log_file.split('/')[-1]
output_file = seed_output_root + output_file.split('/')[-1]
print('seed: ', seed)
print('save model path: ', save_model_path)
print('log path: ', log_file)
print('output path: ', output_file)

num_epochs = config['num_epochs']
batch_size = config['batch_size']

d_model = config['d_model']
d_inner_hid = config['d_inner_hid']
d_k = config['d_k']
d_v = config['d_v']

n_head = config['n_head']
n_layers = config['n_layers']
n_warmup_steps = config['n_warmup_steps']

dropout = config['dropout']
embs_share_weight = config['embs_share_weight']
proj_share_weight = config['proj_share_weight']
label_smoothing = config['label_smoothing']

train_size = config['train_size']
val_size = config['val_size']
test_size = config['test_size']


# ###################
# Out:
# {'save_model_path': '../models/transformer_bert_enc_attention.pth', 'log_file': '../logs/transformer_bert_enc_attention.txt', 'test_output_file': '../outputs/test_transformer_bert_enc_attention.txt', 'val_output_file': '../outputs/val_transformer_bert_enc_attention.txt', 'preprocessed_folder': '../data/preprocess_quora_bert_mask_predict/', 'dataset': 'quora_bert_dataset', 'num_epochs': 50, 'batch_size': 100, 'd_model': 450, 'd_inner_hid': 512, 'd_k': 50, 'd_v': 50, 'n_head': 9, 'n_layers': 3, 'n_warmup_steps': 12000, 'dropout': 0.1, 'embs_share_weight': True, 'proj_share_weight': True, 'label_smoothing': False, 'train_size': 100000, 'val_size': 4000, 'test_size': 20000, 'is_bow': False, 'lr': '1e-3'}
# seed:  0
# save model path:  ../../models/fixseed/seed0/transformer_key_enc_bert_val_attention_alpha0.5.pth
# log path:  ../../logs/fixseed/seed0/transformer_key_enc_bert_val_attention_alpha0.5.txt
# output path:  ../../outputs/fixseed/seed0/transformer_key_enc_bert_val_attention_alpha0.5.txt

# %%
# bert_alpha = 0 # normal
bert_alpha = 0.5 # half-half
# bert_alpha = 1 # only bert attention

# %%
def create_mini_batch(samples):
    seq1_tensors = [s[0] for s in samples]
    seq2_tensors = [s[1] for s in samples]
    probs_tensors = [s[2] for s in samples]

    # zero pad
    seq1_tensors = pad_sequence(seq1_tensors,
                                  batch_first=True)

    seq2_tensors = pad_sequence(seq2_tensors,
                                  batch_first=True)
    probs_tensors = pad_sequence(probs_tensors,
                                  batch_first=True)
    
    return seq1_tensors, seq2_tensors, probs_tensors

dataset = QuoraBertMaskPredictProbDataset("train", train_size, val_size, text_path='../../data/quora_train.txt')
val_dataset = QuoraBertMaskPredictProbDataset("val", train_size, val_size, text_path='../../data/quora_train.txt')

data_loader = DataLoader(dataset, batch_size=batch_size, collate_fn=create_mini_batch, shuffle=True)
val_data_loader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=create_mini_batch, shuffle=False)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F

from transformer.SubLayers import MultiHeadAttention, PositionwiseFeedForward
from transformer.Models import get_pad_mask, get_subsequent_mask
from transformer.Models import PositionalEncoding, Encoder

# QKV: dec_out  enc_out  bert_out
class DecoderLayer(nn.Module):
    ''' Compose with three layers '''

    def __init__(self, d_model, d_inner, n_head, d_k, d_v, dropout=0.1, bert_alpha=0):
        super(DecoderLayer, self).__init__()
        self.slf_attn = MultiHeadAttention(n_head, d_model, d_k, d_v, dropout=dropout)
        self.enc_attn = MultiHeadAttention(n_head, d_model, d_k, d_v, dropout=dropout)
        self.bert_attn = MultiHeadAttention(n_head, d_model, d_k, d_v, dropout=dropout)
        self.pos_ffn = PositionwiseFeedForward(d_model, d_inner, dropout=dropout)
        self.bert_alpha = bert_alpha

    def forward(
            self, dec_input, enc_output, bert_out,
            slf_attn_mask=None, dec_enc_attn_mask=None):
        
        dec_output, dec_slf_attn = self.slf_attn(
            dec_input, dec_input, dec_input, mask=slf_attn_mask)
        
        dec_output, dec_enc_attn = self.enc_attn(
            dec_output, enc_output, enc_output, mask=dec_enc_attn_mask)
        
        dec_bert_output, dec_enc_bert_attn = self.bert_attn(
            dec_output, enc_output, bert_out, mask=dec_enc_attn_mask)
        
        dec_output = (1-self.bert_alpha) *  dec_output + self.bert_alpha * dec_bert_output
        
        dec_output = self.pos_ffn(dec_output)
        return dec_output, dec_slf_attn, dec_enc_attn

# %%
class Decoder(nn.Module):
    ''' A decoder model with self attention mechanism. '''

    def __init__(
            self, n_trg_vocab, d_word_vec, n_layers, n_head, d_k, d_v,
            d_model, d_inner, pad_idx, n_position=200, dropout=0.1, bert_alpha=0):

        super().__init__()

        self.trg_word_emb = nn.Embedding(n_trg_vocab, d_word_vec, padding_idx=pad_idx)
        self.position_enc = PositionalEncoding(d_word_vec, n_position=n_position)
        self.dropout = nn.Dropout(p=dropout)
        self.layer_stack = nn.ModuleList([
            DecoderLayer(d_model, d_inner, n_head, d_k, d_v, dropout=dropout, bert_alpha=bert_alpha)
            for _ in range(n_layers)])
        self.layer_norm = nn.LayerNorm(d_model, eps=1e-6)

    def forward(self, trg_seq, trg_mask, enc_output, bert_out, src_mask, return_attns=False):

        dec_slf_attn_list, dec_enc_attn_list = [], []

        # -- Forward
        dec_output = self.dropout(self.position_enc(self.trg_word_emb(trg_seq)))
        dec_output = self.layer_norm(dec_output)
        
#         print('encoder output', enc_output.shape)
#         print('decoder output', dec_output.shape)
#         print('bert output', bert_out.shape)

        for dec_layer in self.layer_stack:
            dec_output, dec_slf_attn, dec_enc_attn = dec_layer(
                dec_output, enc_output, bert_out, slf_attn_mask=trg_mask, dec_enc_attn_mask=src_mask)
            dec_slf_attn_list += [dec_slf_attn] if return_attns else []
            dec_enc_attn_list += [dec_enc_attn] if return_attns else []

        if return_attns:
            return dec_output, dec_slf_attn_list, dec_enc_attn_list
        return dec_output,

# %%
class Transformer(nn.Module):
    ''' A sequence to sequence model with attention mechanism. '''

    def __init__(
            self, n_src_vocab, n_trg_vocab, src_pad_idx, trg_pad_idx,
            d_word_vec=512, d_model=512, d_inner=2048,
            n_layers=6, n_head=8, d_k=64, d_v=64, dropout=0.1, n_position=200,
            trg_emb_prj_weight_sharing=True, emb_src_trg_weight_sharing=True, bert_alpha=0):

        super().__init__()

        self.src_pad_idx, self.trg_pad_idx = src_pad_idx, trg_pad_idx
        
        self.probnn = nn.Linear(n_src_vocab, d_model)

        self.encoder = Encoder(
            n_src_vocab=n_src_vocab, n_position=n_position,
            d_word_vec=d_word_vec, d_model=d_model, d_inner=d_inner,
            n_layers=n_layers, n_head=n_head, d_k=d_k, d_v=d_v,
            pad_idx=src_pad_idx, dropout=dropout)

        self.decoder = Decoder(
            n_trg_vocab=n_trg_vocab, n_position=n_position,
            d_word_vec=d_word_vec, d_model=d_model, d_inner=d_inner,
            n_layers=n_layers, n_head=n_head, d_k=d_k, d_v=d_v,
            pad_idx=trg_pad_idx, dropout=dropout, bert_alpha=bert_alpha)

        self.trg_word_prj = nn.Linear(d_model, n_trg_vocab, bias=False)

        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p) 

        assert d_model == d_word_vec, \
        'To facilitate the residual connections, \
         the dimensions of all module outputs shall be the same.'

        self.x_logit_scale = 1.
        if trg_emb_prj_weight_sharing:
            # Share the weight between target word embedding & last dense layer
            self.trg_word_prj.weight = self.decoder.trg_word_emb.weight
            self.x_logit_scale = (d_model ** -0.5)

        if emb_src_trg_weight_sharing:
            self.encoder.src_word_emb.weight = self.decoder.trg_word_emb.weight


    def forward(self, src_seq, trg_seq, bert_prob, return_attns=False):
        src_mask = get_pad_mask(src_seq, self.src_pad_idx)
        trg_mask = get_pad_mask(trg_seq, self.trg_pad_idx) & get_subsequent_mask(trg_seq)

        enc_output, enc_slf_attn_list = self.encoder(src_seq, src_mask, return_attns=True)
        
        bert_out = self.probnn(bert_prob)
#         print("bert prod:", bert_prob.shape)
#         print("(trans) bert out: ", bert_out.shape)
        
        dec_output, dec_slf_attn_list, dec_enc_attn_list = self.decoder(trg_seq, trg_mask, enc_output, bert_out, src_mask, return_attns=True)
        seq_logit = self.trg_word_prj(dec_output) * self.x_logit_scale

        if return_attns:
            return seq_logit.view(-1, seq_logit.size(2)), enc_slf_attn_list, dec_slf_attn_list, dec_enc_attn_list
        return seq_logit.view(-1, seq_logit.size(2))

# %%
transformer = Transformer(
    dataset.n_words,
    dataset.n_words,
    src_pad_idx=dataset.PAD_token_id,
    trg_pad_idx=dataset.PAD_token_id,
    trg_emb_prj_weight_sharing=proj_share_weight,
    emb_src_trg_weight_sharing=embs_share_weight,
    d_k=d_k,
    d_v=d_v,
    d_model=d_model,
    d_word_vec=d_model,
    d_inner=d_inner_hid,
    n_layers=n_layers,
    n_head=n_head,
    dropout=dropout,
    bert_alpha=bert_alpha
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = transformer.to(device)

# %%
from transformer.CustomModels import Translator

# %%
import re
import numpy as np

class QuoraTextDataset(Dataset):
    def __init__(self, mode, train_size=5000, val_size=1000, test_size=1000, text_path='../data/quora_train.txt'):
        assert mode in ["train", "val", "test"]
        self.mode = mode
        self.train_size = train_size
        self.val_size = val_size
        self.test_size = test_size
        self.sentences = []

        self._init_sentences(text_path)

    def __getitem__(self, idx):
        return self.sentences[idx]
        seq1, seq2 = self.sentences[idx]

    def __len__(self):
        if self.mode == 'train':
            return self.train_size
        elif self.mode == 'val':
            return self.val_size
        else:
            return self.test_size
    
    def _init_sentences(self, text_path):
        f = open(text_path, 'r')
        lines = f.readlines()
        np.random.shuffle(lines)
        if self.mode == "train":
            lines = lines[:self.train_size]
        elif self.mode == 'val':
            lines = lines[self.train_size:self.train_size+self.val_size]
        else:
            lines = lines[self.train_size+self.val_size:self.train_size+self.val_size+self.test_size]
        
        def normalize_sentence(s):
            s = re.sub(r"([.!?])", r" \1", s)
            s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
            return s

        for line in lines:
            seq1, seq2 = [normalize_sentence(seq) for seq in line.split('\t')]
            self.sentences.append((seq1, seq2))

# %%
tbatch_size = 1
beam_size = 3
max_seq_len = 30

same_seeds(seed)

# dataset = QuoraBertMaskPredictProbDataset("test", train_size, val_size, test_size, preprocessed_folder=preprocessed_folder)
test_dataset = QuoraBertMaskPredictProbDataset("test", train_size, val_size, test_size, text_path='../../data/quora_train.txt')

same_seeds(seed) 
text_dataset = QuoraTextDataset("test", train_size, val_size, test_size, text_path='../../data/quora_train.txt')
test_data_loader = DataLoader(test_dataset, batch_size=tbatch_size, collate_fn=create_mini_batch, shuffle=False)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model.load_state_dict((torch.load(
        save_model_path, map_location=device)))
# Out:
# <All keys matched successfully>

# %%
src_pad_idx = dataset.PAD_token_id
trg_pad_idx = dataset.PAD_token_id
    
trg_bos_idx = dataset.SOS_token_id
trg_eos_idx = dataset.EOS_token_id
unk_idx = dataset.UNK_token_id

# %%
translator = Translator(
        model=model,
        beam_size=beam_size,
        max_seq_len=max_seq_len,
        src_pad_idx=src_pad_idx,
        trg_pad_idx=trg_pad_idx,
        trg_bos_idx=trg_bos_idx,
        trg_eos_idx=trg_eos_idx,
).to(device)

# %%
# dry-run
it = iter(test_data_loader)
i = 1
for _ in range(i):
    next(it)

seq1, seq2, bert_prob = next(it)
input_seq = seq1.to(device)
bert_prob = bert_prob.to(device)
pred_seq = translator.translate_sentence(input_seq, bert_prob)
print(dataset.tokenizer.convert_ids_to_tokens(pred_seq))
# Out:
# ['[CLS]', 'How', 'can', 'I', 'learn', 'faster', '?', '[SEP]']

# %%
print(test_dataset.sentences[i])
_, _, mp = test_dataset[i]
soft = torch.nn.Softmax(dim=1)
mp = soft(mp)
print(mp.shape)
prob, indices = torch.topk(mp[4], 40)
print(prob)
dataset.tokenizer.convert_ids_to_tokens(list(indices.numpy()))
# Out:
# How can I speak faster?	How can you speak faster?
#
# torch.Size([8, 28996])
# tensor([0.2046, 0.1890, 0.1698, 0.1139, 0.1039, 0.0461, 0.0262, 0.0234, 0.0220,
#         0.0063, 0.0040, 0.0038, 0.0037, 0.0031, 0.0030, 0.0024, 0.0024, 0.0023,
#         0.0015, 0.0015, 0.0014, 0.0014, 0.0014, 0.0013, 0.0013, 0.0013, 0.0013,
#         0.0012, 0.0012, 0.0012, 0.0012, 0.0011, 0.0011, 0.0011, 0.0011, 0.0011,
#         0.0009, 0.0009, 0.0009, 0.0009])
# ['go',
#  'move',
#  'run',
#  'walk',
#  'be',
#  'get',
#  'travel',
#  'think',
#  'drive',
#  'breathe',
#  'swim',
#  'see',
#  'fly',
#  'heal',
#  'talk',
#  'turn',
#  'work',
#  'come',
#  'sprint',
#  'ride',
#  'live',
#  'race',
#  'do',
#  'fight',
#  'escape',
#  'fall',
#  'beat',
#  'know',
#  'jump',
#  'dance',
#  'speed',
#  'learn',
#  'step',
#  'die',
#  'function',
#  'speak',
#  'change',
#  'pass',
#  'shift',
#  'read']

# %%
print(sum(bert_prob[0][1]))
print(sum(bert_prob[0][4]))
# Out:
# tensor(-86045.5859, device='cuda:0')
# tensor(-84083.0859, device='cuda:0')

# %%
# diter = iter(test_data_loader)
# _ = next(diter)
# _ = next(diter)
# seq1_tensor, seq2_tensor, mask_prob = next(diter)
# print(seq1_tensor.shape)
# print(dataset.tokenizer.convert_ids_to_tokens(seq1_tensor[0]))
# Out:
# torch.Size([1, 14])
# ['[CLS]', 'What', 'is', 'the', 'best', 'laptop', 'under', 'IN', '##R', '30', ',', '000', '?', '[SEP]']

# %%
dataset.tokenizer.convert_tokens_to_ids(['novels', 'books', 'book', 'comic', 'story'])

# %%
# build mask stack
bos_prob = torch.zeros(dataset.n_words)
bos_prob[dataset.SOS_token_id] = 1

eos_prob = torch.zeros(dataset.n_words)
eos_prob[dataset.EOS_token_id] = 1

mask_preds = []
for i, idx in enumerate(seq1_tensor[0,:]):
    prob = torch.zeros(dataset.n_words)
    prob[idx] = 1
    
    if idx == 5520:
        prob[idx] = 0
        prob[2146] = 0
        prob[1520] = 0
        prob[4824] = 0
        prob[1642] = 0
    mask_preds.append(prob)
#     print(idx, prob[idx], len(mask_preds))
mask_stack = torch.stack(mask_preds)
print(mask_stack.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-7407859f055c> in <module>
#       7
#       8 mask_preds = []
# ----> 9 for i, idx in enumerate(seq1_tensor[0,:]):
#      10     prob = torch.zeros(dataset.n_words)
#      11     prob[idx] = 1
#
# NameError: name 'seq1_tensor' is not defined

# %%
mask_stack = mask_stack.reshape(1, len(seq1_tensor[0]), -1)
print(mask_stack.shape)

# %%
# dry-run
diter = iter(test_data_loader)
_ = next(diter)
_ = next(diter)
seq1, seq2, bert_prob = next(diter)
input_seq = seq1.to(device)
bert_prob = bert_prob.to(device)
pred_seq = translator.translate_sentence(input_seq, bert_prob)
print(dataset.tokenizer.convert_ids_to_tokens(pred_seq))

# %%
# analyze model probnn

# %%
weight = model.probnn.weight
weight[0].shape
# Out:
# torch.Size([28996])

# %%
word = 'value'
word2 = 'prefer'
for i in range(450):
    w = weight[i].cpu().detach()
    prob, indices = torch.topk(w, 30)
    tokens = dataset.tokenizer.convert_ids_to_tokens(list(indices.numpy()))
#     print("-----------------------------")
#     print(tokens)
    if word in tokens:
        print("-----------------------------")
        if word2 in tokens:
            print("[Info] Find word2 here!")
        print(tokens)
# Out:
# -----------------------------
# ['myself', 'itself', 'm', 'ca', 'anymore', 'j', 'x', 'u', 'am', 'b', 'herself', 'either', 'sir', 'yes', 'saw', 'somewhere', 'X', 'connected', 'c', 'co', 'ha', 'nearby', 'everywhere', 'sub', 'himself', 'term', 'ka', 'London', 'hybrid', 'Mu']
# -----------------------------
# ['Chinese', 'Indian', 'summer', 'Western', 'western', 'winter', 'French', 'especially', 'whole', 'contemporary', 'during', 'style', 'British', 'Japanese', 'Central', 'Southern', 'international', 'culture', 'early', 'Christmas', 'cold', 'southern', 'eating', 'Asian', 'throughout', 'Eastern', 'young', 'political', 'division', 'particular']
# -----------------------------
# ['simply', 'job', '$', 'campaign', '#', 'ad', 'suddenly', 'quick', 'quickly', 'idea', 'figure', 'address', 'busy', 'dear', 'Just', 'says', 'supposed', 'besides', 'finally', 'starting', 'f', 'sudden', 'mad', 'begin', 'going', 'possibly', 'further', 'usual', 'god', 'creative']
# -----------------------------
# ['production', 'yours', 'anyway', 'sound', 'required', 'safe', 'property', 'city', 'anymore', 'movement', 'City', 'whose', 'protection', 'company', 'whatever', 'building', 'available', 'higher', 'anywhere', 'construction', 'design', 'difference', 'large', 'interest', 'purchase', 'favorite', 'collection', 'area', 'ones', 'unknown']
# -----------------------------
# ['former', 'X', 'let', '##o', 'chosen', 'nearly', 'body', 'military', 'white', 'chose', 'usually', '##a', 'army', 'Army', 'v', 'large', 'plant', 'watching', 'late', 'u', 'U', 'fire', '##e', 'tube', 'eventually', 'baby', 'front', 'shoot', 'therefore', 'actual']
# -----------------------------
# ['few', 'usually', 'least', 'ones', 'former', 'individual', 'whose', 'several', 'typically', 'various', 'side', 'average', 'rest', 'most', 'normally', 'remaining', 'female', 'required', 'behind', 'brain', 'often', 'male', 'single', 'currently', 'non', 'Most', 'top', 'couple', 'hundred', 'private']
# -----------------------------
# ['China', 'earlier', 'red', 'gold', 'whatever', 'eventually', 'album', 'yellow', 'white', 'recently', 'sudden', 'finally', 'press', 'Christmas', 'numbers', 'price', 'song', 'whose', 'This', 'yesterday', 'overall', 'blue', 'therefore', 'interest', 'thus', 'draft', 'color', 'paper', 'till', 'Chinese']
# -----------------------------
# ['itself', 'himself', 'instead', 'herself', 'someone', 'directly', 'twice', 'same', 'close', 'something', 'forever', 'rather', 'anything', 'simply', 'material', 'thus', 'anyway', 'otherwise', 'easily', 'away', 'University', 'another', 'England', 'Germany', 'anymore', 'territory', 'gone', 'Charlie', 'accidentally', 'went']
# -----------------------------
# ['quick', 'usual', 'im', 'proper', 'counter', 'common', 'UK', 'daily', 'traditional', 'together', 'twenty', 'master', 'combined', 'Army', 'England', 'joined', 'stage', 'video', 'anal', 'IT', 'direct', 'Navy', 'co', 'begin', 'wing', 'air', 'above', 'United', 'un', 'er']
# -----------------------------
# ['anyway', 'however', 'tomorrow', 'brain', 'required', 'less', 'extra', 'basic', 'fly', 'mass', 'faster', 'anymore', 'noise', 'equivalent', 'minimum', 'sleep', 'nearby', 'sir', 'population', 'practice', 'light', 'fun', 'winter', 'system', 'necessary', 'few', '0', 'simple', 'higher', 'proper']
# -----------------------------
# ['anymore', 'anyway', 'individual', 'vampire', 'etc', 'ones', 'few', 'others', 'hospital', 'due', 'forever', 'count', 'among', 'list', 'Hollywood', 'material', 'alone', 'mine', 'mobile', 'yet', 'yesterday', 'disease', 'society', 'longer', 'affected', 'flat', 'own', 'elsewhere', 'tonight', 'telling']
# -----------------------------
# ['double', 'via', 'final', 'during', 'consider', 'starting', 'taking', 'every', 'until', 'against', 'stop', 'getting', 'without', '=', 'considering', 'early', 'except', 'took', '_', 'whether', 'favor', 'healthy', 'equal', 'avoid', 'triple', 'couples', 'several', 'came', 'try', 'course']
# -----------------------------
# ['law', 'due', 'al', 'arms', 'rest', 'behind', 'military', 'supposed', 'secret', 'ad', 'army', 'except', 'Earth', 'Law', 'hell', 'let', 'labor', 'ground', 'race', 'reason', 'present', 'lay', 'waste', 'few', 'forces', 'draft', 'working', 'intelligence', 'host', '##T']
# -----------------------------
# ['full', 'least', 'they', 'evidence', 'may', '_', 'version', 'actual', 'god', 'They', 'speed', 'safety', 'digital', 'nearly', 'bloody', 'every', 'western', 'wide', 'Western', 'dust', 'police', 'since', 'never', 'almost', 'until', 'must', 'hardly', 'merely', 'religious', 'demon']
# -----------------------------
# ['u', 'middle', 'okay', 'either', 'neither', 'reality', 'X', 'instead', 'U', 'full', 'count', 'higher', 'exist', 'matter', 'possibility', 'free', 'forever', 'backward', 'hope', 'twice', 'One', 'o', 'dream', 'another', 'nuclear', 'OK', 'born', 'somewhere', 'times', 'study']
# -----------------------------
# ['anyway', 'asked', 'asking', 'away', 'yesterday', 'anymore', 'ask', 'due', 'yours', 'million', 'ones', 'immediately', 'rest', 'surprise', 'protection', 'tonight', 'earlier', 'ahead', 'daily', 'material', 'along', 'coming', 'care', 'reported', 'waiting', 'directly', 'side', 'regardless', 'whatever', 'recently']
# -----------------------------
# ['anymore', 'itself', 'anyway', 'nowadays', 'saying', 'regular', 'wait', 'herself', 'nearby', 'instead', 'tonight', 'unless', 'requires', 'yes', 'asked', 'station', 'uniform', 'crap', 'using', 'waste', 'confused', 'don', 'thin', 'bound', 'otherwise', 'special', 'used', 'waiting', 'close', 'why']
# -----------------------------
# ['pre', 'won', 'grand', 'un', 'heart', 'history', 'sure', 'worth', 'mi', 'Da', 'making', 'having', 'taken', 'Hell', 'wish', 'piece', 'size', 'video', 'condition', 'A', 'success', 'Pi', 'promise', 'da', 'rich', 'winning', 'played', 'memory', 'Miss', 'taking']
# -----------------------------
# ['anyone', 'until', 'Mr', 'himself', 'anything', 'anybody', 'sure', 'Miss', 'President', 'alone', 'attempt', 'anyway', 'twice', 'tonight', 'flight', 'impact', 'president', 'company', 'knowing', 'since', 'however', 'helping', 'watching', 'Master', 'anywhere', 'GM', 'ever', 'during', 'afterwards', 'manager']
# -----------------------------
# ['female', 'male', 'positive', 'mine', 'ex', 'account', 'false', 'text', 'self', 'fake', 'voice', 'negative', 'Dr', 'behind', 'address', 'cause', 'social', 'friends', 'check', 'anymore', 'My', 'Mom', 'message', 'firm', 'lying', 'acting', 'relationship', 'front', 'father', 'blind']
# -----------------------------
# ['anyway', 'area', 'production', 'however', 'capital', 'm', 'others', 'feeling', 'living', 'myself', 'region', 'otherwise', 'absolutely', 'fix', 'city', 'yourself', 'million', 'p', 'tonight', 'apartment', 'purchase', 'Caroline', 'Christmas', 'growing', 'Nick', 'content', 'nearly', 'Internet', 'across', 'underneath']
# -----------------------------
# ['anymore', 'anyway', 'food', 'humans', 'itself', 'considered', 'between', 'indeed', 'vampire', 'same', 'material', 'military', 'separate', 'Christian', 'alone', 'yes', 'fish', 'natural', 'equal', 'eat', 'trade', 'choose', 'truth', 'fly', 'nuclear', 'transport', 'exact', 'except', 'vampires', 'allowed']
# -----------------------------
# ['equal', 'itself', 'safe', 'due', 'square', 'idea', 'cross', 'entirely', 'par', 'simply', 'In', 'close', 'access', 'worse', 'okay', 'coming', 'middle', 'bound', 'proper', 'across', 'fair', 'European', 'U', 'fit', 'indeed', '+', 'r', 'alternative', 'comes', 'u']
# -----------------------------
# ['itself', 'steam', 'otherwise', 'himself', 'similar', 'him', 'differently', 'fast', 'themselves', 'closer', 'directly', 'separate', 'twice', 'its', 'different', 'apart', 'quickly', 'faster', 'several', 'ship', 'turned', 'earlier', 'starting', 'rank', 'own', 'Go', 'Re', 'Nick', 'herself', 'using']
# -----------------------------
# ['~', 'nearly', 'ones', 'super', 'average', '*', 'apparently', 'My', 'having', 'memory', 'cell', 'per', 'capacity', 'times', 'adult', 'tone', 'Y', 'maximum', 'record', 'middle', 'feature', 'likely', 'age', 'female', 'flat', 'lower', 'display', 'list', 'cause', 'screen']
# -----------------------------
# ['#', '[UNK]', 'known', '|', 'ever', 'video', 'least', 'hit', 'hair', 'daily', 'seen', 'possible', 'attack', 'Ever', 'anything', 'Doc', 'lately', 'exactly', 'deal', 'fight', '%', 'company', 'happened', 'spell', '[', 'murder', 'worse', '!', '##ha', 'killed']
# -----------------------------
# ['anymore', 'Christian', 'anyway', 'between', 'serious', 'business', 'online', 'trouble', 'herself', 'tonight', 'separate', 'London', 'social', 'related', 'together', 'somewhere', 'while', 'trade', 'mentioned', 'normal', 'deep', 'elsewhere', 'ask', 'teaching', 'married', 'whether', 'con', 'bound', 'outside', 'except']
# -----------------------------
# ['spread', 'whole', 'flat', 'plus', 'clean', 'non', 'few', 'entire', 'several', 'winter', 'Asian', 'return', 'average', 'summer', 'backward', 'leaving', 'rest', 'mid', 'Sunday', 'eventually', 'Asia', 'grow', 'fine', 'spent', 'times', 'busy', 'warm', 'Euro', 'traffic', 'came']
# -----------------------------
# ['self', 'forward', 'own', 'others', 'public', 'purpose', 'straight', 'online', 'personal', 'proper', 'anyone', 'birth', 'hands', 'himself', 'words', 'intended', 'front', 'original', 'wrong', 'yourself', 'ready', 'live', 'necessary', 'father', 'started', 'career', 'wanted', 'physical', 'blind', 'correct']
# -----------------------------
# ['whatever', 'however', 'exactly', 'instead', 'finally', 'indeed', 'saying', 'history', 'named', 'came', 'supposed', 'specifically', 'tell', 'eventually', 'version', 'knew', 'asked', 'precisely', 'anyway', 'surprise', 'Daniel', 'told', 'might', 'George', 'earlier', 'until', 'telling', 'yesterday', 'What', '[']
# -----------------------------
# ['speed', 'fast', 'fair', 'anyone', 'physical', 'except', 'natural', 'directly', 'fuel', 'via', 'hell', 'changes', 'program', 'remote', 'means', 'testing', 'measures', 'drive', 'nor', 'Marshall', 'necessary', 'blind', 'steps', 'helping', 'excuse', 'push', 'someone', 'w', 'shrink', 'quick']
# -----------------------------
# ['herself', 'himself', 'anymore', 'anyway', 'myself', 'yourself', 'otherwise', 'itself', 'mine', 'yours', 'health', 'trying', 'worth', 'career', 'campaign', 'IV', 'check', 'prime', 'online', '2012', 'public', 'neck', 'III', 'minor', 'professional', 'shot', 'alone', '2013', 'anyone', 'properly']
# -----------------------------
# ['becoming', 'worth', 'myself', 'self', 'been', 'became', 'become', 'yourself', 'past', 'routine', 'totally', 'being', 'taken', 'career', 'feeling', 'deep', 'becomes', 'currently', 'ex', 'normally', 'sitting', 'master', 'taking', 'entirely', 'getting', 'such', 'during', 'beyond', 'fellow', 'typical']
# -----------------------------
# ['truly', 'possibly', 'never', 'nearly', 'self', 'simply', 'been', 'Just', 'gets', 'finally', 'always', 'voice', 'probably', 'totally', 'seemingly', 'became', 'others', 'quite', 'except', 'usually', 'getting', 'least', 'merely', 'came', 'almost', 'll', 'definitely', 'nearest', 'fucking', 'gift']
# -----------------------------
# ['push', 'never', 'firm', 'i', 'Re', 'super', 'strong', 'non', 'desire', 'actual', 'contract', 'worth', 'fully', 're', 'paid', 'marriage', 'skill', 'simply', 'born', 'real', 'strictly', 'merely', 'they', '##gu', 'Power', 've', 'gun', 'broad', 'Canadian', 'gift']
# -----------------------------
# ['supposed', 'fast', 'wrong', 'material', 'proper', 'am', 'believed', 'saying', 'plot', 'magic', 'done', 're', 'happened', 'anymore', 'yesterday', 'evidence', 'truth', 'hundred', 'planned', 'idea', 'suppose', 'believe', 'purpose', 'going', 'Pa', 'present', 'plan', 'exist', 'hiding', 'secret']
# -----------------------------
# ['voice', 'forward', 'behind', 'forth', 'himself', 'bit', 'net', 'Mr', 'online', 'helping', 'herself', 'provided', 'cause', 'Dr', '#', 'career', 'space', 'beat', 'poor', 'down', 'open', 'anti', 'Africa', 'elsewhere', 'meaning', 'powers', 'ground', '##ow', 'role', 'free']
# -----------------------------
# ['version', 'simply', 'instead', 'forces', 'freaking', 'nearly', 'middle', 'rather', 'endless', 'written', 'points', 'coin', 'almost', 'split', 'battle', 'stuck', 'album', 'entire', 'rock', 'island', 'silver', 'spread', 'engine', '+', 'third', 'whole', 'finally', 'species', 'rule', 'monster']
# -----------------------------
# ['instead', 'anyway', 'anymore', 'otherwise', 'mass', 'rather', 'himself', '##able', 'higher', 'itself', 'yourself', 'forever', 'pack', 'herself', 'hell', 'altogether', 'somewhere', 'us', 'alternative', 'such', 'twenty', 'whatever', 'sport', 'fun', 'terms', 'close', 'prime', 'another', 'worse', 'themselves']
# -----------------------------
# ['former', 'rest', 'super', 'several', 'same', 'race', 'non', 'others', 'four', 'host', 'every', 'future', 'species', 'six', 'themselves', 'con', 'each', 'They', 'five', 'row', 'few', 'double', 'ad', 'hold', 'pair', 'ones', 'side', 'they', 'fellow', 'majority']
# -----------------------------
# ['news', 'non', 'i', 'happy', 'sales', 'Boston', 'speaking', 'micro', 'social', 'trade', 'middle', 'business', 'sweet', 'foreign', 'matters', 'u', 'growing', 'treatment', 'Mr', 'brand', 'lifestyle', 'especially', 'spread', 'policy', 'talk', 'club', 'street', 'super', 'particularly', 'v']
# -----------------------------
# ['based', 'available', 'style', 'online', '#', 'technology', 'learning', 'related', 'field', 'learned', 'written', 'agent', 'contact', 'option', 'used', 'media', 'mentioned', 'traditional', 'mixed', 'offered', 'text', 'series', 'term', 'developed', 'featured', 'foreign', 'novel', 'popular', 'especially', 'Western']
# -----------------------------
# ['self', 'nearly', 'literally', 'straight', '+', 'fair', 'forever', 'quickly', 'event', 'physical', 'stage', 'slowly', 'giving', 'himself', 'fast', 'personal', 'campaign', 'thus', 'marriage', 'close', 'de', 'successfully', 'o', 'machine', 'happy', 'effectively', 'triple', 'grand', '[UNK]', 'wa']
# -----------------------------
# ['super', 'similar', 'Bill', 'worth', 'security', 'Z', 'reality', 'Joe', 'definitely', 'they', 'machine', 'knowing', 'likely', 'gas', 'every', 'law', 'these', 'per', 'difference', 'micro', 'insurance', 'sure', 'Were', 'we', 'Chris', 'having', 'ho', 'trade', 'bill', 'joint']
# -----------------------------
# ['#', '|', 'playing', 'named', 'mixed', 'acting', 'running', 'especially', 'based', 'mix', 'gone', 'considered', 'included', 'whether', 'junior', 'far', 'speaking', 'director', 'been', 'award', 'rated', 'contrast', 'mentioned', 'hot', 'mixing', 'cross', 'cost', 'taken', 'western', 'division']
# -----------------------------
# ['instead', 'anyway', 'anymore', 'earlier', 'yesterday', 'tonight', 'II', 'today', 'mix', 'ch', 'white', 'c', 'history', 'respectively', 'ex', 'pre', 'originally', 'however', 'non', 'background', '##ry', 'domestic', 'wonder', 'syndrome', 'w', 'away', 'III', 'blue', 'electric', 'initially']
# -----------------------------
# ['average', 'per', 'otherwise', 'each', 'kind', 'variety', 'produce', 'type', 'television', 'series', 'large', 'almost', 'Japanese', 'interest', 'numbers', 'medium', 'feature', 'ordinary', 'usually', 'whatever', 'flat', 'action', 'Martian', 'rich', 'pop', 'multiple', 'mobile', 'complex', 'number', 'could']
# -----------------------------
# ['running', 'using', 'police', 'false', '#', 'title', 'missing', 'text', 'na', 'DNA', 'open', 'fake', 'Master', 'behind', 'trust', 'uses', 'ran', 'lack', 'gold', 'Google', 'heart', 'al', 'various', 'named', 'brand', 'used', 'issues', 'murder', 'internal', 'metal']
# -----------------------------
# ['says', 'Indian', 'code', 'gold', 'oh', 'uses', 'exact', 'size', 'per', 'dear', 'twenty', 'poor', 'Magic', 'heart', '##h', 'Mark', 'eh', 'needs', 'Black', 'match', 'words', 'precious', 'matching', 'black', 'Smith', 'added', 'himself', 'version', 'simple', 'sa']
# -----------------------------
# ['freaking', 'fucking', 'faction', 'super', 'usually', 'certainly', 'inner', 'between', 'oh', 'clan', 'definitely', 'senior', '*', 'remaining', 'bloody', 'relationship', 'loved', 'god', 'former', 'generally', 'loves', 'wish', 'couple', 'absolutely', 'entire', 'hundred', 'parent', 'may', 'relationships', 'gang']
# -----------------------------
# ['attack', 'eventually', 'rule', 'himself', 'completely', 'act', 'instead', 'feeling', 'forever', 'fight', 'living', 'escape', 'somehow', 'process', 'faster', 'otherwise', 'burst', 'fighting', 'measure', 'cause', 'mass', 'period', 'discovered', 'race', 'count', 'shot', 'disease', 'release', 'anymore', 'future']
# -----------------------------
# ['involved', 'fast', 'specifically', 'equivalent', 'ready', 'directly', 'style', 'custom', 'went', 'included', '##an', 'fun', 'nice', 'going', 'range', 'round', '##k', 'heart', 'alive', 'micro', 'used', 'anyway', 'goes', 'pro', 'safe', 'compared', 'close', 'rich', 'traditional', 'gone']
# -----------------------------
# ['directly', 'same', 'earlier', 'similar', 'random', 'whose', 'video', 'interest', 'DNA', 'lives', 'accident', 'close', 'row', 'separate', 'plot', 'inter', 'itself', '2009', '2012', '2008', 'fate', 'suicide', 'marriage', 'management', 'closely', '##up', 'This', '2013', 'remote', 'various']
# -----------------------------
# ['non', 'machine', 'per', 'eventually', 'instead', 'prime', 'board', 'simple', 'glass', 'auto', 'another', 'white', 'ex', 'late', 'themselves', 'firm', 'John', 'micro', 'race', 'van', 'return', 'pro', 'former', 'sin', '##less', 'future', 'suicide', 'Mac', 'para', 'stone']
# -----------------------------
# ['whatever', 'nothing', 'let', 'saying', 'suddenly', 'action', 'something', 'seen', 'wrong', 'anything', 'someone', 'shot', 'quick', 'done', 'once', 'One', 'words', 'knowing', 'anymore', 'acting', 'sudden', 'painting', 'everything', 'longer', 'Lo', 'simply', 'demand', 'unless', 'bit', 'success']
# -----------------------------
# ['#', 'central', 'south', 'god', 'found', 'speed', 'word', 'mention', 'Prince', 'western', 'mainly', 'words', 'north', 'further', 'flash', 'using', 'tone', 'local', 'east', 'west', 'channel', 'access', 'evidence', 'West', 'native', 'southern', 'finding', 'pure', 'agent', 'de']
# -----------------------------
# ['quite', 'style', 'truly', 'fare', 'entirely', 'worth', 'itself', 'New', 'online', 'became', 'tomorrow', '2013', 'finally', 'otherwise', '#', 'week', 'hardly', 'ever', 'brand', 'starting', 'Sam', 'available', 'soon', 'planned', 'division', 'further', '|', 'again', 'published', '##pp']
# -----------------------------
# ['sweet', 'due', 'indeed', 'feeling', 'met', 'past', 'brand', 'however', 'worth', 'everything', 'calling', 'saying', 'Mr', 'asking', 'felt', 'Mark', 'himself', 'becoming', 'twice', 'equal', 'instead', 'despite', 'eventually', 'factor', 'therefore', 'finally', 'idea', 'hurt', 'okay', 'ultimately']
# -----------------------------
# ['include', 'example', 'science', 'nature', 'words', 'others', 'non', 'media', 'positive', 'something', 'con', 'Ad', 'nothing', 'concrete', 'further', 'DC', 'strong', 'reading', 'course', 'beyond', 'solely', 'quantum', 'certain', 'seeing', 'bar', 'religion', 'including', 'besides', 'teaching', 'several']
# -----------------------------
# ['season', 'located', 'similar', 'obviously', 'international', 'weather', 'clearly', 'location', 'original', 'Central', 'local', 'access', 'cross', 'relationship', 'mark', 'East', 'actual', 'physical', 'style', 'often', 'natural', 'brand', 'between', 'hardly', 'Cross', 'past', 'spread', 'nearby', 'smell', 'word']
# -----------------------------
# ['nearby', 'fresh', 'fast', 'wild', 'quickly', 'instead', 'minds', 'Free', 'faster', 'apart', 'moving', 'spirit', 'together', 'St', 'further', 'bid', 'red', 'Red', 'anyway', 'hands', 'quick', 'lab', 'immediately', 'several', 'ways', 'w', 'entire', 'manner', 'alike', 'space']
# -----------------------------
# ['changed', 'writing', 'original', 'young', 'Latin', 'own', 'George', 'herself', 'staff', 'city', 'certain', 'million', 'late', 'Daniel', 'office', 'beginning', 'adult', 'everything', 'himself', 'rich', 'originally', 'deep', 'years', 'write', 'others', 'past', 'letters', 'previous', 'otherwise', 'close']
# -----------------------------
# ['super', 'whose', 'damn', 'computer', 'quality', 'mine', 'totally', 'fucking', 'network', 'private', 'personal', 'con', 'track', 'every', 'onto', 'anyone', 'professional', 'movie', 'voice', 'Internet', 'sound', 'talent', 'com', 'data', 'Facebook', 'color', 'their', 'myself', 'My', 'record']
# -----------------------------
# ['directly', 'starting', 'grade', '[UNK]', 'written', 'beginning', 'period', 'learning', 'view', 'post', 'Roman', 'learned', 'whether', 'pop', 'UK', 'Now', 'history', 'T', 'front', 'Boston', 'Sam', 'style', 'support', 'writing', '##I', 'Rome', 'Go', 'learn', 'online', 'Chinese']
# -----------------------------
# ['living', 'stuff', ']', 'known', 'worse', 'less', 'tomorrow', 'material', 'W', 'coming', 'sound', 'anyway', 'anymore', 'idea', 'speaking', 'ya', '##ful', 'bit', 'matters', 'outside', 'IT', 'creature', 'Christmas', 'ME', 'education', 'overall', 'ahead', 'alien', 'thing', 'problem']
# -----------------------------
# ['tone', 'fresh', 'green', 'further', 'towards', 'colour', 'stuff', 'soft', 'tomorrow', 'changes', 'foreign', 'piece', 'its', 'staff', 'square', 'put', 'da', 'revolution', 'weight', 'cut', 'energy', 'dear', 'New', 'away', 'room', 'intellectual', 'division', 'quality', 'Sunday', 'volume']
# -----------------------------
# ['itself', 'shot', 'himself', 'calling', 'saying', 'One', 'military', 'herself', 'gone', 'construction', 'hardware', 'using', 'fly', 'desert', 'alone', 'special', 'anymore', 'instead', 'shoot', 'model', 'chicken', 'someone', 'glass', 'electric', 'medicine', 'ordinary', 'train', 'neither', 'wearing', 'should']
# -----------------------------
# ['earlier', 'million', 'further', 'anyway', 'anymore', 'policy', 'tell', 'told', 'attack', 'likely', 'instead', 'planet', 'exactly', 'address', 'counter', 'reported', 'question', 'knowing', 'except', 'rule', 'else', 'saying', 'later', 'immediately', 'bit', 'precisely', 'published', 'worse', 'app', 'however']
# -----------------------------
# ['spread', 'daily', 'm', '##m', 'birth', 'capital', 'growing', 'entirely', 'contact', 'young', 'million', 'raw', 'feel', 'quite', 'Facebook', 'travel', 'gain', 'f', 'full', 'Internet', 'blind', 'release', 'digital', 'youth', 'growth', 'stage', 'god', 'myself', 'art', 'wanted']
# -----------------------------
# ['fucking', 'freaking', 'na', 'definitely', '_', 'bloody', '##th', 'damn', '&', 'bomb', 'probably', 'loved', 'oh', 'finally', 'done', 'eventually', 'truly', 'trace', 'rule', 'th', 'got', 'al', 'unit', 'wear', 'FM', 'possibly', 'cancer', 'du', 'remaining', 'problems']
# -----------------------------
# ['White', 'least', 'hand', 'hundred', 'fair', 'times', '50', 'million', 'individual', 'estimated', 'fat', '2000', 'capital', 'count', 'event', 'straight', 'hair', 'money', 'birth', 'percentage', 'income', 'white', 'minimum', 'gift', 'hands', 'low', 'spending', 'literally', 'fast', '100']
# -----------------------------
# ['full', '#', 'directly', 'basic', 'online', 'fresh', 'totally', '2012', 'hard', 'self', 'safe', 'Google', 'pre', 'hot', 'plot', 'via', '2013', 'campaign', 'video', 'direct', '7', 'health', 'fast', 'using', 'course', 'traditional', '5', 'quick', 'speed', '8']
# -----------------------------
# ['somewhere', '#', 'law', 'claim', 'vote', 'mass', 'inter', 'remote', 'arms', 'aid', 'points', 'funding', 'spirit', 'another', 'Lake', 'mention', 'course', 'row', 'proposed', 'open', 'stage', 'grounds', 'himself', 'further', 'fund', 'secret', 'funds', 'laws', '##ting', 'via']
# -----------------------------
# ['low', 'due', 'minimum', 'says', 'above', 'BC', 'plant', 'chance', 'usually', 'CA', 'states', 'saying', 'area', 'exercise', 'campaign', 'program', 'iron', ']', 'stuff', 'estimated', 'asked', 'supposedly', 'lower', '##1', 'reserve', 'structure', 'overhead', 'ca', 'drink', 'generally']
# -----------------------------
# ['few', 'super', 'among', 'skills', 'possibly', 'easily', 'individual', 'certainly', 'especially', 'age', 'usually', 'AI', 'former', 'experience', 'female', 'ones', 'sex', 'average', 'couple', 'having', 'fellow', 'prefer', 'typically', 'comparison', 'style', 'nor', 'probably', '#', 'male', 'track']
# -----------------------------
# ['political', 'winning', 'young', 'career', 'social', 'himself', 'fighting', 'dance', 'king', 'campaign', 'fall', 'president', 'themselves', 'business', 'mass', 'stage', 'football', 'acting', 'party', 'front', 'bust', 'President', 'youth', 'staff', 'rise', 'lead', 'dead', 'fight', 'women', 'stay']
# -----------------------------
# ['Mr', 'instead', 'another', 'middle', 'later', 'DC', 'Ms', 'bigger', 'causes', 'larger', '#', 'al', 'free', 'flight', 'c', 'below', 'Mrs', '$', 'Dr', 'stronger', 'separate', 'further', 'Peter', 'simple', 'IBM', 'stroke', 'inside', 'smaller', 'quantum', 'beyond']
# -----------------------------
# ['political', 'impact', 'wonder', 'Indian', 'separate', 'alien', '##like', '##less', 'transfer', 'security', 'pressure', 'experienced', 'eyes', 'contact', 'wing', 'differently', 'Chinese', 'Raj', 'shocked', '##ish', 'shaped', '##l', 'anymore', 'action', 'star', 'happy', 'earlier', 'solid', 'bank', '##an']
# -----------------------------
# ['rather', 'instead', 'entire', 'waste', 'super', 'cost', 'since', 'So', 'al', 'nearby', 'Radio', 'faster', 'eventually', 'whole', 'however', 'somehow', 'modern', 'fact', 'BBC', 'although', 'expensive', 'steam', 'patent', 'commercial', 'capacity', 'bio', 'buy', 'radio', 'because', 'anti']
# -----------------------------
# ['whose', 'following', 'various', 'sports', 'football', 'similar', 'quality', 'recent', 'horror', 'per', 'several', 'mystery', 'previous', 'their', 'Peter', 'truth', 'foreign', 'Big', 'every', 'follow', 'historical', 'beauty', 'below', 'wave', 'few', 'grand', 'Tom', 'each', 'these', 'big']
# -----------------------------
# ['individual', 'often', 'former', 'same', 'keep', 'sometimes', 'generally', 'several', 'media', 'rather', 'multiple', 'con', 'usually', 'especially', 'both', 'mostly', 'race', 'typically', 'kept', 'hate', 'everyone', 'although', 'ones', 'separate', 'couple', 'except', 'upset', 'original', 'television', 'relationship']
# -----------------------------
# ['various', 'same', 'whatever', 'O', 'may', 'specific', 'copy', 'Google', 'language', 'They', 'Latin', 'birth', 'changed', 'others', 'video', 'wish', 'actual', 'particular', 'final', 'exist', 'mirror', 'picture', 'guardian', 'themselves', 'certain', 'speaking', 'full', 'alter', 'Facebook', 'complete']
# -----------------------------
# ['#', 'third', 'rule', 'instead', 'large', 'number', 'h', 'higher', 'rest', 'anymore', 'lower', 'eyes', 'anyway', 'Al', '%', 'display', 'fear', 'smaller', 'hold', 'parts', 'fish', 'H', 'choice', 'cup', 'certain', 'My', 'front', 'double', 'top', 'Mr']
# -----------------------------
# ['Mr', 'becoming', 'saying', 'same', 'negative', 'past', 'yes', 'Ms', 'Mark', 'Dr', 'Mrs', 'Miss', 'opposite', 'become', 'something', 'future', 'vs', 'towards', 'former', 'shot', 'bit', 'slightly', 'aka', 'mostly', 'whereas', 'fellow', 'including', 'equal', 'double', 'ca']
# -----------------------------
# ['age', 'joint', 'anyway', 'material', 'vampire', 'without', 'anymore', 'available', 'period', 'got', 'getting', 'disease', 'selection', 'likely', 'mine', 'hair', 'exercise', 'choice', 'IV', 'determined', 'ever', 'due', 'society', 'compared', 'difference', 'virus', 'received', 'left', 'lost', 'average']
# -----------------------------
# ['particular', 'specific', 'per', 'common', 'whose', '_', 'whatever', 'What', '##ever', 'exact', 'basic', 'store', 'every', 'typical', 'song', 'each', '|', 'board', 'display', 'main', 'general', 'meeting', 'This', 'size', 'Which', 'town', 'language', 'random', 'various', 'review']
# -----------------------------
# ['spent', 'currently', 'hardly', 'quite', 'content', 'damn', 'stop', 'freaking', 'finally', 'summer', 'nearly', 'barely', '&', 'digital', 'needed', 'stopped', 'least', 'despite', 'never', 'completely', 'spend', 'except', 'population', 'totally', 'ready', 'been', 'seem', 'seemed', 'everyone', '11']
# -----------------------------
# ['worth', 'stop', '&', 'digital', 'million', 'bad', '_', 'solid', 'data', 'false', 're', 'beyond', 'de', 'album', 'nothing', 'ghost', 'published', 'happy', 'related', 'real', 'fresh', 'linear', 'key', 'games', 'seed', 'am', 'useful', 'dangerous', 'smart', 'Sir']
# -----------------------------
# ['whatever', '_', 'changed', 'fucking', 'song', 'Google', '=', 'Latin', 'change', '@', 'IT', 'letters', 'channel', 'da', 'digital', '~', 'actual', 'baby', 'du', '[UNK]', 'changing', 'Magic', 'music', 'till', '##in', 'controlling', 'someone', 'finally', '##it', 'ya']
# -----------------------------
# ['anymore', 'Mr', '[', 'young', 'Miss', 'anyway', 'separate', 'hold', 'negative', 'General', 'overall', 'ch', 'cross', 'whether', 'United', 'tonight', 'special', 'instead', 'understanding', 'graduate', 'early', 'miss', 'different', 'history', '2018', 'political', 'named', 'reading', 'changing', 'view']
# -----------------------------
# ['having', '##an', 'received', 'recently', 'somehow', 'Indian', 'hearing', 'recent', 'un', 'finally', 'our', 'ta', 'UN', 'government', 'planet', 'history', 'The', 'Han', 'na', 'Pa', 'got', 'old', 'wa', 'place', 'grand', 'had', 'Ku', 'la', 'selection', 'official']
# -----------------------------
# ['fast', 'easily', 'itself', 'simply', 'fuel', 'anymore', 'rather', 'rule', 'available', 'vampire', 'himself', 'myself', 'fighting', 'iron', 'material', 'act', 'necessary', 'literally', 'forward', 'completely', 'such', 'subject', 'mass', 'fight', 'herself', 'correct', 'flat', 'open', 'impossible', 'machine']
# -----------------------------
# ['days', 'due', 'changes', 'measures', 'planned', 'equal', 'whatever', 'final', 'Sunday', 'tomorrow', 'daily', 'yesterday', 'August', 'fast', 'hours', 'factor', 'away', 'moment', 'period', 'till', 'nearly', 'easy', 'album', 'paper', 'weight', 'red', 'soon', '~', 'minutes', 'sudden']
# -----------------------------
# ['OK', 'okay', 'com', 'Mr', 'con', 'u', 'un', 'fun', 'fucking', 'Hell', 'pro', 'en', 'non', 'ex', 'es', 'o', 'grounds', 'w', 'indie', 'ta', 'excuse', 'super', 'que', 'hey', 'ass', 'f', 'NO', 'bout', 'rules', 'Po']
# -----------------------------
# ['equal', 'weight', 'overall', 'taste', 'present', 'price', 'competition', 'stomach', 'hair', 'production', 'diet', 'amount', 'fighting', 'idea', 'So', 'al', 'waste', 'fight', 'anyway', 'What', 'supposed', 'color', 'share', 'reason', ']', 'drink', 'eating', 'breakfast', 'Diet', 'bet']
# -----------------------------
# ['written', 'changed', 'dear', 'changes', 'influence', 'basic', 'cut', 'similar', 'green', 'especially', 'based', 'away', 'fit', 'stuff', 'color', '#', 'write', '[', 'language', 'shaped', 'Latin', '##able', 'compared', 'questions', 'equal', 'higher', 'detail', 'directly', 'special', 'Martin']
# -----------------------------
# ['earlier', 'whose', 'society', 'among', 'DNA', 'overall', 'recently', 'whatever', 'management', 'along', 'generally', 'television', 'hair', 'dialogue', 'joint', 'song', '##hand', 'immediately', 'directly', '2009', 'previously', 'upon', 'apart', 'nearby', 'style', 'note', 'opinion', 'speech', 'slowly', 'quickly']
# -----------------------------
# ['anymore', 'itself', 'making', 'herself', 'writing', 'anyway', 'using', 'however', 'himself', 'learning', 'yes', 'somehow', 'online', 'calling', 'style', 'novel', 'nowadays', 'instead', 'completely', 'programming', 'creation', 'nature', 'character', 'understanding', 'tonight', 'music', 'Japanese', 'sound', 'therefore', 'Blue']
# -----------------------------
# ['example', 'usually', 'male', 'instance', 'typically', 'generally', 'fire', 'common', 'whom', '##ever', 'each', 'industry', 'often', 'having', 'hell', 'former', 'species', 'mostly', 'saying', 'inter', 'main', 'closest', 'country', 'particular', 'chosen', 'latter', 'earth', 'Ford', 'supposedly', 'female']
# -----------------------------
# ['above', 'counter', 'address', 'whatever', 'below', 'close', 'material', 'kind', 'c', 'er', 'marriage', 'needed', '##c', 'political', 'shoulder', 'What', 'followed', 'sir', 'hell', 'gender', 'CIA', 'labor', 'involved', 'minor', 'IV', '##al', 'directly', 'III', 'Johnson', 'staff']
# -----------------------------
# ['generally', 'mostly', 'count', 'between', 'pick', 'having', 'typically', 'lead', 'species', 'multiple', 'usually', 'either', 'rather', 'several', 'super', 'pair', 'both', 'race', 'themselves', 'consider', 'easily', 'slightly', 'various', 'although', 'totally', 'respectively', 'considered', 'guess', 'naturally', 'series']
# -----------------------------
# ['male', 'eh', 'pre', 'child', 'female', 'too', 'anyway', 'former', 'master', 'thus', 'ta', 'ha', 'com', 'wear', 'young', 'wa', 'super', 'becoming', 'co', 'ca', 'le', 'everywhere', 'ass', 'wearing', 'sa', 'huh', 're', 'r', 'deaf', 'Bell']
# -----------------------------
# ['[', 'same', 'typical', 'section', 'double', 'whether', 'equivalent', 'kind', '|', 'holding', 'v', 'example', 'police', 'separate', 'specific', 'something', 'versus', 'evidence', 'baby', 'side', 'parts', 'matching', 'M', 'A', 'proof', 'ex', '=', '[UNK]', 'auto', 'loving']
# -----------------------------
# ['available', 'course', 'parts', 'seen', 'evidence', 'version', 'based', 'II', 'written', 'side', 'hope', 'IV', 'DNA', 'ones', 'treatment', 'strength', 'III', 'H', 'action', 'medicine', 'technology', 'higher', 'working', 'subject', 'option', 'held', 'AI', 'case', 'able', 'required']
# -----------------------------
# ['tonight', 'together', 'anymore', 'anyway', 'cause', 'sound', 'alone', 'overall', 'dance', 'making', 'Mr', 'stage', ']', 'M', 'yourself', 'Christian', 'purpose', 'yours', 'producing', 'vampire', 'master', 'smart', 'professional', 'strong', 'anybody', 'trying', 'throat', 'meeting', 'underneath', 'own']
# -----------------------------
# ['secret', 'health', 'overall', 'tonight', 'lately', 'daily', 'red', 'yesterday', 'Christmas', 'recently', 'color', 'quality', 'loss', '##ness', 'growth', 'waste', 'throughout', 'green', '2010', 'hair', 'fair', 'anyway', 'special', 'enough', 'days', 'tomorrow', 'white', 'budget', 'production', 'coverage']
# -----------------------------
# ['former', 'stage', 'young', 'reach', 'age', 'season', 'distance', '=', 'fast', 'month', 'period', 'song', 'successfully', 'fighting', 'directly', 'speed', '##in', 'myself', 'mentally', 'speech', 'quickly', 'famous', 'campaign', 'reached', 'national', 'National', 'voice', 'physical', 'level', 'match']
# -----------------------------
# ['between', 'several', 'multiple', 'few', 'older', 'sometimes', 'similar', 'among', 'random', 'anymore', 'although', 'various', 'earlier', 'instead', 'generally', 'using', 'alike', 'though', 'per', 'often', 'neither', 'typically', 'since', 'seven', 'select', 'individual', 'either', 'same', 'numerous', 'nearby']
# -----------------------------
# ['positive', 'negative', 'itself', 'anymore', '|', 'somehow', 'online', 'learning', '+', '#', 'anything', 'machine', '[', 'otherwise', 'herself', 'based', 'fair', 'physical', 'social', 'enough', 'III', 'related', 'political', 'action', 'elsewhere', 'reverse', 'play', 'IT', 'realized', 'yet']
# -----------------------------
# ['vampire', 'age', 'available', 'supposed', 'yet', 'speed', 'hair', 'until', 'known', 'given', 'rule', 'theory', 'whatever', 'along', 'except', 'mass', 'material', 'suppose', 'magic', 'absolute', 'fighting', 'fight', 'species', 'trying', 'stage', 'reason', 'faster', 'humans', 'precisely', 'least']
# -----------------------------
# ['anyway', 'specifically', 'express', 'cross', 'related', 'directly', 'respectively', 'range', 'familiar', 'earlier', 'access', 'white', 'connection', 'style', 'connected', 'neutral', 'complex', 'located', 'attached', 'mode', 'period', 'vs', 'link', 'based', 'finger', 'II', 'original', 'square', 'yesterday', 'data']
# -----------------------------
# ['*', 'Mr', 'Dr', 'famous', 'ancient', 'shot', 'modern', 'believe', '##u', 'anyway', 'al', 'young', 'BS', 'anymore', 'm', 'overall', 'yes', 'middle', 'older', '#', 'British', 'watching', 'star', 'earlier', 'weak', 'nearby', 'wonder', 'recently', 'news', 'classic']
# -----------------------------
# ['per', 'specific', 'every', 'whatever', 'each', 'whose', 'exact', 'original', 'during', 'various', 'until', 'reference', 'types', 'whom', 'directly', 'individual', '|', 'age', 'Latin', 'First', 'influence', 'du', 'campaign', 'order', 'actual', 'type', 'contact', 'similar', 'record', 'detail']
# -----------------------------
# ['non', 'close', 'food', 'nothing', 'chance', 'gender', 'post', 'television', 'plus', 'weight', 'size', 'large', 'church', 'multi', 'suffering', 'His', 'light', 'radio', 'low', 'witness', 'ex', 'rent', 'par', 'marriage', 'zero', 'desire', 'equal', 'example', 'child', 'sugar']
# -----------------------------
# ['average', 'simply', 'same', 'someone', 'enough', 'low', 'simple', 'slim', 'able', 'young', 'plain', 'pretty', 'merely', 'easily', 'least', 'single', 'multi', 'born', 'ass', 'nice', 'super', 'noble', 'easy', 'former', 'each', 'generally', 'every', 'm', 'somebody', 'winning']
# -----------------------------
# ['anymore', 'anyway', 'itself', 'tonight', 'shot', 'elsewhere', 'mine', 'herself', 'wrong', 'trying', 'okay', 'worse', 'negative', 'again', 'OK', 'today', 'impossible', 'done', 'forever', 'saying', 'etc', 'straight', 'anything', 'property', 'III', '##able', 'instead', 'us', 'inside', 'underground']
# -----------------------------
# ['_', 'main', 'media', 'least', 'pressure', 'gets', 'phone', 'someone', 'central', '&', 'press', 'contact', 'former', 'fucking', '[', 'forces', 'message', 'link', 'blind', 'freaking', 'screen', 'alternate', 'sent', 'mainly', '/', 'lower', '=', 'communication', 'inner', 'country']
# -----------------------------
# ['tonight', 'tomorrow', 'indeed', 'alone', 'bet', 'fair', 'shot', 'along', 'anyway', 'somewhere', 'anymore', 'competition', 'anywhere', 'chance', 'option', 'law', 'fare', 'instead', 'W', 'Mr', 'idea', 'itself', 'hell', 'another', 'remote', 'PR', 'forever', 'wait', 'anyone', 'himself']
# -----------------------------
# ['brand', 'style', 'large', 'bar', 'pack', 'itself', 'saying', '##u', 'white', 'Chinese', 'Thai', 'practice', 'Southern', 'China', 'note', '##i', 'spread', 'season', 'traditional', 'compound', 'Central', 'Bar', 'eating', 'instead', 'often', 'Texas', 'smell', 'natural', 'making', 'stick']
# -----------------------------
# ['least', 'non', 'including', 'required', 'example', 'popular', 'plus', 'included', 'Internet', 'available', 'damn', 'allowed', 'road', 'near', 'needed', 'fun', 'needs', 'New', 'extra', 'market', 'summer', 'selling', 'industry', 'dedicated', 'area', 'damned', 'single', 'sold', 'content', 'morning']
# -----------------------------
# ['similar', 'mostly', 'mixed', 'non', 'based', 'been', 'style', 'especially', 'quality', 'agent', 'y', 'hot', 'London', 'typical', 'experienced', 'between', 'aka', 'star', 'typically', 'type', 'talk', 'vs', 'chemistry', 'field', '##ar', 'experience', 'born', '=', 'whose', 'nice']
# -----------------------------
# ['perfect', 'may', 'fucking', 'must', 'cannot', 'truly', 'brand', 'super', 'freaking', 'don', 'My', '##u', 'false', '##is', 'creation', '*', 'select', 'entire', 'complete', 'term', 'o', '>', 'aka', 'medical', '_', 'usually', 'movie', 'return', 'request', 'i']
# -----------------------------
# ['others', 'yourself', 'helping', 'fast', 'using', 'natural', 'reason', 'fix', 'excuse', 'himself', 'herself', 'basic', 'someone', 'purpose', 'Nick', 'calling', 'Mom', 'craft', 'try', 'considering', 'theory', 'start', 'necessary', 'sport', 'al', 'ways', 'speed', 'myself', 'faster', 'saying']
# -----------------------------
# ['plot', 'latest', 'further', 'novel', 'recent', 'clear', 'specific', 'quick', 'brought', 'published', 'broad', 'review', 'fresh', 'red', 'fund', 'drug', 'changes', 'paper', 'album', 'forest', 'gold', 'sent', 'title', 'false', '##em', 'price', 'director', 'put', 'detailed', 'soft']
# -----------------------------
# ['plot', 'nearby', 'version', 'among', 'popular', 'few', 'species', 'hands', 'movie', 'series', 'making', 'race', 'believed', 'hand', 'however', 'bet', 'famous', 'easily', 'times', 'favorite', 'having', 'West', 'box', 'using', 'nearly', 'until', 'suggested', 'song', 'instead', 'competition']
# -----------------------------
# ['specifically', 'directly', 'anyway', 'safe', 'secret', 'anymore', 'official', 'dear', 'fair', 'recently', 'done', 'missing', 'along', 'yesterday', 'miss', 'similar', 'plot', 'section', 'connection', 'legal', 'hidden', 'covering', 'protection', 'immediately', 'twice', 'remote', 'cover', '#', 'wrong', 'blood']
# -----------------------------
# ['especially', '#', '##ness', 'particularly', 'except', 'key', 'including', 'important', 'million', 'missing', 'won', 'talent', 'fact', 'gold', 'pre', 'prize', 'seemingly', 'Book', 'asking', 'fresh', 'needed', 'critical', 'believe', 'news', 'buy', 'amount', 'written', 'clue', 'rate', 'waste']
# -----------------------------
# ['saying', 'anyway', 'season', 'drink', 'itself', 'often', 'alike', 'note', 'everything', 'etc', 'Mr', 'painting', 'everywhere', 'same', 'anymore', 'together', 'shot', '##ss', 'saw', 'whatever', 'white', 'style', 'club', 'themselves', 'song', 'similar', 'felt', 'deal', 'mine', 'huh']
# -----------------------------
# ['#', 'middle', 'rule', 'standing', 'practice', 'parts', 'main', 'center', 'myself', 'room', 'somewhere', 'numbers', 'needed', 'freaking', 'point', 'open', 'points', '##in', 'wide', 'London', 'Guy', 'easily', 'rest', 'South', 'proper', 'counter', 'mentioned', 'along', 'minimum', 'altogether']
# -----------------------------
# ['between', 'oh', 'c', 'er', 'BC', 'ca', 'x', 'sir', 'money', 'letter', 'above', 'co', 'sign', 'IT', 'relationship', 'letters', 'cash', 'Roman', 'relationships', 'twins', '##us', 'development', 'respectively', 'usually', 'dad', 'coincidence', 'management', 'twin', 'lo', '##x']
# -----------------------------
# ['until', 'somehow', 'every', 'till', 'supposed', 'finally', 'age', 'nearly', 'adult', 'whole', 'official', 'entire', 'during', 'half', 'almost', 'since', 'Lord', 'clock', 'never', 'let', 'screen', 'March', 'times', 'students', 'immortal', 'attempt', 'kid', 'memory', 'release', 'discovered']
# -----------------------------
# ['nearly', 'equivalent', 'California', 'during', 'hours', 'close', 'square', 'exactly', 'safe', 'hell', 'away', 'room', 'due', 'used', 'maximum', 'near', 'precisely', 'Charlie', 'approximately', '##able', 'chicken', 'anyway', 'exact', 'empty', 'chance', 'age', 'August', 'March', 'needed', 'round']
# -----------------------------
# ['whose', 'movie', 'original', 'truly', 'actual', 'screen', 'every', 'style', 'picture', 'each', 'whom', 'record', 'memory', 'entire', '=', 'never', 'historical', 'happy', 'fact', 'album', 'damn', 'fucking', 'super', 'Your', 'web', 'making', 'reality', 'machine', 'fan', 'personal']
# -----------------------------
# ['[', '#', 'clear', 'double', 'hold', 'beef', 'read', '##d', 'strong', 'Dr', 'positive', 'reading', 'solely', 'issues', 'pro', 'excuse', 'negative', 'status', 'open', '##sh', 'BS', 'raise', 'fit', '##ed', 'using', 'doctor', 'running', 'issue', '##g', 'runs']
# -----------------------------
# ['meant', 'nuclear', 'itself', 'n', 'protection', 'safe', 'designed', 'marriage', 'micro', 'intended', 'anti', 'dating', 'pre', 'bi', 'theory', 'Canada', '15', 'rape', 'Billy', 'used', '21', 'midnight', 'certainly', 'size', '19', 'era', 'Charlie', 'rules', 'close', 'sure']
# -----------------------------
# ['saying', 'whole', 'cause', 'negative', 'earlier', 'let', 'ex', 'past', 'light', 'nothing', 'having', 'air', 'positive', 'sin', 'evidence', 'India', 'however', 'al', 'Army', 'white', 'witness', 'fact', 'non', 'therefore', 'yesterday', 'sub', 'instead', 'seeing', 'nuclear', 'r']
# -----------------------------
# ['worth', 'taking', '2008', '##in', 'making', '2007', 'fair', 'via', 'himself', 'nearly', '2009', 'close', 'forward', 'view', '2013', 'took', 'mi', 'touch', 'Cross', 'low', 'getting', 'twice', '2012', '##u', 'Park', '2015', '2005', '2014', 'taken', 'reach']
# -----------------------------
# ['style', 'star', 'totally', 'AI', 'opinion', 'especially', 'fare', 'German', 'division', 'European', 'Be', 'based', 'ranked', 'definitely', 'super', '&', 'certainly', 'French', 'policy', 'security', 'officially', 'someone', 'became', 'simply', 'national', '##less', 'another', 'Chinese', 'perfect', 'decision']
# -----------------------------
# ['currently', 'anyway', 'especially', 'important', 'fan', 'lately', 'generally', 'hot', 'popular', 'tone', 'whose', 'below', 'yours', 'mostly', 'share', 'Mr', 'overall', 'quality', 'particularly', 'missing', 'unknown', 'interesting', 'usually', 'obviously', 'besides', 'tonight', 'guess', 'named', 'friend', 'star']
# -----------------------------
# ['Chinese', '[', 'whatever', 'ma', '=', 'gets', '##ha', 'Indian', 'wonder', 'bang', 'shaped', 'young', 'studies', '|', 'overall', 'got', 'fucking', 'milk', 'leaves', 'has', 'section', 'beautiful', 'things', 'Southern', 'Ma', 'takes', '##h', 'selected', 'represents', 'pop']
# -----------------------------
# ['history', 'whole', 'un', 'future', 'positive', 'negative', 'early', 'official', 'past', 'post', 'mad', 'full', 'finally', 'further', 'reverse', 'pre', 'during', 'fully', 'events', 'speech', 'entire', 'somehow', 'press', 'everything', 'whatever', 'reform', 'fact', 'host', 'era', '[']
# -----------------------------
# ['between', 'whatever', 'named', 'version', 'thinking', 'option', 'whom', 'choice', 'born', '[', 'calling', 'yours', 'party', 'share', 'definitely', 'ex', '##r', 'idea', 'ahead', 'either', 'true', 'pick', 'expected', 'middle', 'leading', 'whose', 'lived', 'personal', 'guess', 'son']
# -----------------------------
# ['named', 'v', 'versus', 'round', 'between', 'aka', 'near', 'meeting', 'Miss', 'x', 'born', 'unlike', 'located', 'k', '$', 'married', 'across', '#', 'vs', 'becoming', '##man', 'y', 'cross', 'agent', 'sweet', '##ish', 'becomes', 'Mr', '=', 'ch']
# -----------------------------
# ['What', '|', '[', '$', '[UNK]', 'supposed', 'worth', 'whatever', 'coin', 'changed', 'what', 'idea', '{', 'taken', 'simple', 'That', 'short', 'pro', '~', 'typical', 'CIA', 'kind', 'Now', 'sum', 'meeting', '?', ';', 'How', 'exactly', 'changes']
# -----------------------------
# ['behind', 'instead', 'c', 'eventually', 'overall', 'helped', 'father', 'tonight', 'wanted', 'cost', 'whatever', 'alongside', 'price', 'upset', 'grand', 'wants', 'helping', 'ultimately', 'expected', 'sir', 'issues', 'cause', 'needed', 'causes', 'however', 'saying', 'anyway', 'son', 'white', 'below']
# -----------------------------
# ['every', 'fan', 'per', 'random', 'un', 'past', 'half', 'million', 'whole', 'since', 'press', 'damn', 'buzz', 'somewhere', 'indeed', 'proof', '100', 'thus', 'screen', 'supposedly', 'convincing', 'several', 'hit', 'twice', 'behind', 'record', 'nearby', 'mi', 'otherwise', 'fucking']
# -----------------------------
# ['pilot', 'near', 'available', 'totally', 'hot', 'definitely', 'currently', 'nearest', 'actual', 'seat', 'certainly', 'Bay', 'truly', 'freaking', 'modern', 'every', 'full', 'birth', 'whose', 'latest', 'access', 'nearly', 'record', 'candidate', 'lay', 'camp', 'least', 'possibly', 'probably', 'health']
# -----------------------------
# ['yours', 'ass', 'changed', 'yourself', 'married', 'pre', 'alive', 'former', 'lives', 'otherwise', 'yes', 'career', 'engaged', 'independent', 'met', 'same', 'meeting', 'general', 'average', '[', 'person', 'actual', 'hurt', 'close', 'fit', 'normal', 'business', 'whom', 'picture', 'happy']
# -----------------------------
# ['whatever', 'each', 'interest', 'eventually', 'same', 'dear', 'due', 'chosen', 'former', 'unknown', 'Y', 'yes', 'rich', 'choosing', 'lot', 'whom', 'whoever', 'city', 'changed', 'chance', 'originally', 'numbers', 'song', 'closer', 'surprise', 'plant', 'typically', 'directly', 'usually', 'neither']
# -----------------------------
# ['various', 'few', 'anymore', 'anyway', 'specific', 'individual', 'al', 'several', 'ones', 'numerous', 'many', 'original', 'everywhere', 'often', 'These', 'wild', 'Latin', 'spread', 'certain', 'earlier', 'weird', 'these', 'sometimes', 'Do', 'green', 'crap', 'those', 'paper', 'mess', 'generally']
# -----------------------------
# ...
# -----------------------------
# ['ex', 'mine', 'ya', 'problem', 'sir', 'yours', 'ah', 'calling', 'bar', 'met', 'fire', 'aka', 'AA', 'door', 'oh', 'yes', 'common', 'command', 'practice', 'wanted', 'file', 'mail', 'opposite', 'asking', 'mate', 'them', 'following', 'failed', 'same', 'per']
# -----------------------------
# ['something', '=', 'turn', '[', 'whatever', 'act', 'everything', '+', '_', 'reverse', 'negative', 'write', 'double', 'lot', 'van', 'office', 'otherwise', 'chose', 'coin', 'split', 'box', 'Mark', 'sum', 'shift', 'Adam', 'firm', 'political', 'rule', 'House', 'shaped']
# -----------------------------
# ['Latin', 'address', 'voice', 'mostly', 'words', 'learning', 'basic', 'text', 'writing', 'others', 'online', 'education', 'natural', 'language', 'word', 'anymore', 'teaching', 'simple', '#', 'bound', 'rich', 'Christian', 'Dr', 'few', 'beginning', 'higher', 'asking', 'working', 'written', 'co']
# -----------------------------
# ['natural', 'higher', 'lot', 'fine', 'average', 'overall', 'plus', 'mostly', 'cut', 'both', 'grow', 'put', 'basic', 'middle', 'especially', 'lower', 'increase', 'Peter', 'American', 'instead', 'm', 'generally', 'turn', 'putting', 'equal', 'comfort', 'drop', 'concept', 'French', 'strength']
# -----------------------------
# ['mad', 'independent', 'okay', 'Mr', 'met', 'pro', 'v', 'stage', 'ass', 'u', 'MS', 'match', 'married', 'post', 'ME', 'cross', 'early', 'close', 'evidence', 'clear', 'meeting', 'contact', 'Ms', 'understanding', 'dark', 'anyone', 'involved', 'former', 'someone', 'blind']
# -----------------------------
# ['simple', 'plus', 'weapons', 'least', 'including', 'clear', 'fun', 'super', 'Internet', 'grand', '~', 'speed', 'forth', 'battle', 'k', 'plot', 'plotting', 'size', 'auto', 'basic', 'copy', 'Super', '_', 'decide', 'brush', 'maximum', 'drug', 'forming', 'motor', 'others']
# -----------------------------
# ['University', 'students', 'Mom', 'somewhere', 'campus', 'College', 'IV', 'available', '#', 'UK', 'double', 'meant', 'except', 'longer', 'pro', 'traditional', 'required', 'United', 'narrow', 'means', 'basic', 'proper', 'U', 'girls', 'low', 'won', 'u', 'working', 'parts', 'milk']
# -----------------------------
# ['fact', 'saw', 'seen', 'box', 'com', 'evidence', 'however', 'games', 'India', 'ran', 'powers', 'China', 'somehow', '##3', 'version', 'seeing', 'theory', 'obviously', 'pre', 'came', 'press', 'van', 'hope', 'data', 'heard', 'Jake', 'game', 'played', 'blue', 'news']
# -----------------------------
# ['whole', 'everything', 'something', 'whatever', 'Mr', 'mad', 'director', 'sub', 'because', 'post', 'Miss', 'history', 'un', 'its', 'huge', 'issue', 'dull', 'future', 'version', 'fault', 'station', 'lands', 'why', 'broad', 'comes', 'suddenly', 'whether', 'changes', 'official', 'issues']
# -----------------------------
# ['based', 'remaining', '%', 'search', 'ranked', 'decision', 'rule', 'available', 'flat', 'feeling', 'choices', 'account', 'bet', 'placed', 'held', 'percent', 'ones', 'kept', 'easily', 'representative', 'options', 'likely', 'option', 'top', 'track', '##able', 'currently', 'score', 'betting', 'choice']
# -----------------------------
# ['anyway', 'average', 'female', 'tonight', 'however', '|', 'Mr', 'male', 'overall', 'considered', 'indeed', 'range', 'junior', 'Miss', 'pitch', 'otherwise', 'below', 'string', 'graduate', 'genius', 'too', 'h', 'Lake', 'children', 'young', 'anymore', 'scale', 'reach', 'child', 'elected']
# -----------------------------
# ['lately', 'everyone', 'screen', 'others', 'behind', 'Google', 'dull', 'ta', 'contact', 'patients', 'attention', '_', 'anymore', 'public', 'skin', 'cell', 'tonight', 'upon', 'room', 'blind', 'choose', 'trouble', 'individual', 'during', 'impact', 'affected', 'female', 'target', 'beat', '##ter']
# -----------------------------
# ['Miss', 'making', 'summer', 'worth', '=', 'trade', 'pre', 'average', 'becoming', 'become', 'year', 'future', 'truly', '##k', 'turned', 'certainly', 'M', 'makes', 'graduate', 'buy', 'ship', 'meant', 'taking', 'dream', 'Marine', 'super', 'buying', 'non', 'turn', 'picture']
# -----------------------------
# ['present', 'What', 'compared', 'supposed', 'except', 'hundred', 'used', 'hair', 'usual', 'given', 'average', '[UNK]', 'least', 'seen', 'amount', 'measured', 'typical', 'square', 'drink', 'How', 'color', 'display', 'approximately', 'how', 'common', 'way', 'example', 'similar', 'thick', 'included']
# -----------------------------
# ['let', 'firm', 'somewhere', 'zero', 'simply', 'someone', 'space', 'therefore', 'demand', 'flat', 'merely', 'van', 'sitting', 'nearby', 'fact', 'i', 'course', 'cannot', 'virtual', '$', 'poor', 'Adam', 'may', 'u', 'leaving', 'somebody', 'ship', 'although', 'totally', 'ad']
# -----------------------------
# ['similar', 'named', 'specific', 'large', 'interest', 'specifically', 'former', 'rich', 'various', 'especially', 'foreign', 'interested', 'shaped', 'particular', 'related', 'typical', 'same', 'separate', 'special', 'unlike', 'speaking', 'important', 'directly', 'fish', 'different', 'original', 'actual', 'larger', 'themselves', 'da']
# -----------------------------
# ['needs', 'condition', 'French', 'culture', 'wonder', 'having', 'Chinese', 'rights', 'India', 'therefore', 'Indian', 'learning', 'request', '##m', 'poor', 'Mother', 'supply', 'memory', 'bus', '##i', 'mother', 'thinking', '##ma', 'oh', 'Muslim', 'orders', '##my', 'order', 'requirement', 'spare']
# -----------------------------
# ['young', 'female', 'former', ']', 'average', 'whose', 'kind', 'male', 'born', 'community', 'professional', 'type', 'sort', '*', 'career', 'married', 'field', '[', 'voice', 'named', 'Who', 'unknown', 'typical', 'living', 'general', 'adult', 'dead', 'learned', 'reference', 'college']
# -----------------------------
# ['further', 'na', 'plus', 'middle', 'needs', 'family', 'remaining', 'considered', 'mother', 'below', 'facing', 'balance', 'solution', 'options', 'development', 'figure', 'tank', 'degree', 'breast', 'higher', 'III', 'less', 'shoulder', 'price', 'pill', 'growth', 'India', 'ME', 'rocket', 'clean']
# -----------------------------
# ['otherwise', 'anyway', 'thus', 'close', 'anywhere', 'involved', 'un', 'forward', '2008', 'entirely', 'equivalent', 'directly', 'away', 'way', '2004', 'Lee', 'reported', 'alive', 'however', 'period', 'stage', 'age', 'era', 'online', 'simultaneously', 'pre', 'earlier', 'average', 'fit', '2005']
# -----------------------------
# ['pressure', 'central', 'everyone', 'island', 'someone', 'middle', 'fucking', 'IS', 'freaking', 'god', 'let', 'whether', 'Jesus', 'center', 'simply', 'inner', 'evidence', 'planet', 'somebody', 'lay', 'finding', '_', 'church', 'western', 'she', 'comes', 'goddamn', 'reason', 'nearby', 'somewhere']
# -----------------------------
# ['low', 'instead', 'Mr', 'p', 'faster', 'higher', 'fast', 'fine', 'dark', 'poor', 'closer', 'prime', 'cheap', 'free', 'firm', 'cost', 'flat', 'capital', 'rich', 'Free', 'forward', 'tight', 'h', 'young', 'decent', 'c', 'hundred', 'mad', 'less', 'quick']
# -----------------------------
# ['anyway', 'anymore', 'reported', 'count', 'tonight', 'however', 'times', 'nearby', 'lately', 'recently', 'yet', 'worldwide', 'modern', 'somehow', 'believe', 'currently', 'video', 'news', 'yesterday', 'report', 'nowadays', 'waste', 'connection', 'reason', 'Channel', 'until', 'contemporary', 'channel', 'South', '##C']
# -----------------------------
# ['average', 'maximum', 'quite', 'ones', 'except', 'bottom', 'extra', 'absolutely', 'very', '_', 'minimum', 'least', 'daily', '100', 'rest', 'feeling', 'top', 'those', 'feel', 'sexual', 'reported', 'living', 'super', 'most', 'normally', 'currently', ']', 'count', 'everyday', 'lately']
# -----------------------------
# ['list', 'favorite', 'New', 'access', 'common', '#', '##able', 'song', 'various', 'spot', 'dog', 'brain', 'da', 'ones', 'few', 'voice', '##ow', 'style', 'tree', 'motor', 'fast', 'among', '##est', 'kill', 'skills', 'natural', 'cure', 'method', 'daily', 'damn']
# -----------------------------
# ['someone', 'm', 'simply', 'shot', 'am', 'walk', 'nearly', 'been', 'something', 'merely', 'being', 'past', 'fact', 'living', 'every', 'sitting', 'act', 'desire', 'Lord', 'literally', 'negative', 'never', 'species', 'self', 'race', 'straight', 'twice', 'seen', 'step', 'mere']
# -----------------------------
# ['truly', 'indeed', 'whose', 'whom', 'wonder', 'party', 'monster', 'species', ']', 'rock', 'whatever', 'creature', 'certainly', 'Christmas', 'baby', 'animal', '|', 'itself', 'That', 'share', 'truth', 'cast', 'attack', 'however', 'child', 'definitely', 'super', 'leading', 'knew', 'eating']
# -----------------------------
# ['whether', 'further', '#', 'version', 'finding', 'running', 'understanding', 'increasingly', 'lower', 'mostly', '%', 'Lady', 'especially', 'fully', 'full', 'since', 'von', 'solely', 'fact', 'speed', 'role', '_', 'internal', 'strength', 'knowledge', 'mainly', 'because', 'put', 'Google', 'middle']
# -----------------------------
# ['due', 'idea', 'changed', 'equal', '%', 'everything', 'safe', 'n', '$', 'changes', 'fair', 'changing', 'campaign', 'least', 'financial', 'increase', 'greater', 'true', 'corporate', 'always', 'amount', 'simply', 'finally', 'million', 'fine', 'Christmas', 'coverage', 'increased', 'important', 'summer']
# -----------------------------
# ['tonight', 'anyway', 'Dr', 'forever', 'specifically', 'saying', '2012', 'yesterday', '2013', 'anymore', 'novel', 'Mr', 'wa', 'helping', 'George', 'offering', 'Now', 'twin', 'setting', 'included', 'herself', 'trying', 'young', 'overnight', 'Ma', 'ha', '2014', 'worse', 'tomorrow', 'nonsense']
# -----------------------------
# ['Latin', 'coin', 'mainstream', 'themselves', 'non', 'sports', 'Peter', 'battle', 'video', 'push', 'either', 'panel', 'combined', 'speaking', 'playing', 'science', 'radio', 'football', 'chess', 'mixed', 'gene', 'fish', 'math', 'watch', 'computer', 'Dutch', 'news', 'No', 'Tech', 'German']
# -----------------------------
# ['whom', 'share', 'party', 'son', 'Sam', 'song', '_', 'met', 'particular', '|', 'named', 'v', 'head', 'brand', 'headed', 'care', 'became', 'meeting', 'safety', 'particularly', 'battle', 'especially', 'feelings', 'chief', 'main', 'report', 'side', ']', 'guard', 'collection']
# -----------------------------
# ['totally', 'basic', 'secret', 'central', '#', 'ta', 'area', 'language', 'access', 'community', 'major', 'master', 'completely', 'mostly', 'entirely', 'training', 'started', 'key', 'government', 'specifically', 'put', 'core', 'student', 'needed', 'cost', 'public', 'program', 'arm', 'official', 'seriously']
# -----------------------------
# ['future', 'during', 'several', 'learning', 'course', 'studies', 'summer', 'while', 'girls', 'students', 'week', 'young', 'average', 'changes', 'college', 'post', 'Miss', 'become', 'graduate', 'study', 'few', 'fashion', 'student', 'university', 'normal', 'learn', 'early', 'ad', 'various', 'teacher']
# -----------------------------
# ['health', 'eating', 'social', 'becoming', 'mix', 'diet', 'typical', 'beyond', 'Mr', 'pure', 'everyday', 'grow', 'Da', 'making', 'growing', 'son', 'scale', 'treat', 'clean', 'healthy', 'approaching', 'gross', 'past', 'benefits', 'impact', 'His', 'raising', 'themselves', 'traditional', 'causes']
# -----------------------------
# ['non', 'super', '~', 'pre', 'per', '#', 'causes', 'post', 'Big', 'ex', 'Super', 'multi', '|', 'following', 'fund', 'web', 'management', 'whom', 'dating', 'matching', 'using', 'micro', 'follow', 'duo', 'oh', 'via', 'giant', 'sub', 'pseudo', 'loves']
# -----------------------------
# ['kind', 'rich', 'young', 'Latin', 'sort', 'typical', 'former', 'pre', 'length', 'ordinary', 'average', 'older', 'ex', 'poor', 'married', '[', 'per', 'wonder', 'large', 'deep', 'however', 'told', 'times', 'source', 'type', 'M', 'terms', 'earlier', 'originally', 'knew']
# -----------------------------
# ['ask', 'career', 'asked', 'fellow', 'damn', 'non', 'former', 'advice', 'including', 'lay', 'idiot', 'Earth', 'upset', 'push', 'job', 'few', 'rest', 'd', 'asking', 'author', 'intelligent', 'smart', 'individual', 'lone', 'guy', 'voice', 'AI', 'command', 'adult', 'able']
# -----------------------------
# ['yourself', 'beyond', 'itself', 'dark', 'considered', 'child', 'feeling', 'born', 'final', 'herself', 'middle', 'fucking', 'acting', 'birth', 'vampire', 'stage', 'truly', 'overall', 'lived', 'late', 'considering', 'goddamn', 'understanding', 'living', 'physical', 'times', 'toward', 'understand', 'adult', 'tonight']
# -----------------------------
# ['hot', 'gay', 'date', 'pre', 'behind', 'sports', 'famous', 'dating', 'calling', 'news', 'games', '*', 'helped', 'stupid', 'author', 'friend', 'dog', 'former', 'late', 'movie', 'white', 'Christmas', 'ran', 'brand', 'dinner', 'Parker', 'campaign', 'whom', 'pick', 'beside']
# -----------------------------
# ['full', 'de', 'further', 'fully', 'critical', 'reform', 'pre', 'changes', 'final', '2010', 'daily', 'already', 're', 'stress', 'positive', 'actual', 'negative', 'speech', 'counter', 'stop', '_', 'endless', 'official', 'continue', 'supposed', ']', 'loop', 'extra', 'self', 'suddenly']
# -----------------------------
# ['u', 'na', 'background', 'co', 'sub', 'mostly', 'ad', 'term', 'v', 'non', 'pressure', 'former', 'i', 'ex', 'director', 'ch', 'an', 'mad', 'Mom', 'pro', 'com', 'b', 'lack', 'counter', 'An', 'post', 'forest', 'General', 'runs', 'van']
# -----------------------------
# ['non', 'except', 'plus', 'less', 'traffic', 'directly', 'ad', 'island', 'further', 'mostly', 'provided', 'those', 'solely', 'fresh', 'rather', 'everyone', 'full', 'additional', 'least', 'extra', 'virtual', 'nothing', 'terminal', 'If', 'rest', 'combat', 'host', 'con', 'pretend', 'let']
# -----------------------------
# ['al', 'among', 'count', 'condition', 'individual', 'finding', 'between', 'smell', 'blind', 'include', 'few', 'con', 'find', 'ratio', 'reported', '##ma', 'Southern', 'cause', 'rare', 'reason', 'fake', 'fashion', 'taste', 'street', 'sweat', 'found', 'wild', 'boy', '&', 'source']
# -----------------------------
# ['Mr', 'million', 'few', 'master', 'outside', 'song', 'per', 'similar', 'equivalent', 'custom', 'specifically', 'thousand', 'familiar', 'typical', 'strange', 'Japanese', 'besides', 'city', 'yes', 'famous', 'however', 'including', 'rich', 'fellow', 'several', 'ask', 'certain', 'hundred', 'nice', 'within']
# -----------------------------
# ['Mr', 'below', 'recently', 'sir', 'ex', 'earlier', 'above', 'within', 'anymore', 'Dr', 'secret', 'pre', 'various', 'non', 'history', 'per', 'related', 'names', 'note', 'tell', 'Bible', 'several', 'respectively', 'J', 'specifically', 'gold', 'ca', 'Mark', 'originally', 'mentioned']
# -----------------------------
# ['period', 'machine', 'helped', 'overall', 'stage', '+', 'Mr', 'anyway', 'stroke', 'eventually', 'impact', 'tomorrow', 'plan', 'respectively', 'before', 'etc', 'planned', 'Adam', 'DC', 'hand', 'dream', 'event', 'win', 'tonight', 'scale', 'ago', 'flight', 'BC', 'vampire', 'final']
# -----------------------------
# ['rest', 'chance', 'final', 'required', 'traffic', 'further', 'bloody', 'test', 'least', 'bus', 'stop', 'job', 'several', 'everyone', 'knowledge', '_', 'put', 'Google', 'practice', 'remote', 'win', 'fear', 'took', 'held', 'air', 'stopped', 'round', 'points', 'demand', 'stopping']
# -----------------------------
# ['yours', 'available', 'least', 'ever', 'sure', 'anyone', 'hit', 'data', 'brain', 'anyway', 'ones', '##ever', 'truly', 'video', 'else', 'whom', 'Google', 'record', 'planet', 'job', 'spell', 'provided', 'information', 'guy', 'unknown', 'random', 'whose', 'll', 'currently', 'dear']
# -----------------------------
# ['freaking', 'beyond', 'lay', 'fucking', 'several', 'goddamn', 'math', 'damn', 'main', 'Alaska', '_', 'brief', 'particular', 'Austen', 'further', 'butt', 'possibly', 'six', 'including', 'town', 'combat', 'web', 'climate', 'skills', 'cheer', 'solely', 'defeat', 'seven', 'Boston', 'Arizona']
