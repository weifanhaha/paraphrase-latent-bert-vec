# %%
import torch
import argparse
from tqdm import tqdm
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader
from argparse import ArgumentParser
import yaml
import os

from transformer.Models import Transformer
from transformer.Translator import Translator
from utils import same_seeds

# %%
# parse argument
parser = ArgumentParser()
parser.add_argument("--config_path", dest="config_path",
                    default='../configs/dpng_transformer_bert_tokenizer_bow_indivtopk.yaml')
parser.add_argument("--seed", dest="seed", default=0, type=int)

args = parser.parse_args()
config_path = args.config_path
seed = args.seed
print("config_path:", config_path)
print("seed: ", seed)
# Out:
# usage: ipykernel_launcher.py [-h] [--config_path CONFIG_PATH]
# ipykernel_launcher.py: error: unrecognized arguments: -f /shared_home/r08922168/.local/share/jupyter/runtime/kernel-dedc5aa2-89a1-4bfe-8719-a074b031da8f.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /shared_home/r08922168/miniconda3/envs/my_paraphrase_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3425: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# fix seed
same_seeds(seed)

# %%
##### Read Arguments from Config File #####

# config_path = '../configs/base_transformer.yaml'
# config_path = '../configs/dpng_transformer.yaml'
# config_path = '../configs/dpng_transformer_bert_tokenizer.yaml'
# config_path = '../configs/dpng_transformer_bert_tokenizer_bow.yaml'
# config_path = '../configs/dpng_transformer_bert_tokenizer_bow_indivtopk.yaml'
# config_path = '../configs/dpng_transformer_bert_tokenizer_bow_indivtopk_onlybow.yaml'
# config_path = '../configs/dpng_transformer_wordnet.yaml'

with open(config_path) as f:
    config = yaml.load(f, Loader=yaml.FullLoader)
    print(config)

save_model_path = config['save_model_path']
output_file = config['test_output_file']
use_dataset = config['dataset']

batch_size = 1

d_model = config['d_model']
d_inner_hid = config['d_inner_hid']
d_k = config['d_k']
d_v = config['d_v']

n_head = config['n_head']
n_layers = config['n_layers']
n_warmup_steps = config['n_warmup_steps']

dropout = config['dropout']
embs_share_weight = config['embs_share_weight']
proj_share_weight = config['proj_share_weight']
label_smoothing = config['label_smoothing']

train_size = config['train_size']
val_size = config['val_size']
test_size = config['test_size']

beam_size = 3
max_seq_len = 30

try:
    is_bow = config['is_bow']

    if is_bow:
        bow_strategy = config['bow_strategy']
        topk = config['topk']
        only_bow = config['only_bow']
        if bow_strategy != 'simple_sum':
            indiv_topk = config['indiv_topk']
        else:
            # not used but use default value for simplicity
            indiv_topk = 50

except KeyError:
    is_bow = False
    
try:
    use_wordnet = config['use_wordnet']
    indiv_k = config['indiv_k']
    replace_origin = config['replace_origin']
    append_bow = config['append_bow']
except KeyError:
    use_wordnet = False
    
# ###################
# Out:
# {'save_model_path': '../models/DNPG_base_transformer_wordnet.pth', 'log_file': '../logs/DNPG_base_transformer_wordnet_training.txt', 'test_output_file': '../outputs/test_DNPG_base_transformer_wordnet.txt', 'val_output_file': '../outputs/val_DNPG_base_transformer_wordnet.txt', 'dataset': 'quora_wordnet_dataset', 'num_epochs': 50, 'batch_size': 128, 'd_model': 450, 'd_inner_hid': 512, 'd_k': 50, 'd_v': 50, 'n_head': 9, 'n_layers': 3, 'n_warmup_steps': 12000, 'dropout': 0.1, 'embs_share_weight': True, 'proj_share_weight': True, 'label_smoothing': False, 'train_size': 100000, 'val_size': 4000, 'test_size': 20000, 'is_bow': False, 'lr': '1e-3', 'use_wordnet': True, 'indiv_k': 5, 'replace_origin': False}

# %%
# set model and log path
seed_model_root = '../models/fixseed/seed{}/'.format(seed)
seed_output_root = '../outputs/fixseed/seed{}/'.format(seed)

if not os.path.exists(seed_model_root):
    os.makedirs(seed_model_root)

if not os.path.exists(seed_output_root):
    os.makedirs(seed_output_root)

save_model_path = seed_model_root + save_model_path.split('/')[-1]
output_file = seed_output_root + output_file.split('/')[-1]
print('seed: ', seed)
print('save model path: ', save_model_path)
print('output file: ', output_file)

# %%
# ############### Arguments ###############
# # The argument is same for DNPG paper
# save_model_path = '../models/DNPG_base_transformer.pth'
# output_file = '../outputs/test_DNPG_transformer_out.txt'
# max_seq_len = 30

# batch_size = 1
# beam_size = 3 # 1 for greedy

# d_model = 450
# d_inner_hid = 512
# d_k = 64
# d_v = 64

# n_head = 9
# n_layers = 3
# dropout = 0.1
# embs_share_weight = True
# proj_share_weight = True

# train_size = 100000
# val_size = 4000
# test_size = 20000
# #######################################

# %%
# ##### Arguments #####
# d_model = 512
# save_model_path = '../models/base_transformer.pth'
# batch_size = 1
# beam_size = 3 # 1 for greedy
# max_seq_len = 30
# output_file = '../outputs/val_transformer_out.txt'

# d_model = 512
# d_inner_hid = 512
# d_k = 64
# d_v = 64

# n_head = 8
# n_layers = 6
# dropout = 0.1
# embs_share_weight = True
# proj_share_weight = True
# ###################

# %%
# load dataset
from datasets.quora_text_dataset import QuoraTextDataset

if use_dataset == 'quora_dataset':
    from datasets.quora_dataset import QuoraDataset as Dataset
elif use_dataset == 'quora_wordnet_dataset':
    from datasets.quora_wordnet_dataset import QuoraWordnetDataset as Dataset
elif use_dataset == 'quora_wordnet_aug_dataset':
    from datasets.quora_wordnet_aug_dataset import QuoraWordnetAugDataset as Dataset        
else:
    raise NotImplementedError("Dataset is not defined or not implemented: {}".format(use_dataset))

# %%
def create_mini_batch(samples):
    seq1_tensors = [s[0] for s in samples]
    seq2_tensors = [s[1] for s in samples]

    # zero pad
    seq1_tensors = pad_sequence(seq1_tensors,
                                  batch_first=True)

    seq2_tensors = pad_sequence(seq2_tensors,
                                  batch_first=True)    
    
    return seq1_tensors, seq2_tensors

if use_wordnet:
    dataset = Dataset("test", train_size, val_size, test_size, indiv_k=indiv_k, replace_origin=False, append_bow=append_bow)
else:
    dataset = Dataset("test", train_size, val_size, test_size)
same_seeds(seed)    
text_dataset = QuoraTextDataset("test", train_size, val_size, test_size)
data_loader = DataLoader(dataset, batch_size=batch_size, collate_fn=create_mini_batch, shuffle=False)
# Out:
# 100%|██████████| 20000/20000 [00:00<00:00, 86411.37it/s]
# [Info] Loading the Dictionary...
# [Info] Dictionary Loaded

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transformer = Transformer(
    dataset.n_words,
    dataset.n_words,
    src_pad_idx=dataset.PAD_token_id,
    trg_pad_idx=dataset.PAD_token_id,
    trg_emb_prj_weight_sharing=proj_share_weight,
    emb_src_trg_weight_sharing=embs_share_weight,
    d_k=d_k,
    d_v=d_v,
    d_model=d_model,
    d_word_vec=d_model,
    d_inner=d_inner_hid,
    n_layers=n_layers,
    n_head=n_head,
    dropout=dropout    
)

model = transformer.to(device)

model.load_state_dict((torch.load(
        save_model_path, map_location=device)))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-e33c0bba710f> in <module>
#      18 )
#      19
# ---> 20 model = transformer.to(device)
#      21
#      22 model.load_state_dict((torch.load(
#
# ~/miniconda3/envs/my_paraphrase_env/lib/python3.7/site-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#     610             return t.to(device, dtype if t.is_floating_point() else None, non_blocking)
#     611
# --> 612         return self._apply(convert)
#     613
#     614     def register_backward_hook(
#
# ~/miniconda3/envs/my_paraphrase_env/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/miniconda3/envs/my_paraphrase_env/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/miniconda3/envs/my_paraphrase_env/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/miniconda3/envs/my_paraphrase_env/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/miniconda3/envs/my_paraphrase_env/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# ~/miniconda3/envs/my_paraphrase_env/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply(self, fn)
#     379                 # `with torch.no_grad():`
#     380                 with torch.no_grad():
# --> 381                     param_applied = fn(param)
#     382                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     383                 if should_use_set_data:
#
# ~/miniconda3/envs/my_paraphrase_env/lib/python3.7/site-packages/torch/nn/modules/module.py in convert(t)
#     608             if convert_to_format is not None and t.dim() == 4:
#     609                 return t.to(device, dtype if t.is_floating_point() else None, non_blocking, memory_format=convert_to_format)
# --> 610             return t.to(device, dtype if t.is_floating_point() else None, non_blocking)
#     611
#     612         return self._apply(convert)
#
# RuntimeError: CUDA out of memory. Tried to allocate 2.00 MiB (GPU 0; 10.91 GiB total capacity; 88.33 MiB already allocated; 3.56 MiB free; 94.00 MiB reserved in total by PyTorch)

# %%
src_pad_idx = dataset.PAD_token_id
trg_pad_idx = dataset.PAD_token_id
    
trg_bos_idx = dataset.SOS_token_id
trg_eos_idx = dataset.EOS_token_id
unk_idx = dataset.UNK_token_id

# %%
translator = Translator(
        model=model,
        beam_size=beam_size,
        max_seq_len=max_seq_len,
        src_pad_idx=src_pad_idx,
        trg_pad_idx=trg_pad_idx,
        trg_bos_idx=trg_bos_idx,
        trg_eos_idx=trg_eos_idx).to(device)

# %%
# todo: modify to  Source / Target / Input / Output
idx2word = dataset.idx2word
with open(output_file, 'w') as f:
    for i, (seq1, seq2) in enumerate(tqdm(data_loader)):
        input_seq = seq1.to(device)
        trg_seq = seq2[0].tolist()
        
        pred_seq = translator.translate_sentence(input_seq)
        pred_line = ' '.join(idx2word[idx] for idx in pred_seq)
        pred_line = pred_line.replace(dataset.SOS_token, '').replace(dataset.EOS_token, '')
            
        input_line = ' '.join(idx2word[idx] for idx in input_seq[0].tolist())
        input_line = input_line.replace(dataset.SOS_token, '').replace(dataset.EOS_token, '')

        src_line, trg_line = text_dataset.sentences[i]
        
#         print('*' * 80)
#         print('Source: ', src_line.strip())
#         print('Target: ', trg_line.strip())
#         print('Input: ', input_line.strip())
#         print('Predict: ', pred_line.strip())
        
        f.write('*' * 80)
        f.write('\n')
        f.write('Source: {}\n'.format(src_line.strip()))
        f.write('Target: {}\n'.format(trg_line.strip()))
        f.write('Input: {}\n'.format(input_line.strip()))
        f.write('Predict: {}\n'.format(pred_line.strip()))
# Out:
#   2%|▏         | 368/20000 [00:00<00:10, 1824.22it/s]
# ********************************************************************************
# Source:  What is the food you can eat every day for breakfast lunch and dinner ?
# Target:  Is it healthy to eat fish every day ?
# Input:  What is the food you can eat every day for breakfast lunch and dinner ?
# ********************************************************************************
# Source:  What are some of the best ways to write in exams ?
# Target:  How do we write the exam ?
# Input:  What are some of the best ways to write in exams ?
# ********************************************************************************
# Source:  Which are best novels one should must read before die ?
# Target:  What are the top novels I should read before I die ? And why ?
# Input:  Which are best novels one should must read before die ?
# ********************************************************************************
# Source:  What will be your New Year s resolution for ?
# Target:  What is your resolution for ?
# Input:  What will be your New Year s resolution for ?
# ********************************************************************************
# Source:  How should I study in first year of MBBS ?
# Target:  How should I study to pass the first Semester of the st year of MBBS ?
# Input:  How should I study in first year of MBBS ?
# ********************************************************************************
# Source:  Who are the top ten astrologers in India ?
# Target:  Who are the top ten Indian astrologers ?
# Input:  Who are the top ten astrologers in India ?
# ********************************************************************************
# Source:  How do I tell a friend that his legs body stinks of bad odor without hurting his feelings ?
# Target:  How do you tell a friend or colleague they they have body odor without offending them ?
# Input:  How do I tell a friend that his legs body stinks of bad odor without hurting his feelings ?
# ********************************************************************************
# Source:  What are the benefits you got from reading ?
# Target:  Which really are the benefits of reading ?
# Input:  What are the benefits you got from reading ?
# ********************************************************************************
# Source:  How can we make money from YouTube ?
# Target:  How can I make money on YouTube ?
# Input:  How can we make money from YouTube ?
# ********************************************************************************
# Source:  How do I stop caring about what others think ?
# Target:  When will I stop thinking about what other people think ?
# Input:  How do I stop caring about what others think ?
# ********************************************************************************
# Source:  Why chemistry is so boring ?
# Target:  Why is chemistry so boring ?
# Input:  Why chemistry is so boring ?
# ********************************************************************************
# Source:  Do IITs have sports coaches ?
# Target:  Do iits have sports coaching ?
# Input:  Do IITs have sports coaches ?
# ********************************************************************************
# Source:  How can I get entry in MIT ?
# Target:  How IS TO get into MIT ?
# Input:  How can I get entry in MIT ?
# ********************************************************************************
# Source:  How is it to work as a fresher in Deloitte ?
# Target:  Working at Deloitte ?
# Input:  How is it to work as a fresher in Deloitte ?
# ********************************************************************************
# Source:  What are tracer rounds ? Are they legal for the public to possess in the state of Delaware ?
# Target:  What are tracer rounds ? Are they legal for the public to possess in the state of Arizona ?
# Input:  What are tracer rounds ? Are they legal for the public to possess in the state of Delaware ?
# ********************************************************************************
# Source:  What is the best platform media source to learn digital marketing ?
# Target:  What are the best resources available to learn Digital Marketing Social Media and Online Strategies ?
# Input:  What is the best platform media source to learn digital marketing ?
# ********************************************************************************
# Source:  Why do people ask such questions here on Quora which could be easily found on the internet ?
# Target:  Why do folks ask questions on Quora that a Google search could answer faster and more accurately ?
# Input:  Why do people ask such questions here on Quora which could be easily found on the internet ?
# ********************************************************************************
# Source:  How can you speak and learn fluent English like Karan Johar ?
# Target:  How can I speak fluent english with confidence ?
# Input:  How can you speak and learn fluent English like Karan Johar ?
# ********************************************************************************
# Source:  How much marks do I have to score in NEET to get a seat in a prestigious government medical college in India ?
# Target:  How much do I need to score in neet to get a government medical seat ?
# Input:  How much marks do I have to score in NEET to get a seat in a prestigious government medical college in India ?
# ********************************************************************************
# Source:  How can the drive from Edmonton to Auckland be described and how do these cities attractions compare to those in Windsor ?
# Target:  How can the drive from Edmonton to Auckland be described and how do these cities attractions compare to those in Calgary ?
# Input:  How can the drive from Edmonton to Auckland be described and how do these cities attractions compare to those in Windsor ?
# ********************************************************************************
# Source:  What role does a father play in a child s life ?
# Target:  What role does your father play in your life ?
# Input:  What role does a father play in a child s life ?
# ********************************************************************************
# Source:  How can I improve score in PTE ?
# Target:  How do I prepare for PTE ?
# Input:  How can I improve score in PTE ?
# ********************************************************************************
# Source:  Palliative care services in India . What barriers would we face in teaching and providing care ? What will be most culturally acceptable ?
# Target:  What are the barriers we would face in teaching and providing care to teach palliative care services in India ? What will be the most culturally acceptable ?
# Input:  Palliative care services in India . What barriers would we face in teaching and providing care ? What will be most culturally acceptable ?
# ********************************************************************************
# Source:  Super Smash Bros . Brawl What is the best strategy against Sheik ?
# Target:  Super Smash Bros . Brawl What is the best Sheik strategy ?
# Input:  Super Smash Bros . Brawl What is the best strategy against Sheik ?
# ********************************************************************************
# Source:  What opportunities exist after completing a B .Tech in mechanical engineering ?
# Target:  I m a mechanical engineering student . What skills should I possess after completing my B .Tech ?
# Input:  What opportunities exist after completing a B .Tech in mechanical engineering ?
# ********************************************************************************
# Source:  How would a military coup in the US be foiled ?
# Target:  How likely is a military coup in the United States ?
# Input:  How would a military coup in the US be foiled ?
# ********************************************************************************
# Source:  What are the top five strongest militaries in the world ?
# Target:  What are the strongest military armies in the world ?
# Input:  What are the top five strongest militaries in the world ?
# ********************************************************************************
# Source:  Will the value of Indian rupee increase after the ban of and rupee notes ?
# Target:  What would be the possible impact on Indian economy after cancellation of and Rs notes ?
# Input:  Will the value of Indian rupee increase after the ban of and rupee notes ?
# ********************************************************************************
# Source:  How do you train a pet magpie ?
# Target:  How do you train a magpie ?
# Input:  How do you train a pet magpie ?
# ********************************************************************************
# Source:  What do you think about NdTv ban for a day in India ? All unbiased answers are welcome .
# Target:  What do you think about the day ban on NDTV by Modi Govt . ?
# Input:  What do you think about NdTv ban for a day in India ? All unbiased answers are welcome .
# ********************************************************************************
# Source:  How do I add an image to a question on Quora ?
# Target:  How do I add photos to my questions on Quora ?
# Input:  How do I add an image to a question on Quora ?
# ********************************************************************************
# Source:  How do you speak in front of large groups of people ?
# Target:  How do I speak up in front of many people ?
# Input:  How do you speak in front of large groups of people ?
# ********************************************************************************
# Source:  Which are some of the best romantic movies ?
# Target:  What are some of the best romantic movies in English ?
# Input:  Which are some of the best romantic movies ?
# ********************************************************************************
# Source:  How much money can a country print every year ?
# Target:  Why can t every country print as much money as they want ? What puts a limit on the printing ?
# Input:  How much money can a country print every year ?
# ********************************************************************************
# Source:  What is the difference between adapt and adopt ?
# Target:  What s the difference between adapt and adopt ?
# Input:  What is the difference between adapt and adopt ?
# ********************************************************************************
# Source:  If you recall your memory to the best you can what is the oldest memory of your life ? i .e What is the first memory in your life ?
# Target:  What is the oldest memory you can recall ?
# Input:  If you recall your memory to the best you can what is the oldest memory of your life ? i .e What is the first memory in your life ?
# ********************************************************************************
# Source:  Would Apple get rid of their Braille display support in iOS devices ?
# Target:  Would Apple get rid of voiceover and Braille support on iOS ?
# Input:  Would Apple get rid of their Braille display support in iOS devices ?
# ********************************************************************************
# Source:  Who ll get the Iron Throne in Game of Thrones ?
# Target:  Who will be on the Iron Throne at the end of Game Of Thrones ?
# Input:  Who ll get the Iron Throne in Game of Thrones ?
# ********************************************************************************
# Source:  How do I learn the art of meditating ?
# Target:  Where can I start to learn meditation ?
# Input:  How do I learn the art of meditating ?
# ********************************************************************************
# Source:  Does Hillary Clinton have any serious health issues ?
# Target:  Why does it matter if Hillary Clinton has poor health ?
# Input:  Does Hillary Clinton have any serious health issues ?
# ********************************************************************************
# Source:  What is the meaning of RMS ?
# Target:  What is the meaning of RMS ?
# Input:  What is the meaning of RMS ?
# ********************************************************************************
# Source:  How much will the road tax be under GST in india ?
# Target:  How will GST impact on the road tax issue in India ?
# Input:  How much will the road tax be under GST in india ?
# ********************************************************************************
# Source:  What backpack was used by Oliver Queen to break out John Diggle from prison in Arrow Season ?
# Target:  What mask was used by Oliver Queen to break out John Diggle from prison in Arrow Season ?
# Input:  What backpack was used by Oliver Queen to break out John Diggle from prison in Arrow Season ?
# ********************************************************************************
# Source:  How can I hack my snapchat password ?
# Target:  Can someone hack my snapchat password ?
# Input:  How can I hack my snapchat password ?
# ********************************************************************************
# Source:  What s the meaning of John Berger s Each pine at dusk poem ?
# Target:  What s the meaning of this poem by John Berger ?
# Input:  What s the meaning of John Berger s Each pine at dusk poem ?
# ********************************************************************************
# Source:  Have you ever seen ghost really ?
# Target:  Have you ever seen any ghost ?
# Input:  Have you ever seen ghost really ?
# ********************************************************************************
# Source:  Where how can I find a mentor ?
# Target:  Where and how can I find a life coach or mentor ?
# Input:  Where how can I find a mentor ?
# ********************************************************************************
# Source:  What is maturity in general ?
# Target:  What do you think maturity means ?
# Input:  What is maturity in general ?
# ********************************************************************************
# Source:  How can I speak English like natives ?
# Target:  HOw do I speak Fluent English ?
# Input:  How can I speak English like natives ?
# ********************************************************************************
# Source:  How often does the average couple have sex ?
# Target:  How often couples have sex ?
# Input:  How often does the average couple have sex ?
# ********************************************************************************
# Source:  How do stop smoking ?
# Target:  What are the possible ways to stop smoking ?
# Input:  How do stop smoking ?
# ********************************************************************************
# Source:  Why does the liquid part of the egg become solid when we boil it ?
# Target:  Why egg becomes hard when we boil it ?
# Input:  Why does the liquid part of the egg become solid when we boil it ?
# ********************************************************************************
# Source:  How much weight can a quadcopter lift ?
# Target:  How much weight can a drone carry ?
# Input:  How much weight can a quadcopter lift ?
# ********************************************************************************
# Source:  How can I determine a good patent attorney ?
# Target:  How can I find a good provisional patent attorney ?
# Input:  How can I determine a good patent attorney ?
# ********************************************************************************
# Source:  How so I ask questions on Quora ?
# Target:  What are some good tips for asking questions on Quora ?
# Input:  How so I ask questions on Quora ?
# ********************************************************************************
# Source:  What is a strong point that we aren t living in a simulation ?
# Target:  Is it possible for humans to prove that we aren t living in the matrix ?
# Input:  What is a strong point that we aren t living in a simulation ?
# ********************************************************************************
# Source:  Should India go for war with Pakistan ?
# Target:  Should India go through war with Pakistan ?
# Input:  Should India go for war with Pakistan ?
# ********************************************************************************
# Source:  What are the best books to start learning about finance ?
# Target:  Which is the best book on personal finance ?
# Input:  What are the best books to start learning about finance ?
# ********************************************************************************
# Source:  How should I prepare for BITSAT examination ?
# Target:  What should be the strategy to prepare for BITSAT ?
# Input:  How should I prepare for BITSAT examination ?
# ********************************************************************************
# Source:  How can I find out who has logged into my Instagram account ?
# Target:  Can you tell if someone else has logged into your Instagram account ?
# Input:  How can I find out who has logged into my Instagram account ?
# ********************************************************************************
# Source:  Will the war between India and Pakistan take place ?
# Target:  Can a war between India and Pakistan really take place ?
# Input:  Will the war between India and Pakistan take place ?
# ********************************************************************************
# Source:  What will be the impact of banning Rs . and Rs . on the Indian economy ?
# Target:  How can the ban of and rupee notes increase the Indian economy ?
# Input:  What will be the impact of banning Rs . and Rs . on the Indian economy ?
# ********************************************************************************
# Source:  What is the difference between a public limited company and a private limited company ? Which is better ?
# Target:  What is the main difference between a public Ltd . company and a private Ltd . company ?
# Input:  What is the difference between a public limited company and a private limited company ? Which is better ?
# ********************************************************************************
# Source:  What do you think about the Indian Government policy of not circulating INR and INR ?
# Target:  What do you think about Modi s new policy on the ban of Rs and Rs notes ?
# Input:  What do you think about the Indian Government policy of not circulating INR and INR ?
# ********************************************************************************
# Source:  What does sociodemographic mean ? How is it used in marketing ?
# Target:  What does sociodemographic mean ? How is it used in social sciences ?
# Input:  What does sociodemographic mean ? How is it used in marketing ?
# ********************************************************************************
# Source:  What books should I read to develop reading habits ?
# Target:  What books should I read to develop reading a habit ?
# Input:  What books should I read to develop reading habits ?
# ********************************************************************************
# Source:  How should I start learning Python ?
# Target:  I am New to Deep Learning . How do I start with Python ?
# Input:  How should I start learning Python ?
# ********************************************************************************
# Source:  Why is Saltwater Taffy candy imported in Spain ?
# Target:  Why is Saltwater Taffy candy imported in Portugal ?
# Input:  Why is Saltwater Taffy candy imported in Spain ?
# ********************************************************************************
# Source:  For a very first beginner what are ways to start with competitive programming ?
# Target:  How do I start competitive programming as a beginner ?
# Input:  For a very first beginner what are ways to start with competitive programming ?
# ********************************************************************************
# Source:  What are the best books for SSC CGL preparation ?
# Target:  Which are the best books for SSC CGL ?
# Input:  What are the best books for SSC CGL preparation ?
# ********************************************************************************
# Source:  Why is Quora so completely biased towards Hillary Clinton ?
# Target:  Has Quora turned into a political hack for Clinton ?
# Input:  Why is Quora so completely biased towards Hillary Clinton ?
# ********************************************************************************
# Source:  Would you rather be loved by many or feared by all ?
# Target:  Would you rather be feared or loved ?
# Input:  Would you rather be loved by many or feared by all ?
# ********************************************************************************
# Source:  What s annoying about feminism ?
# Target:  What are the downfalls of feminism ?
# Input:  What s annoying about feminism ?
# ********************************************************************************
# Source:  How do I start my preparations for Google Summer of Code ?
# Target:  What are the tips for clearing Google Summer of Code ?
# Input:  How do I start my preparations for Google Summer of Code ?
# ********************************************************************************
# Source:  I have extremely bad keratosis pilaris rubra facetious all over my cheeks and they are extremely red all of the time . How can I get rid of this ?
# Target:  How do I get rid of keratosis pilaris on my tricep areas ?
# Input:  I have extremely bad keratosis pilaris rubra facetious all over my cheeks and they are extremely red all of the time . How can I get rid of this ?
# ********************************************************************************
# Source:  Can I join Indian Army with myopia ?
# Target:  Can I join the Indian Army with myopia ?
# Input:  Can I join Indian Army with myopia ?
# ********************************************************************************
# Source:  How can I trade forex in India legally ?
# Target:  How do I trade Forex legally from India ?
# Input:  How can I trade forex in India legally ?
# ********************************************************************************
# Source:  What are the best movies ever irrespective of genre ?
# Target:  What are the best movies of all time ?
# Input:  What are the best movies ever irrespective of genre ?
# ********************************************************************************
# Source:  How can I get rid of my anger ?
# Target:  How can I get rid of anger ?
# Input:  How can I get rid of my anger ?
# ********************************************************************************
# Source:  What are some good Android apps for video editing ?
# Target:  What are some good video editing apps for Android ?
# Input:  What are some good Android apps for video editing ?
# ********************************************************************************
# Source:  What are some interesting differences between a current account and a saving account ?
# Target:  What s difference between saving account and current account ?
# Input:  What are some interesting differences between a current account and a saving account ?
# ********************************************************************************
# Source:  My friend is depressed what can I do to help ?
# Target:  How do I help my friend with depression ?
# Input:  My friend is depressed what can I do to help ?
# ********************************************************************************
# Source:  Why do Hindus feel closer to the Sikhs ?
# Target:  Do Sikhs consider Hindus as their brothers ?
# Input:  Why do Hindus feel closer to the Sikhs ?
# ********************************************************************************
# Source:  How can I prevent SQL injection in my site ?
# Target:  How do I prevent sql injection ?
# Input:  How can I prevent SQL injection in my site ?
# ********************************************************************************
# Source:  How can I be the best husband to my wife ?
# Target:  How can I be a good husband for my wife ?
# Input:  How can I be the best husband to my wife ?
# ********************************************************************************
# Source:  What is the best way to do self study ?
# Target:  What is the best way to self study ?
# Input:  What is the best way to do self study ?
# ********************************************************************************
# Source:  What is better SEO or PPC ?
# Target:  Which one is better SEO or PPC ?
# Input:  What is better SEO or PPC ?
# ********************************************************************************
# Source:  Can someone translate this Kannada text to English Hindi ?
# Target:  Could someone translate this Kannada text to English Hindi ?
# Input:  Can someone translate this Kannada text to English Hindi ?
# ********************************************************************************
# Source:  How do you improve speaking skills in public ?
# Target:  How can I improve my public speaking ability ?
# Input:  How do you improve speaking skills in public ?
# ********************************************************************************
# Source:  How much does it cost to print at Kinkos ?
# Target:  What does it cost to print at Kinkos ?
# Input:  How much does it cost to print at Kinkos ?
# ********************************************************************************
# Source:  What are the various ways through which one can earn money online ?
# Target:  How can I earn money online seriously ?
# Input:  What are the various ways through which one can earn money online ?
# ********************************************************************************
# Source:  What is the funniest joke you have read or herd ? Com on share with others also
# Target:  What is the funniest joke you have ever read heard or listened ?
# Input:  What is the funniest joke you have read or herd ? Com on share with others also
# ********************************************************************************
# Source:  What are the best tricks to remember what you read ?
# Target:  How can I remember what I ve read ?
# Input:  What are the best tricks to remember what you read ?
# ********************************************************************************
# Source:  How do I find a lost android phone ?
# Target:  How do I find my lost android phone ?
# Input:  How do I find a lost android phone ?
# ********************************************************************************
# Source:  What are some traits of Hamlet ?
# Target:  What are character traits of Hamlet ?
# Input:  What are some traits of Hamlet ?
# ********************************************************************************
# Source:  What is your favorite book that you have read this year ?
# Target:  What s your favorite read of this year ?
# Input:  What is your favorite book that you have read this year ?
# ********************************************************************************
# Source:  Has demonetisation failed ?
# Target:  Is Modi s demonetisation failing ?
# Input:  Has demonetisation failed ?
# ********************************************************************************
# Source:  Does drinking green tea for weight loss really help ? Does it have any adverse effects on your skin ?
# Target:  How does green tea helps in weight loss ?
# Input:  Does drinking green tea for weight loss really help ? Does it have any adverse effects on your skin ?
# ********************************************************************************
# Source:  What are some diseases of the respiratory system ?
# Target:  What are the diseases related to respiratory system ?
# Input:  What are some diseases of the respiratory system ?
# ********************************************************************************
# Source:  How do I improve English writing skills as well as the ability to analyse texts as an English learner ?
# Target:  How do I improve my English writing ability ?
# Input:  How do I improve English writing skills as well as the ability to analyse texts as an English learner ?
# ********************************************************************************
# Source:  What are the best ways to promote a YouTube channel ?
# Target:  How can I improve a slow growing Youtube channel ?
# Input:  What are the best ways to promote a YouTube channel ?
# ********************************************************************************
# Source:  What should be done to improve our education system ?
# Target:  How can we improve our education system so as to better prepare young people for an uncertain future ?
# Input:  What should be done to improve our education system ?
# ********************************************************************************
# Source:  What are Some of the best iphone gadgets ?
# Target:  What are the best Iphone gadgets for ?
# Input:  What are Some of the best iphone gadgets ?
# ********************************************************************************
# Source:  How can I create my own chatbot from scratch ?
# Target:  How do I create a chatbot app ?
# Input:  How can I create my own chatbot from scratch ?
# ********************************************************************************
# Source:  How do I know if someone blocked me on WhatsApp or not ?
# Target:  How do I find if someone has blocked me on watsapp ?
# Input:  How do I know if someone blocked me on WhatsApp or not ?
# ********************************************************************************
# Source:  How did Donald Trump win the Presidential Election ?
# Target:  How did Donald Trump win the Presidential election ?
# Input:  How did Donald Trump win the Presidential Election ?
# ********************************************************************************
# Source:  What is a sewing machine used for ?
# Target:  How is the sewing machine used ?
# Input:  What is a sewing machine used for ?
# ********************************************************************************
# Source:  Which is the best earphone under rs ?
# Target:  What is the best earphone under rs ?
# Input:  Which is the best earphone under rs ?
# ********************************************************************************
# Source:  What would be the best way to quit smoking ?
# Target:  How do you quit smoking ?
# Input:  What would be the best way to quit smoking ?
# ********************************************************************************
# Source:  How do Americans view British people ?
# Target:  What do Americans think of British people ?
# Input:  How do Americans view British people ?
# ********************************************************************************
# Source:  What are the best venture capital firms in India ?
# Target:  What is the best venture capitalist firm in India ?
# Input:  What are the best venture capital firms in India ?
# ********************************************************************************
# Source:  Would Arvind Kejriwal become PM in the future ?
# Target:  Do you think Kejriwal can ever become PM ?
# Input:  Would Arvind Kejriwal become PM in the future ?
# ********************************************************************************
# Source:  Why have my Instagram hashtags stopped working ?
# Target:  Why have Instagram hashtags stopped working ? What is the new algorithm ?
# Input:  Why have my Instagram hashtags stopped working ?
# ********************************************************************************
# Source:  How often do US inmates use smuggled cell phones in jail ?
# Target:  How often do the US inmates use smuggled cell phones in jail ?
# Input:  How often do US inmates use smuggled cell phones in jail ?
# ********************************************************************************
# Source:  How can I lose weight slowly and naturally ?
# Target:  How can you lose weight fast in a healthy way ?
# Input:  How can I lose weight slowly and naturally ?
# ********************************************************************************
# Source:  Where are the cameras placed during a cricket match ?
# Target:  Where are the cameras located in a cricket match ?
# Input:  Where are the cameras placed during a cricket match ?
# ********************************************************************************
# Source:  Is any startup in India recruiting SDE interns for winters ?
# Target:  Is any startup in India recruiting SDE interns for winter ?
# Input:  Is any startup in India recruiting SDE interns for winters ?
# ********************************************************************************
# Source:  What causes fibromyalgia ?
# Target:  What is the true cause of Fibromyalgia ?
# Input:  What causes fibromyalgia ?
# ********************************************************************************
# Source:  How should I prepare for TSPSC Group ?
# Target:  How should I prepare for TSPSC GROUP services ?
# Input:  How should I prepare for TSPSC Group ?
# ********************************************************************************
# Source:  How can I interact with people on Quora ?
# Target:  How do I interact with people on Quora ?
# Input:  How can I interact with people on Quora ?
# ********************************************************************************
# Source:  How do I contact a certified hacker ?
# Target:  How do I contact a good hacker ?
# Input:  How do I contact a certified hacker ?
# ********************************************************************************
# Source:  How do you get into a locked iPod ? Is it possible ?
# Target:  How can you get into a locked iPod touch ?
# Input:  How do you get into a locked iPod ? Is it possible ?
# ********************************************************************************
# Source:  I m how do I get into top range universities ?
# Target:  How can I get into a top university ?
# Input:  I m how do I get into top range universities ?
# ********************************************************************************
# Source:  How do I get rid of a computer virus ?
# Target:  How do I get rid of a computer virus program ?
# Input:  How do I get rid of a computer virus ?
# ********************************************************************************
# Source:  Facebook makes money through ads how does Quora make money ?
# Target:  How does Quora make money ?
# Input:  Facebook makes money through ads how does Quora make money ?
# ********************************************************************************
# Source:  What is purpose of LaTex ?
# Target:  What is LaTeX ?
# Input:  What is purpose of LaTex ?
# ********************************************************************************
# Source:  What happens after we die ?
# Target:  What will happen after we die ? Does nothing happen ?
# Input:  What happens after we die ?
# ********************************************************************************
# Source:  Can you see who views your Instagram videos ?
# Target:  On Instagram can you now see how many times someone has watched your video ?
# Input:  Can you see who views your Instagram videos ?
# ********************************************************************************
# Source:  How many rows are there in excel sheet ?
# Target:  How many rows is there excel sheet ?
# Input:  How many rows are there in excel sheet ?
# ********************************************************************************
# Source:  How can WE TOGETHER Make the World a Better Place ?
# Target:  How can I make this world a better place ?
# Input:  How can WE TOGETHER Make the World a Better Place ?
# ********************************************************************************
# Source:  Is there any relation between dreams and reality ?
# Target:  Why do we dream ? What is a relation between dreams and reality ?
# Input:  Is there any relation between dreams and reality ?
# ********************************************************************************
# Source:  How does one not get bored in class ?
# Target:  What should I do when I am bored in class ?
# Input:  How does one not get bored in class ?
# ********************************************************************************
# Source:  I think my dad may be having an affair with another woman . What should I do ?
# Target:  My dad is having an affair . What should I do ?
# Input:  I think my dad may be having an affair with another woman . What should I do ?
# ********************************************************************************
# Source:  What is the oldest religion ?
# Target:  How old is the oldest religion ?
# Input:  What is the oldest religion ?
# ********************************************************************************
# Source:  How can we create backlinks to our website ?
# Target:  How I create backlinks for my website ?
# Input:  How can we create backlinks to our website ?
# ********************************************************************************
# Source:  How many times does the hands of the clock overlap in a day ?
# Target:  How many times do the hour and minute hands of a clock overlap in a hour period ?
# Input:  How many times does the hands of the clock overlap in a day ?
# ********************************************************************************
# Source:  What should I do to know if my girlfriend still loves me ?
# Target:  How do I know if my girlfriend still loves me ?
# Input:  What should I do to know if my girlfriend still loves me ?
# ********************************************************************************
# Source:  How do I see who viewed any video on instagram ?
# Target:  How can I see who viewed my video on Instagram but didn t like my video ?
# Input:  How do I see who viewed any video on instagram ?
# ********************************************************************************
# Source:  What does Quora use to automatically update a question s view count ?
# Target:  How does the Quora view counting system work ?
# Input:  What does Quora use to automatically update a question s view count ?
# ********************************************************************************
# Source:  How exactly is the President of the United States elected ?
# Target:  How is the U .S . President elected ?
# Input:  How exactly is the President of the United States elected ?
# ********************************************************************************
# Source:  Where or what is the strangest place you have ever had sex ?
# Target:  What is the craziest place where you have had sex ?
# Input:  Where or what is the strangest place you have ever had sex ?
# ********************************************************************************
# Source:  Why do some people and kids believe in Santa Claus Tooth Fairy and the Easter Bunny ? Should the kids be taught to believe in these fantasy characters ?
# Target:  Why do people lie to children about the Easter bunny Santa Claus and the tooth fairy ?
# Input:  Why do some people and kids believe in Santa Claus Tooth Fairy and the Easter Bunny ? Should the kids be taught to believe in these fantasy characters ?
# ********************************************************************************
# Source:  Why is Goldilocks guilty in Goldilocks And The Three Bears ?
# Target:  Why is Goldilocks guilty in the book Goldilocks and The Three Bears ?
# Input:  Why is Goldilocks guilty in Goldilocks And The Three Bears ?
# ********************************************************************************
# Source:  How can you rapidly lose weight in days ?
# Target:  How can I lose weight quickly ? Need serious help .
# Input:  How can you rapidly lose weight in days ?
# ********************************************************************************
# Source:  How do you say Happy Birthday in German ?
# Target:  How do you say happy birthday in German ? What is the correct pronunciation ?
# Input:  How do you say Happy Birthday in German ?
# ********************************************************************************
# Source:  How can I earn money through Quora ?
# Target:  How can we earn from Quora ?
# Input:  How can I earn money through Quora ?
# ********************************************************************************
# Source:  What are the major advantages disadvantages of using the magento platform ?
# Target:  Magento What are the major advantages disadvantages of using the magento platform ?
# Input:  What are the major advantages disadvantages of using the magento platform ?
# ********************************************************************************
# Source:  How do I get more traffic on my website ?
# Target:  How do I get more traffic to my site ?
# Input:  How do I get more traffic on my website ?
# ********************************************************************************
# Source:  What are some ways of converting mg to ml ?
# Target:  How can I convert mg to ml ?
# Input:  What are some ways of converting mg to ml ?
# ********************************************************************************
# Source:  How did Trump win America s vote ?
# Target:  How did Donald Trump win despite projections that he would fail ?
# Input:  How did Trump win America s vote ?
# ********************************************************************************
# Source:  How will abolishing rs . and rs . notes reduce corruption and identifying black money ?
# Target:  How will the India demonetization of and rupees notes will reduce black money ?
# Input:  How will abolishing rs . and rs . notes reduce corruption and identifying black money ?
# ********************************************************************************
# Source:  Is it healthy to eat egg whites every day ?
# Target:  Is it healthy to eat bread every day ?
# Input:  Is it healthy to eat egg whites every day ?
# ********************************************************************************
# Source:  What is the most important decision you have made in your life ?
# Target:  What is your most important decision that has made a significant impact on your quality of life today ?
# Input:  What is the most important decision you have made in your life ?
# ********************************************************************************
# Source:  Who all are the seven kingdoms ?
# Target:  What are the seven kingdoms ? Who rules them ? Is there a chance that they will be reunited at the end of the book series ?
# Input:  Who all are the seven kingdoms ?
# ********************************************************************************
# Source:  How do I search job while working ?
# Target:  How do you search for a job when you are currently working ?
# Input:  How do I search job while working ?
# ********************************************************************************
# Source:  What is the First Amendment ?
# Target:  What is the First Amendment s purpose ?
# Input:  What is the First Amendment ?
# ********************************************************************************
# Source:  How long does it take for a patent to be approved after submission ?
# Target:  How long does it take to approve a patent ?
# Input:  How long does it take for a patent to be approved after submission ?
# ********************************************************************************
# Source:  How can discontinuing and rupee will help to control black money ?
# Target:  Would banning notes of denominations and help to curb the black money in system ?
# Input:  How can discontinuing and rupee will help to control black money ?
# ********************************************************************************
# Source:  What are your inspirations to write ?
# Target:  What are your inspirations when you are writing ?
# Input:  What are your inspirations to write ?
# ********************************************************************************
# Source:  How can I prove that every even number is a sum of two prime numbers ?
# Target:  Is it possible to prove that all even numbers can be written as the sum of two primes ? If so how is it proved ?
# Input:  How can I prove that every even number is a sum of two prime numbers ?
# ********************************************************************************
# Source:  How does fuel system works ?
# Target:  How does the complete fuel system works ?
# Input:  How does fuel system works ?
# ********************************************************************************
# Source:  How do I see who viewed my instagram videos ?
# Target:  How can I see who viewed my video on Instagram but didn t like my video ?
# Input:  How do I see who viewed my instagram videos ?
# ********************************************************************************
# Source:  What is ultimate purpose of life ?
# Target:  What s the purpose of life ? What is life actually about ?
# Input:  What is ultimate purpose of life ?
# ********************************************************************************
# Source:  What do you do when you feel like life is meaningless ?
# Target:  What do you do when you feel like life is pointless ?
# Input:  What do you do when you feel like life is meaningless ?
# ********************************************************************************
# Source:  How can I be more confident for a PhD interview ?
# Target:  How can I be more confident in a PhD interview ?
# Input:  How can I be more confident for a PhD interview ?
# ********************************************************************************
# Source:  What is a good business field to get into these days ?
# Target:  What is the best business to start these days ?
# Input:  What is a good business field to get into these days ?
# ********************************************************************************
# Source:  What opportunities exist after completing a B .Tech in mechanical engineering ?
# Target:  What are the career opportunities in companies after an M .Tech in aerospace engineering with a B .Tech in mechanical engineering ?
# Input:  What opportunities exist after completing a B .Tech in mechanical engineering ?
# ********************************************************************************
# Source:  What exactly is Rothschild Conspiracy ?
# Target:  What is the whole theory behind the Rothschild Illuminati conspiracy ?
# Input:  What exactly is Rothschild Conspiracy ?
# ********************************************************************************
# Source:  Why do people always stare at me ? People constantly ask me if I m adopted or if my dad is my real dad . People always say my dads the milk man .
# Target:  Why do people say my dads the milk man ?
# Input:  Why do people always stare at me ? People constantly ask me if I m adopted or if my dad is my real dad . People always say my dads the milk man .
# ********************************************************************************
# Source:  How can I stop myself from being affected by what other people think about me ?
# Target:  Should I care what people think about me ? Most have a positive impression of me but should I care to keep it that way ?
# Input:  How can I stop myself from being affected by what other people think about me ?
# ********************************************************************************
# Source:  Can you offer me any advice on how to lose weight ?
# Target:  How do I actually lose weight ?
# Input:  Can you offer me any advice on how to lose weight ?
# ********************************************************************************
# Source:  What should be the first programming language I learn if I want to become a game developer ?
# Target:  What is the best programming language to learn in order to rapidly develop video games ?
# Input:  What should be the first programming language I learn if I want to become a game developer ?
# ********************************************************************************
# Source:  I m . How can I make money online ?
# Target:  How can I make money online consistently ?
# Input:  I m . How can I make money online ?
# ********************************************************************************
# Source:  Why is Facebook still so popular ?
# Target:  Why is Facebook so popular ? Is it profitable to users ?
# Input:  Why is Facebook still so popular ?
# ********************************************************************************
# Source:  How will the scrapping of Rs and Rs notes help in reducing black money and corruption ?
# Target:  How is discontinuing and rupee note going to put a hold on black money in India ?
# Input:  How will the scrapping of Rs and Rs notes help in reducing black money and corruption ?
# ********************************************************************************
# Source:  What can Google Home do that Amazon Echo cannot ?
# Target:  In what ways is Google Home Assistant smarter than Amazon Echo Alexa ?
# Input:  What can Google Home do that Amazon Echo cannot ?
# ********************************************************************************
# ...
# Target:  Seriously what are the chances that there is not another form of intelligent life somewhere in the universe ?
# Input:  Will we ever discover or be discovered by an intelligent life form from another planet ?
# ********************************************************************************
# Source:  Why does the Samsung Galaxy Note explode ?
# Target:  Why does the Galaxy note explode ?
# Input:  Why does the Samsung Galaxy Note explode ?
# ********************************************************************************
# Source:  Can you offer me any advice on how to lose weight ?
# Target:  How do i lose weight ?
# Input:  Can you offer me any advice on how to lose weight ?
# ********************************************************************************
# Source:  What does sign language involve ? How can you learn sign language ?
# Target:  How can I learn a signed language ?
# Input:  What does sign language involve ? How can you learn sign language ?
# ********************************************************************************
# Source:  Where is the cheapest country to visit ?
# Target:  Where is the cheapest and nice country to visit ?
# Input:  Where is the cheapest country to visit ?
# ********************************************************************************
# Source:  Where can I download dragon ball episodes ?
# Target:  Where can I download episodes of dragon ball ?
# Input:  Where can I download dragon ball episodes ?
# ********************************************************************************
# Source:  How do I write my first research paper ?
# Target:  How can I start writing a research paper ?
# Input:  How do I write my first research paper ?
# ********************************************************************************
# Source:  What is the point of hacking NASA server ?
# Target:  What is the point of hacking NASA servers ?
# Input:  What is the point of hacking NASA server ?
# ********************************************************************************
# Source:  If universe is expanding without a limit and dark and vacuum energy are created as it expands ?
# Target:  Is vacuum energy infinite ? If it is how and why ? Is it dark energy ?
# Input:  If universe is expanding without a limit and dark and vacuum energy are created as it expands ?
# ********************************************************************************
# Source:  What would happen to an astronaut who took their helmet off in space for a few seconds ?
# Target:  What happen when helmet of the astronaut are opened in the space ?
# Input:  What would happen to an astronaut who took their helmet off in space for a few seconds ?
# ********************************************************************************
# Source:  Why do so many people ask questions on Quora .com when they could easily find the answers themselves online ?
# Target:  Why do people ask questions on Quora that are easily answerable via a quick internet search ?
# Input:  Why do so many people ask questions on Quora .com when they could easily find the answers themselves online ?
# ********************************************************************************
# Source:  What are your regular simple habits that has lead to your achievement so far ?
# Target:  What are your regular simple habits that has lead to your achievements so far ?
# Input:  What are your regular simple habits that has lead to your achievement so far ?
# ********************************************************************************
# Source:  After our st date that lasted only mins for dinner he tried to kiss me and texted saying he had a lot of fun . Is he interested or being nice ?
# Target:  Why hasn t he contacted me at all for two days after our date where he tried to kiss me and texted that nite that he had a lot of fun ?
# Input:  After our st date that lasted only mins for dinner he tried to kiss me and texted saying he had a lot of fun . Is he interested or being nice ?
# ********************************************************************************
# Source:  How can I get myself to stop slouching ?
# Target:  How can I stop slouching ?
# Input:  How can I get myself to stop slouching ?
# ********************************************************************************
# Source:  How will the demonetization of and rupee notes affect the value of INR against USD ?
# Target:  Will rupee value rise after banning and notes ?
# Input:  How will the demonetization of and rupee notes affect the value of INR against USD ?
# ********************************************************************************
# Source:  How do you train a Black Lab Pitbull Mix ?
# Target:  What is the best way to train my Black Lab Pitbull mix puppy ?
# Input:  How do you train a Black Lab Pitbull Mix ?
# ********************************************************************************
# Source:  How can I get a list of my Gmail accounts ?
# Target:  Is there any way I can get a list of all of my Gmail accounts ?
# Input:  How can I get a list of my Gmail accounts ?
# ********************************************************************************
# Source:  Why does Quora limit my question details to characters ?
# Target:  Why does Quora have a character limit in Question Details ?
# Input:  Why does Quora limit my question details to characters ?
# ********************************************************************************
# Source:  How did the Hillsborough disaster happen ?
# Target:  What happened at the Hillsborough disaster ?
# Input:  How did the Hillsborough disaster happen ?
# ********************************************************************************
# Source:  How can I manage to live in Chennai with k salary per month ?
# Target:  How can one manages to live in Chennai with a salary of Rs . ?
# Input:  How can I manage to live in Chennai with k salary per month ?
# ********************************************************************************
# Source:  How can I recover my Facebook account ?
# Target:  How can I recover Facebook account ?
# Input:  How can I recover my Facebook account ?
# ********************************************************************************
# Source:  What are the best earphones under Rs ?
# Target:  Which is the best earphone under rs ? Is soundmagic ES on top of that list ?
# Input:  What are the best earphones under Rs ?
# ********************************************************************************
# Source:  Why does planets move in elliptical orbit why not in circular orbits ?
# Target:  Why the path of planets is elliptical not circular ?
# Input:  Why does planets move in elliptical orbit why not in circular orbits ?
# ********************************************************************************
# Source:  Do you make New Years resolutions ?
# Target:  Do you believe in having New Year s Resolutions ?
# Input:  Do you make New Years resolutions ?
# ********************************************************************************
# Source:  Issue of new provinces in pakistan ?
# Target:  What are the issues associated with creating new provinces in Pakistan ?
# Input:  Issue of new provinces in pakistan ?
# ********************************************************************************
# Source:  What is the history of Quora ? How was it started ?
# Target:  How many years old is Quora ? How was it started ? Which need was trying it to cover ?
# Input:  What is the history of Quora ? How was it started ?
# ********************************************************************************
# Source:  What would be the effect on India if Donald Trump really becomes the president of US ?
# Target:  How is US president Donald Trump important for India ?
# Input:  What would be the effect on India if Donald Trump really becomes the president of US ?
# ********************************************************************************
# Source:  My weight is kg and height is feet . Which Royal Enfield bullet bike should I drive ?
# Target:  My height is which royal Enfield would you prefer ?
# Input:  My weight is kg and height is feet . Which Royal Enfield bullet bike should I drive ?
# ********************************************************************************
# Source:  Which programming language is easy to learn and understand ?
# Target:  Which programming language is easy to understand ?
# Input:  Which programming language is easy to learn and understand ?
# ********************************************************************************
# Source:  What are some good examples of what goes around comes around ?
# Target:  What is the best example of the phrase What goes around comes around ?
# Input:  What are some good examples of what goes around comes around ?
# ********************************************************************************
# Source:  Can I use jio sim in infocus m Mobile supported ?
# Target:  Can I use Reliance Jio sim in a infocus m Mobile ?
# Input:  Can I use jio sim in infocus m Mobile supported ?
# ********************************************************************************
# Source:  What is the meaning of cease to exist ?
# Target:  What is the meaning of the phrase cease to exist ?
# Input:  What is the meaning of cease to exist ?
# ********************************************************************************
# Source:  How can you make a homemade fleshlight ?
# Target:  What are some ways to make a homemade fleshlight ?
# Input:  How can you make a homemade fleshlight ?
# ********************************************************************************
# Source:  Why is the th amendment important ?
# Target:  Why was the th amendment proposed ? And what are the most important provisions ?
# Input:  Why is the th amendment important ?
# ********************************************************************************
# Source:  When will Google Translate or generally AI translators become good ?
# Target:  Will Google Translate ever become a good translation provider ?
# Input:  When will Google Translate or generally AI translators become good ?
# ********************************************************************************
# Source:  What is the importance of the security code on a Visa credit card ?
# Target:  What is a security code on a Visa Card used for ?
# Input:  What is the importance of the security code on a Visa credit card ?
# ********************************************************************************
# Source:  How did the universe look like before the Big Bang ?
# Target:  Did the void exist before the Big Bang ?
# Input:  How did the universe look like before the Big Bang ?
# ********************************************************************************
# Source:  What are the various ways through which one can earn money online ?
# Target:  What is best way to make money online ?
# Input:  What are the various ways through which one can earn money online ?
# ********************************************************************************
# Source:  How do know when you re in love ?
# Target:  How do you know you re in love again ?
# Input:  How do know when you re in love ?
# ********************************************************************************
# Source:  A famous saying is magnets how do they work . How do magnets work ?
# Target:  How do magnets work ?
# Input:  A famous saying is magnets how do they work . How do magnets work ?
# ********************************************************************************
# Source:  How do I install hadoop on my laptop ?
# Target:  How do i setup hadoop environment for my laptop ?
# Input:  How do I install hadoop on my laptop ?
# ********************************************************************************
# Source:  Which answer got the most upvotes on Quora ?
# Target:  What is the most upvoted answer of all time on Quora ?
# Input:  Which answer got the most upvotes on Quora ?
# ********************************************************************************
# Source:  Is there something that travels faster than light ?
# Target:  Is there something that can travel faster than light ?
# Input:  Is there something that travels faster than light ?
# ********************************************************************************
# Source:  What was the greatest day in you life ?
# Target:  What was the best day of your life ?
# Input:  What was the greatest day in you life ?
# ********************************************************************************
# Source:  Why did RBI issue new rupees note instead of new rupees note ?
# Target:  Why is rupee note introduced and the rupee note is scraped ? Why can t note also be changed to new ones like the ?
# Input:  Why did RBI issue new rupees note instead of new rupees note ?
# ********************************************************************************
# Source:  What is your favorite anime and why ?
# Target:  What are your favorite animes ?
# Input:  What is your favorite anime and why ?
# ********************************************************************************
# Source:  What workout clothes did guys wear in the summer back in the year ?
# Target:  What is the best outfit a guy would wear for working out in the summer like it s the year ?
# Input:  What workout clothes did guys wear in the summer back in the year ?
# ********************************************************************************
# Source:  How can I meet Modi ?
# Target:  How can we meet to PM Narendra Modi ?
# Input:  How can I meet Modi ?
# ********************************************************************************
# Source:  What forces are currently fighting in Syria ?
# Target:  Which are the forces and rebels in Syria ?
# Input:  What forces are currently fighting in Syria ?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-6cee9e7215b4> in <module>
#       2 idx2word = dataset.idx2word
#       3 with open(output_file, 'w') as f:
# ----> 4     for i, (seq1, seq2) in enumerate(tqdm(data_loader)):
#       5         input_seq = seq1.to(device)
#       6         trg_seq = seq2[0].tolist()
#
# ~/miniconda3/envs/my_paraphrase_env/lib/python3.7/site-packages/tqdm/std.py in __iter__(self)
#    1169
#    1170         try:
# -> 1171             for obj in iterable:
#    1172                 yield obj
#    1173                 # Update and possibly print the progressbar.
#
# ~/miniconda3/envs/my_paraphrase_env/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/miniconda3/envs/my_paraphrase_env/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#     477             data = _utils.pin_memory.pin_memory(data)
#
# ~/miniconda3/envs/my_paraphrase_env/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
# ---> 47         return self.collate_fn(data)
#
# <ipython-input-5-fbb98c13bda8> in create_mini_batch(samples)
#       5     # zero pad
#       6     seq1_tensors = pad_sequence(seq1_tensors,
# ----> 7                                   batch_first=True)
#       8
#       9     seq2_tensors = pad_sequence(seq2_tensors,
#
# ~/miniconda3/envs/my_paraphrase_env/lib/python3.7/site-packages/torch/nn/utils/rnn.py in pad_sequence(sequences, batch_first, padding_value)
#     364         out_dims = (max_len, len(sequences)) + trailing_dims
#     365
# --> 366     out_tensor = sequences[0].new_full(out_dims, padding_value)
#     367     for i, tensor in enumerate(sequences):
#     368         length = tensor.size(0)
#
# KeyboardInterrupt:

# %%
# Out:
# [28, 154, 76, 1703, 221, 365, 38, 1391, 1265, 22, 30, 2]
