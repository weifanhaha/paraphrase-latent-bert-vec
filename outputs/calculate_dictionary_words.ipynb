# %%
import yaml
import re
import glob
import os
import numpy as np

# %%
config_path = '../configs/dpng_transformer.yaml'

# for training size
with open(config_path) as f:
    config = yaml.load(f, Loader=yaml.FullLoader)
    print(config)

train_size = config['train_size']
val_size = config['val_size']
test_size = config['test_size']
# Out:
# {'save_model_path': '../models/DNPG_base_transformer.pth', 'log_file': '../logs/DNPG_base_transformer_training.txt', 'test_output_file': '../outputs/test_DNPG_base_transformer.txt', 'val_output_file': '../outputs/val_DNPG_base_transformer.txt', 'dataset': 'quora_dataset', 'num_epochs': 50, 'batch_size': 128, 'd_model': 450, 'd_inner_hid': 512, 'd_k': 50, 'd_v': 50, 'n_head': 9, 'n_layers': 3, 'n_warmup_steps': 12000, 'dropout': 0.1, 'embs_share_weight': True, 'proj_share_weight': True, 'label_smoothing': False, 'train_size': 100000, 'val_size': 4000, 'test_size': 20000, 'is_bow': False, 'lr': '1e-3'}

# %%
seeds = [0, 777, 33333]
ref_path = '../data/quora_train.txt'

# %%
seed_dir_dic = {}
seed_root = './fixseed'
for seed in seeds:
    seed_dir = 'seed{}'.format(seed)
    seed_dir = os.path.join(seed_root, seed_dir)
    txt_paths = []
    txt_paths.append(os.path.join(seed_dir, 'test_DNPG_base_transformer.txt'))
    txt_paths.append(os.path.join(seed_dir, 'transformer_key_enc_bert_val_attention_alpha0.5.txt'))
    
    seed_dir_dic[seed] = txt_paths

# %%
def build_ref(ref_path):
    # read source sentence and ref sentence
    reference_text = open(ref_path, 'r').readlines()
    np.random.shuffle(reference_text)
    reference_text = reference_text[train_size+val_size:train_size+val_size+test_size]

    source_text = [text.strip().split('\t')[0] for text in reference_text]
    reference_text = [text.strip().split('\t')[1] for text in reference_text]
    
    # normalize reference corpus , eg: seperate question mark , remove '(' ,')' etc
    source_text = [re.sub(r"([.!?])", r" \1", seq) for seq in source_text]
    source_text = [text.lower() for text in source_text]

    reference_text = [re.sub(r"([.!?])", r" \1", seq) for seq in reference_text]
    reference_text = [text.lower() for text in reference_text]
    return source_text, reference_text

# %%
def build_dic(texts):
    dic = {}
    for text in texts:
#         text = re.sub(r"([.!?])", r" \1", text)
        text = text.lower()
        words = text.split()
        for word in words:
            if word not in dic:
                dic[word] = 1
            else:
                dic[word] = dic[word] + 1
    
    return dic

# %%
st, rt = build_ref(ref_path)
print(st[0], rt[0])

sdic = build_dic(st)
rdic = build_dic(rt)

print(len(sdic), len(rdic))
# Out:
# what is the best way to become rich ? let's cut out the crap . how can somebody really become rich ?
# 13419 13545

# %%
seed_dir_dic
# Out:
# {0: ['./fixseed/seed0/test_DNPG_base_transformer.txt',
#   './fixseed/seed0/transformer_key_enc_bert_val_attention_alpha0.5.txt'],
#  777: ['./fixseed/seed777/test_DNPG_base_transformer.txt',
#   './fixseed/seed777/transformer_key_enc_bert_val_attention_alpha0.5.txt'],
#  33333: ['./fixseed/seed33333/test_DNPG_base_transformer.txt',
#   './fixseed/seed33333/transformer_key_enc_bert_val_attention_alpha0.5.txt']}

# %%
for seed in seeds:
    print("### Evaluating seed {} ###".format(seed))
    # fixseed
    # get reference text
    np.random.seed(seed)
    reference_text, reference_corpus = read_ref(ref_path)
    print(reference_corpus[0])

    # for every file in seeds
    files = seed_dir_dic[seed]
    # get predict text
    for file in files:
        print("Calculating file: ", file)
        prediction_text = open(file, 'r').readlines()
        prediction_text = [text.replace('Predict: ', '').strip().lower() for text in prediction_text if 'Predict: ' in text]
        pdic = build_dic(prediction_text)
        print("number of words in dictionary: ", len(pdic))
        
        print("==============================")
# Out:
# ### Evaluating seed 0 ###
# [['what', 'are', 'the', 'benefits', 'of', 'using', 'digital', 'signage', 'for', 'your', 'business', '?']]
# Calculating file:  ./fixseed/seed0/test_DNPG_base_transformer.txt
# number of words in dictionary:  6268
# ==============================
# Calculating file:  ./fixseed/seed0/transformer_key_enc_bert_val_attention_alpha0.5.txt
# number of words in dictionary:  8513
# ==============================
# ### Evaluating seed 777 ###
# [['what', 'was', 'the', 'first', 'thing', 'you', 'did', 'when', 'you', 'found', 'out', 'donald', 'trump', 'won', 'the', 'election', '?']]
# Calculating file:  ./fixseed/seed777/test_DNPG_base_transformer.txt
# number of words in dictionary:  6111
# ==============================
# Calculating file:  ./fixseed/seed777/transformer_key_enc_bert_val_attention_alpha0.5.txt
# number of words in dictionary:  8691
# ==============================
# ### Evaluating seed 33333 ###
# [['what', 'is', 'the', 'assumed', 'walking', 'speed', 'in', 'google', "maps's", 'time', 'estimates', '?']]
# Calculating file:  ./fixseed/seed33333/test_DNPG_base_transformer.txt
# number of words in dictionary:  6283
# ==============================
# Calculating file:  ./fixseed/seed33333/transformer_key_enc_bert_val_attention_alpha0.5.txt
# number of words in dictionary:  8430
# ==============================

# %%
file = './fixseed/seed33333/test_DNPG_base_transformer.txt'
prediction_text = open(file, 'r').readlines()
prediction_text = [text.replace('Predict: ', '').strip().lower() for text in prediction_text if 'Predict: ' in text]
bdic = build_dic(prediction_text)

# %%
source_ws = set(sdic.keys())
ref_ws = set(rdic.keys())
pred_ws = set(pdic.keys())
base_ws = set(bdic.keys())

# %%
print(len(base_ws - pred_ws))
print(len(pred_ws - base_ws))
# Out:
# 773
# 2920

# %%
print(pred_ws - base_ws)
# Out:
# {'tries', 'sharps', 'carta', 'censor', 'gma', '51', 'm606x', 'jammer', 'sfc', 'gulf', '45k', 'jew', 'ferulos', 'frame', 'visitors', 'commuative', 'squats', 'epigenetic', 'bet', 'impairment', 'perceptron', '40000', 'girth', 'melo', 'braking', 'ass', 'tutorial', 'enlightr', 'earthing', 'fgfa', 'timeings', 'astrophysics', 'scratches', 'vjp', 'taxa', '2014', 'sur19', 'singleton', 'f1', 'inmortal', 'du', 'akbar', 'programing', 'rubibi', 'langely', 'accentedstststst', 'si', '₹1000', 'goldman', 'elenoge', 'nukeed', 'omnintary', 'grudges', 'manrogate', 'trivanrgy', 'trafficda', 'kuan', 'spoke', 'mountaineering', 'bre', 'minora', 'slavs', 'redheads', 'colonize', 'geope', 'cuthvicing', 'landry', 'bandung', 'crest3', 'rim', 'arbitrage', 'kakatiya', 'fears', 'kitten', 'z3', 'goviem', 'flooring', 'biroma', 'trustus', 'bantu', '400', 'ganege', 'documentary', 'reboot', 'homeschooler', 'indo', 'temperament', 'piercing', 'hpc', 'rudisha', 'serveries', 'explained', 'alpha', 'costsochondritis', 'componentsing', 'hotspot', 'interfacec', 'prisma', 'ga', 'ramakrishna', 'rainbows', 'prefuies', 'endothermic', 'kifss', 'lockers', 'gl', 'relief', 'axiomatic', 'aigr', 'blockers', 'pluto', 'lice', 'mine', 'vulture', 'footballiginals', 'csv', '96', 'ed', 'safetys', 'footprint', 'peeling', 'integral', 'wavesfunction', 'chessboard', '60k', 'deductibles', 'sec', 'mus', 'macromolecules', 'entreprenrgy', 'ginger', 'reagent', 'closer', 'matly', 'prespective', 'dangerously', 'popup', 'obsessive', 'vapte', 'pratibha', 'offended', 'lay', 'lights', 'singularity', 'hindutva', 'scorpio', 'brit', 'ragging', 'bedline', 'lime', 'goiy', 'lewissco', 'fakeax', 'admissions', 'lindaeel', 'wallace', 'sts', 'coutry', 'makers', 'simp', 'unudity', 'hypertension', 'contrade', 'fourier', 'hashtag', 'taxes', 'fought', 'safaricom', 'mission', 'lin', '7000', 'pint', 'alibaba', 'sushi', 'mportant', '2016', 'idb', 'physicist', 'hadamard', 'smartphones', 'sledging', 'resonance', 'appraise', 'gole', 'marine', 'nitjjos', 'felony', 'ahmedr', 'maglev', 'punjabi', 'judo', 'mandi', 'airrrent', 'revolve', 'dragonworld', 'mahabharat', 'youmdb', 'moana', 'bultures', 'buttle', 'reicellular', 'prep', 'marxism', 'nakr', 'pinkmy', 'na', '6s', 'salicylic', 'devastation', 'imminent', 'rra', 'oranges', 'spotdes', 'prejaculation', 'fiy', 'substitutewatermoioca', 'mlm', 'macronutphics', 'cheated', 'cramps', 'homophones', '29', 'ssis', 'whinn', 'cos', 'starbucks', 'substantive', 'mamsung', 'bernourogate', 'manit', 'toughness', 'complimented', 'borrowing', 'anonymouss', 'misinterpreted', 'maggot', 'coefficient', 'lcd', 'bombay0', '37', 'unsaturated', '88', 'deck', 'unquepedpedmy', 'suspensioner', 'lindacoma', 'shivaay', 'calorific', '30', 'powermates', 'xenophobia', 'darth', 'gamers', 'fries', 'sprayed', 'cern', 'koreante', 'membership', 'creat', '10s', 'wo', 'urinating', 'invicta', 'dagekart', '2100', 'bhag', 'pichai', 'hash', 'medics', 'aflame', 'octiah', 'septemember', 'shearx', 'sublim', 'nosy', 'contraple', 'polygon', 'benjen', 'reversible', 'ren', 'boycotting', 'ppcode', 'grag', 'herbbir', '70d', '45', 'oshawa', 'zeta', 'flatr', 'levering', 'millionare', 'clar', 'filmmaker', '_', 'piggler', 'rheostatic', 'asympttes', 'ide', 'rrasometer', 'etymology', 'vits', 'colleterol', 'linkrs', 'fossil', 'gruing', '49er', '150', 'airline', 'enlist', 'koopsta', 'puja', '60', 'tcp', 'peeing', 'pushpak', 'pathwaysmials', 'refrigerate', 'elders', 'coning', 'vulturem', 'polymor', 'netgear', 'prozac', 'preterism', 'bicep', 'deci', 'yu', 'someonessapp', 'saiyan', 'completes', 'nutritional', 'spacejos', 'redplus', 'objected', 'auto', 'en', 'summations', 'gakeing', 'razerde', 'antihistamine', 'refrigerated', 'veget', 'heredity', 'arrest', 'bd', 'fightss', 'autocad', 'subscribe', 'stuffy', 'rappers', 'mermaid', 'nakey', 'claculate', 'stinks', 'nonpolar', '1960', 'attached', 'allocate', 'commurd', 'slimming', 'starve', 'scare', 'ngpur', 'impulsive', '23', '9th', 'extreme', 'emigrate', 'stockings', 'cutter', 'pot', 'yawn', ' ...

# %%
print(len(pred_ws - source_ws))
print(len(source_ws - pred_ws))
print(len(pred_ws-ref_ws))
# Out:
# 2539
# 7528
# 2459

# %%
pred_ws - ref_ws
# Out:
# {'bubble',
#  'sharps',
#  'lochte',
#  'gma',
#  'censor',
#  'm606x',
#  'sfc',
#  'subsurface',
#  'jew',
#  'dth',
#  'selfless',
#  'ferulos',
#  'commuative',
#  'squats',
#  'impairment',
#  'perceptron',
#  'proteins',
#  'melo',
#  'klout',
#  'braking',
#  'enlightr',
#  'norse',
#  'icelandic',
#  'fgfa',
#  'timeings',
#  'lewis',
#  'productivity',
#  'spleen',
#  'vjp',
#  'taxa',
#  'sur19',
#  'singleton',
#  'programing',
#  'rubibi',
#  'langely',
#  'accentedstststst',
#  'mandarin',
#  'si',
#  'elenoge',
#  'nukeed',
#  'omnintary',
#  'grudges',
#  'uncertainty',
#  'manrogate',
#  'trivanrgy',
#  'trafficda',
#  'kuan',
#  'bre',
#  'minora',
#  'redheads',
#  'expressions',
#  'cuthvicing',
#  'geope',
#  'landry',
#  'hop',
#  'bandung',
#  'crest3',
#  'rim',
#  'kakatiya',
#  'pnb',
#  'z3',
#  'sized',
#  'goviem',
#  'flooring',
#  'biroma',
#  'trustus',
#  'bantu',
#  '400',
#  'ganege',
#  'documentary',
#  'tune',
#  'reboot',
#  'homeschooler',
#  'indo',
#  'hpc',
#  'piercing',
#  'serveries',
#  'alpha',
#  'wizards',
#  'costsochondritis',
#  'componentsing',
#  'thc',
#  'mammals',
#  'construct',
#  'hotspot',
#  'interfacec',
#  'prisma',
#  'ga',
#  'demographic',
#  'ramakrishna',
#  'malt',
#  'prefuies',
#  'endothermic',
#  'kifss',
#  'lockers',
#  'church',
#  'gl',
#  'axiomatic',
#  'satisfaction',
#  'aigr',
#  'blockers',
#  'alike',
#  'pluto',
#  'lice',
#  'vulture',
#  'footballiginals',
#  'csv',
#  'ed',
#  'safetys',
#  'peeling',
#  'integral',
#  'dancing',
#  'plug',
#  'wavesfunction',
#  'wormholes',
#  'chessboard',
#  'deductibles',
#  'sec',
#  'ee',
#  'mus',
#  'macromolecules',
#  'entreprenrgy',
#  'ginger',
#  'chin',
#  'tom',
#  'prespective',
#  'matly',
#  'dangerously',
#  'popup',
#  'vapte',
#  'pratibha',
#  'singularity',
#  'hindutva',
#  'scorpio',
#  'brit',
#  'bedline',
#  'lime',
#  'goiy',
#  'lewissco',
#  'fakeax',
#  'lindaeel',
#  'kelpie',
#  'sts',
#  'coutry',
#  'unudity',
#  'simp',
#  'sleeve',
#  'hypertension',
#  'contrade',
#  'fourier',
#  'hashtag',
#  'lin',
#  'pint',
#  'sushi',
#  'mportant',
#  'idb',
#  'unsc',
#  'hadamard',
#  'resonance',
#  'gole',
#  'nitjjos',
#  'alzheimer',
#  'ahmedr',
#  'maglev',
#  'punjabi',
#  'judo',
#  'mandi',
#  'airrrent',
#  'chsl',
#  'dragonworld',
#  'mahabharat',
#  'youmdb',
#  'moana',
#  'bultures',
#  'buttle',
#  'reicellular',
#  'marxism',
#  'nakr',
#  'pinkmy',
#  'na',
#  'devastation',
#  'lick',
#  'airbnb',
#  'rra',
#  'spotdes',
#  'prejaculation',
#  'fiy',
#  'substitutewatermoioca',
#  'macronutphics',
#  'homophones',
#  '29',
#  'ssis',
#  'whinn',
#  'cos',
#  'roof',
#  'mamsung',
#  'nofap',
#  'souls',
#  'bernourogate',
#  'manit',
#  'toughness',
#  'complimented',
#  'borrowing',
#  'anonymouss',
#  'misinterpreted',
#  'maggot',
#  'coefficient',
#  'bombay0',
#  'mildew',
#  'unsaturated',
#  'unquepedpedmy',
#  'suspensioner',
#  'lindacoma',
#  'hurricane',
#  'calorific',
#  'spider',
#  'powermates',
#  'xenophobia',
#  'gamers',
#  'sprayed',
#  'koreante',
#  'membership',
#  '10s',
#  'wo',
#  'urinating',
#  'invicta',
#  'dagekart',
#  'bhag',
#  'afghanistan',
#  'medics',
#  'aflame',
#  'octiah',
#  'septemember',
#  'shearx',
#  'sublim',
#  'contraple',
#  'polygon',
#  'benjen',
#  'reversible',
#  'refraction',
#  'ren',
#  'boycotting',
#  'ppcode',
#  'grag',
#  'herbbir',
#  '45',
#  'zeta',
#  'flatr',
#  'levering',
#  'millionare',
#  'clar',
#  'filmmaker',
#  '_',
#  'piggler',
#  'rheostatic',
#  'appointing',
#  'asympttes',
#  'prescription',
#  'rrasometer',
#  'etymology',
#  'vits',
#  'bluetooth',
#  'colleterol',
#  'linkrs',
#  'modem',
#  'gruing',
#  '49er',
#  'verbal',
#  'enlist',
#  'koopsta',
#  'pushpak',
#  'pathwaysmials',
#  'refrigerate',
#  'elders',
#  'coning',
#  'tulips',
#  'vulturem',
#  'polymor',
#  'netgear',
#  'preterism',
#  'eagerly',
#  'deci',
#  'bulb',
#  'yu',
#  'someonessapp',
#  'saiyan',
#  'completes',
#  'spacejos',
#  'redplus',
#  'objected',
#  'en',
#  'summations',
#  'gakeing',
#  'razerde',
#  'antihistamine',
#  'refrigerated',
#  'veget',
#  'heredity',
#  'bd',
#  'fightss',
#  'stuffy',
#  'rappers',
#  'mermaid',
#  'output',
#  'nakey',
#  'cruise',
#  'claculate',
#  'stinks',
#  'nonpolar',
#  'discrimination',
#  'kabali',
#  'absent',
#  'allocate',
#  'commurd',
#  'slimming',
#  'ngpur',
#  'stockings',
#  'cutter',
#  'alarm',
#  '[',
#  'configure',
#  'failualg',
#  'supervisor',
#  'lg',
#  'brains',
#  'witches',
#  'dhanbad',
#  'socialism',
#  'saect',
#  'mcduck',
#  'bengali',
#  'veumractive',
#  'cena',
#  'germanb',
#  '0xfk',
#  'armsfighter',
#  'unbiamicoupn',
#  'aur',
#  'randi',
#  'overdraft',
#  '’',
#  'shri',
#  'viking',
#  'anise',
#  'rummy',
#  'narence',
#  'substandard',
#  'modeist',
#  'descartes',
#  'baroda',
#  'oces',
#  'rto',
#  'antithero',
#  'meturbations',
#  'deprivation',
#  'champagne',
#  'balls',
#  'catcher',
#  'redopsis',
#  'ramgon',
#  'kwayna',
#  'mukesh',
#  'healthier',
#  'acm',
#  'defies',
#  'semiconductors',
#  'hy',
#  'equal',
#  'moderies',
#  'hijab',
#  'reparian',
#  'don',
#  'busy',
#  'mikado',
#  'liners',
#  'bisexuality',
#  'didn',
#  'parliamentus',
#  '9pm',
#  'renican',
#  'diplomat',
#  'bedbugs',
#  'gyroscope',
#  'wn7',
#  'botnet',
#  'ecosport',
#  'kuwait',
#  'pocketrds',
#  'warhol',
#  'rukmini',
#  'muhammed',
#  'infibeam',
#  'ibiza',
#  'unstotype',
#  'conism',
#  'competitivex',
#  'watermelonononon',
#  'lindaed',
#  'volunteer',
#  '*y',
#  'dieached',
#  'kurukshetra',
#  'prechates',
#  'abduction',
#  'iis',
#  'saunas',
#  '49',
#  'probook',
#  'spidercam',
#  '5x10',
#  'brainwood',
#  'astrophysicist',
#  'commercials',
#  'rwo',
#  'hover',
#  'drawner',
#  'refrigerator',
#  'vulturex',
#  '3t',
#  'oscars',
#  'tracked',
#  'tawo',
#  'hula',
#  'nominated',
#  'eyers',
#  '2014at',
#  'ud',
#  'proze',
#  'massage',
#  'reactant',
#  'cafeting',
#  'tetra',
#  'acy',
#  '350k',
#  'serot',
#  'asexuality',
#  'bookinging',
#  'titaium',
#  'compounded',
#  'websitesmap',
#  'pinxecle',
#  'penetrate',
#  'addicting',
#  'pedophile',
#  'halo',
#  'fakely',
#  '504q',
#  'immortals',
#  'sarvepalli',
#  'switchs',
#  'bel',
#  'pgims',
#  'vatsdara',
#  'linkia',
#  'deductible',
#  'nitric',
#  'arya',
#  'fallacies',
#  'violate',
#  'comcrastinament',
#  'manulture',
#  'limitless',
#  'engagement',
#  'ramc',
#  'cwoter',
#  '15u',
#  'iitians',
#  'wifes',
#  'shuttle',
#  'cphp',
#  'batch',
#  'microcontroller',
#  'icicis',
#  '1b',
#  'wealths',
#  'asabi',
#  '250',
#  'converters',
#  'facfiedtation',
#  'capitalization',
#  'hasn',
#  'imax',
#  'cholesterol',
#  'gk',
#  'tweet',
#  'aco',
#  'unsold',
#  'kirini',
#  'ekalavya',
#  'politicality',
#  'bou',
#  'ket',
#  'erup',
#  'udaipur',
#  'fission',
#  'littlefinger',
#  'freelancers',
#  'vinstall',
#  'neut',
#  'nik',
#  'dolphin',
#  'wallwer',
#  'elrablely',
#  'interviewer',
#  'fiters',
#  'aipmt',
#  'analog',
#  'lation',
#  'cfd',
#  'macronutzation',
#  'hoards',
#  'polyneuropathy',
#  'phos',
#  'behampoo',
#  'beliance',
#  'forthcoming',
#  'bronze',
#  'upi',
#  'slept',
#  'snoke',
#  'vggle',
#  'philippinesbul',
#  'geass',
#  'belworth',
#  'marcda',
#  'stephen',
#  'fggle',
#  'ofcker',
#  'outrun',
#  'siri',
#  'tb',
#  'cf',
#  'naturalised',
#  'maju',
#  'coma',
#  'transexual',
#  'aidx',
#  'whis',
#  'weaknesses',
#  'intellipiat',
#  'ribosomes',
#  'dialects',
#  'copying',
#  'streaming',
#  'texting',
#  'promoting',
#  'blackbcc',
#  'manufacture',
#  'scala',
#  'overact',
#  'chihuahua',
#  'freerrentment',
#  'terrors',
#  'ras',
#  'josaa',
#  'cocur',
#  'infjs',
#  'macarons',
#  '1800',
#  'contacting',
#  'myers',
#  'elssi',
#  'lenxapro',
#  'airbnbnb',
#  'dribbble',
#  'involuntarily',
#  'wi',
#  'browse',
#  'licence',
#  'orleans',
#  'idiom',
#  'zronological',
#  'prioritize',
#  'rust',
#  'calorimeter',
#  'emfuialism',
#  'silliest',
#  'romanticle',
#  'earphonejax',
#  'mdma',
#  'gand',
#  'poi',
#  'rcep',
#  'pest',
#  'voteton',
#  'islanding',
#  'deja',
#  'vibples',
#  'subquamatical',
#  'richard',
#  'goliath',
#  'noises',
#  'disciplineron',
#  'amotivate',
#  'viswanathan',
#  'gifting',
#  'handcuepting',
#  'disproportionate',
#  'invisibleer',
#  'bbq',
#  'beijing',
#  'meows',
#  'prepaid',
#  'collapses',
#  'pultureent',
#  'azka',
#  'lysosomes',
#  'itshave',
#  'warp',
#  'scalable',
#  'laveen',
#  'msbooke',
#  'limits',
#  'forwards',
#  'refuine',
#  'noc',
#  'americaa',
#  'pgpm',
#  'videocon',
#  'dehradun',
#  'terro',
#  'remembered',
#  'yfinger',
#  'nightwear',
#  'cpm',
#  'b2',
#  'orange',
#  'tuscalo',
#  'etraterrestrials',
#  'millionline',
#  'testbook',
#  'lumps',
#  'fertility',
#  'silencers',
#  'gausian',
#  'lindacity',
#  'accuse',
#  'auora',
#  'reseting',
#  'granmin',
#  'exuckerberg',
#  'superlumous',
#  'unsubsed',
#  'diode',
#  'infosysc',
#  'jncp',
#  'billmin',
#  'tology',
#  'aerobic',
#  'zubphic',
#  'narcissism',
#  'coo',
#  'sumo',
#  'units',
#  'biological',
#  'nhahahahahahahatecpur',
#  'dietitian',
#  'joker',
#  'iiit',
#  'decrypt',
#  'hypotble',
#  'bosons',
#  'apnea',
#  'tourhu',
#  'reprogram',
#  'scami',
#  'morod1',
#  'repoies',
#  'pber',
#  'a3',
#  'listener',
#  'texasxit',
#  'plungts',
#  'dotroion',
#  '4919',
#  'stds',
#  'shavers',
#  'colliding',
#  'chesse',
#  'neutplement',
#  'brownies',
#  'chandrakar',
#  'samp',
#  'patuntan',
#  'brillnees',
#  'manmohan',
#  'jacks',
#  'rouko',
#  'padhao',
#  'pewie',
#  'rockets',
#  'saulturerous',
#  'mot',
#  'excessively',
#  'nots',
#  'prince',
#  'porkchop',
#  'specs',
#  'parametric',
#  'orbitals',
#  'rauron',
#  'kazka',
#  'exbiologys',
#  'brooms',
#  'kic',
#  '-less',
#  'crophic',
#  'dentistry',
#  'goveri',
#  'enterpriseide',
#  '000',
#  'loon',
#  'apocalipse',
#  'tato',
#  'removeing',
#  'greekso',
#  'solved',
#  'photoin',
#  'organ',
#  'unalienable',
#  'pwo',
#  'cryptocur500',
#  'knicca',
#  'olympicsds',
#  'milkshake',
#  'anaerobic',
#  'berlin',
#  'phlegm',
#  'freezes',
#  'coca',
#  'validate',
#  'shaft',
#  'geeky',
#  'mer',
#  'houlturee',
#  'strengthen',
#  'sana',
#  'bullied',
#  'revisit',
#  'inte',
#  'naually',
#  'astologer',
#  'antithinkable',
#  'molar',
#  'encrypted',
#  'gendry',
#  'kilo',
#  'sooryavansham',
#  'cleaphic',
#  'rep',
#  'aligarh',
#  'rie',
#  'addict',
#  'extrarfing',
#  'geoify',
#  'damaged',
#  'chranie',
#  'seulturel',
#  'solids',
#  'gpl',
#  'polarized',
#  'cvanate',
#  'tourists',
#  'implemented',
#  'pror',
#  'syresn',
#  'constructed',
#  'pharmaphic',
#  'homeopathy',
#  'asians',
#  'healther',
#  'vhdl',
#  'camets',
#  'html5',
#  'snapeaks',
#  'bags',
#  'believing',
#  'surname',
#  'confuiseism',
#  'belt',
#  'feremture',
#  'ingredientss',
#  'paties',
#  'chatbot',
#  'rv',
#  'decrees',
#  'crooked',
#  'comon',
#  'barometer',
#  'iitb',
#  'vrindavan',
#  'proteoglyk',
#  'ula',
#  'fluluorine',
#  'q',
#  'kim',
#  'neurally',
#  'meta',
#  'con',
#  'reowel',
#  'doubledo',
#  'anorexiety',
#  'ghagglebad',
#  'compution',
#  'mpo',
#  'flywheel',
#  'localisation',
#  'structurey',
#  'le',
#  'aspergers',
#  'einsteinau',
#  'jailbreaking',
#  'oreaing',
#  'crashing',
#  'd700',
#  'hdfc',
#  'nationalfc',
#  'rultureclaw',
#  'scdenmidenmidenmiden',
#  'breastfems',
#  'playkart',
#  'leak',
#  'generala',
#  'vulturen',
#  'fir',
#  'biobation',
#  'surprise',
#  'dhogan',
#  'nsg',
#  'mangeshkar',
#  'kundli',
#  'stne',
#  'fictionally',
#  'punctuation',
#  'banana',
#  'pulometer',
#  'sudoku',
#  'perks',
#  'darms',
#  'scaring',
#  'interviewsr',
#  'eh37insins',
#  'jpg',
#  'powering',
#  'plemir',
#  'naning',
#  'adulterated',
#  'purifiers',
#  'cola',
#  'zoosk',
#  'shunt',
#  'anvert',
#  'comapny',
#  'devalue',
#  'nm',
#  'adultery',
#  'alkenes',
#  'consicreted',
#  'fer',
#  'gars',
#  'pyramids',
#  'reformed',
#  'maturity',
#  'preasiest',
#  'computa',
#  'cowino',
#  '*',
#  'cutistic',
#  'riches',
#  'asaise',
#  'theodore',
#  'unst',
#  'rhogkesh',
#  'comey',
#  'neuro',
#  'sheila',
#  'seasonnote',
#  'delaware',
#  'safari',
#  'positions',
#  'exboyfriend',
#  'saucers',
#  'acc',
#  'mouthy',
#  'upise',
#  'subth',
#  'physcial',
#  'sucide',
#  'sacriheiming',
#  'grizzly',
#  'consent',
#  'poses',
#  'vaporizergiant',
#  'disacc',
#  'hocc',
#  'poke',
#  'exposure',
#  'truths',
#  'armpits',
#  'threebiotic',
#  'whipped',
#  '1000ra',
#  'specter',
#  'imped',
#  'chhath',
#  'wind',
#  'imp',
#  'raretegy',
#  'metrics',
#  'polytechnic',
#  'essentials',
#  'resu',
#  'initrd',
#  'chag',
#  'pupp',
#  'transformant',
#  'nukey',
#  'zeljko',
#  'criminals',
#  'brziness',
#  'photoing',
#  'unbanned',
#  'jaiib',
#  'zuma',
#  'contradictd',
#  'sanu',
#  'sodium',
#  'tropos',
#  'priority',
#  'parabola',
#  'respected',
#  'mtdna',
#  'firearm',
#  'cag',
#  'eyre',
#  'socior',
#  'mythology',
#  'believers',
#  'reddits',
#  'originatey',
#  'mulled',
#  'dogight',
#  'agents',
#  'sunburn',
#  'duggle',
#  'cham',
#  'disc',
#  'recoveryify',
#  'n2',
#  'unwelcomed',
#  'pps',
#  'rsi',
#  'facetime',
#  'ambani',
#  'screens',
#  'manufacturer',
#  'pmo',
#  'extrake',
#  'munic',
#  'talked',
#  'dilwale',
#  'recruiter',
#  'refxiple',
#  'te',
#  'revive',
#  'laveru',
#  'desperate',
#  'alexa',
#  'nonparcule',
#  'tp',
#  'nearglete',
#  'bees',
#  'baseball',
#  'voot',
#  'taiwani',
#  'pp',
#  'trapezoid',
#  'catholic',
#  'fultureible',
#  'carol',
#  '-ware',
#  'rypoil',
#  'chronic',
#  'ko',
#  'tatkal',
#  'compmuting',
#  'provoking',
#  'anubis',
#  'conversational',
#  'sponsor',
#  'adulthrones',
#  'rupete',
#  'disciplines',
#  'colonials',
#  'tantric',
#  'soviet',
#  'reggledule',
#  'gulfment',
#  'ccp',
#  'mechanicalp',
#  ...}
