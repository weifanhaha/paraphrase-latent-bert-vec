# %%
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.bleu_score import sentence_bleu
import rouge
import yaml
import re
import glob
import os
import numpy as np

# %%
config_path = '../configs/dpng_transformer.yaml'

# for training size
with open(config_path) as f:
    config = yaml.load(f, Loader=yaml.FullLoader)
    print(config)

train_size = config['train_size']
val_size = config['val_size']
test_size = config['test_size']
# Out:
# {'save_model_path': '../models/DNPG_base_transformer.pth', 'log_file': '../logs/DNPG_base_transformer_training.txt', 'test_output_file': '../outputs/test_DNPG_base_transformer.txt', 'val_output_file': '../outputs/val_DNPG_base_transformer.txt', 'dataset': 'quora_dataset', 'num_epochs': 50, 'batch_size': 128, 'd_model': 450, 'd_inner_hid': 512, 'd_k': 50, 'd_v': 50, 'n_head': 9, 'n_layers': 3, 'n_warmup_steps': 12000, 'dropout': 0.1, 'embs_share_weight': True, 'proj_share_weight': True, 'label_smoothing': False, 'train_size': 100000, 'val_size': 4000, 'test_size': 20000, 'is_bow': False, 'lr': '1e-3'}

# %%
seeds = [0, 777, 33333]
ref_path = '../data/quora_train.txt'

# %%
seed_dir_dic = {}
seed_root = './fixseed'
for seed in seeds:
    seed_dir = 'seed{}'.format(seed)
    seed_dir = os.path.join(seed_root, seed_dir)
    txt_path = os.path.join(seed_dir, '*.txt')
    seed_files = glob.glob(txt_path)
    seed_dir_dic[seed] = seed_files

# %%
def read_ref(ref_path):
    # read reference sentence and prediction sentence
    reference_text = open(ref_path, 'r').readlines()
    np.random.shuffle(reference_text)
    reference_text = reference_text[train_size+val_size:train_size+val_size+test_size]
    # use input sentence to calculate bleu-ori
    reference_text = [text.strip().split('\t')[0] for text in reference_text]

    # normalize reference corpus , eg: seperate question mark , remove '(' ,')' etc
    reference_text = [re.sub(r"([.!?])", r" \1", seq) for seq in reference_text]
    reference_text = [text for text in reference_text]

    # reference_text = [re.sub(r"[^a-zA-Z.!?]+", r" ", seq) for seq in reference_text]
    reference_corpus = [[text.split()] for text in reference_text]
    return reference_text, reference_corpus

# %%
def evaluate(reference_corpus, prediction_corpus):
    print("[Info] Calculating BLEU 1...")
    bleu1 = corpus_bleu(reference_corpus, prediction_corpus, weights=(1, 0, 0, 0))
    print("[Info] Calculating BLEU 2...")
    bleu2 = corpus_bleu(reference_corpus, prediction_corpus, weights=(0.5, 0.5, 0, 0))
    print("[Info] Calculating BLEU 3...")
    bleu3 = corpus_bleu(reference_corpus, prediction_corpus, weights=(0.33, 0.33, 0.34, 0))
    print("[Info] Calculating BLEU 4...")
    bleu4 = corpus_bleu(reference_corpus, prediction_corpus, weights=(0.25, 0.25, 0.25, 0.25))
    print("[Info] Done")

    print("[Info] BLEU1 Score: {}".format(bleu1))
    print("[Info] BLEU2 Score: {}".format(bleu2))
    print("[Info] BLEU3 Score: {}".format(bleu3))
    print("[Info] BLEU4 Score: {}".format(bleu4))
    
    rouge_evaluator = rouge.Rouge(metrics=['rouge-n', 'rouge-l'], max_n=2)
    rouge_scores = rouge_evaluator.get_scores(prediction_text, reference_text)

    print("[Info] Rouge 1 score: {}".format(rouge_scores["rouge-1"]["f"]))
    print("[Info] Rouge 2 score: {}".format(rouge_scores["rouge-2"]["f"]))
    print("[Info] Rouge l score: {}".format(rouge_scores["rouge-l"]["f"]))
    
    return bleu1, bleu2, bleu3, bleu4, rouge_scores

# %%
for seed in seeds:
    print("### Evaluating seed {} ###".format(seed))
    # fixseed
    # get reference text
    np.random.seed(seed)
    reference_text, reference_corpus = read_ref(ref_path)
    print(reference_corpus[0])

    # for every file in seeds
    files = seed_dir_dic[seed]
    # get predict text
    for file in files:
        if 'bow' in file or 'wordnet' in file:
            continue
        print("Calculating file: ", file)
        prediction_text = open(file, 'r').readlines()
        prediction_text = [text.replace('Predict: ', '').strip() for text in prediction_text if 'Predict: ' in text]
        prediction_corpus = [text.split() for text in prediction_text]
        assert len(reference_text) == len(prediction_text), "len mismatch, ref: {}, pred: {}".format(len(reference_text), len(prediction_text))
        
        # evaluate score
        bleu1, bleu2, bleu3, bleu4, rouge_scores = evaluate(reference_corpus, prediction_corpus)
        # write to output
        score_dir = '../scores/fixseed/seed{}/ori'.format(seed)
        if not os.path.exists(score_dir):
            os.mkdir(score_dir)
        score_path = os.path.join(score_dir, file.split('/')[-1])
        print("Writing to file:", score_path)
        
        f = open(score_path, 'w')
        f.write("[Info] BLEU1 Score: {}\n".format(bleu1))
        f.write("[Info] BLEU2 Score: {}\n".format(bleu2))
        f.write("[Info] BLEU3 Score: {}\n".format(bleu3))
        f.write("[Info] BLEU4 Score: {}\n".format(bleu4))

        f.write("\n\n[Info] Rouge 1 score: {}\n".format(rouge_scores["rouge-1"]["f"]))
        f.write("[Info] Rouge 2 score: {}\n".format(rouge_scores["rouge-2"]["f"]))
        f.write("[Info] Rouge l score: {}\n".format(rouge_scores["rouge-l"]["f"]))

        f.close()
        print("==============================")
# Out:
# ### Evaluating seed 0 ###
# [['What', 'are', 'the', 'benefits', 'of', 'using', 'digital', 'signage', 'for', 'your', 'business', '?']]
# Calculating file:  ./fixseed/seed0/test_DNPG_base_transformer_epoch70.txt
# [Info] Calculating BLEU 1...
# [Info] Calculating BLEU 2...
# [Info] Calculating BLEU 3...
# [Info] Calculating BLEU 4...
# [Info] Done
# [Info] BLEU1 Score: 0.6445214424573718
# [Info] BLEU2 Score: 0.5266553765143346
# [Info] BLEU3 Score: 0.4415410065807005
# [Info] BLEU4 Score: 0.3778980355290477
# [Info] Rouge 1 score: 0.6877523016748484
# [Info] Rouge 2 score: 0.487186817342597
# [Info] Rouge l score: 0.670222217730458
# Writing to file: ../scores/fixseed/seed0/ori/test_DNPG_base_transformer_epoch70.txt
# ==============================
# Calculating file:  ./fixseed/seed0/transformer_key_enc_bert_val_attention_alpha0.5_softmax.txt
# [Info] Calculating BLEU 1...
# [Info] Calculating BLEU 2...
# [Info] Calculating BLEU 3...
# [Info] Calculating BLEU 4...
# [Info] Done
# [Info] BLEU1 Score: 0.6065280300710959
# [Info] BLEU2 Score: 0.47987224407050855
# [Info] BLEU3 Score: 0.38979450731601095
# [Info] BLEU4 Score: 0.32366936884515124
# [Info] Rouge 1 score: 0.6376696921838251
# [Info] Rouge 2 score: 0.42574208218895027
# [Info] Rouge l score: 0.618115599003628
# Writing to file: ../scores/fixseed/seed0/ori/transformer_key_enc_bert_val_attention_alpha0.5_softmax.txt
# ==============================
# Calculating file:  ./fixseed/seed0/transformer_key_enc_bert_val_attention_alpha0.5.txt
# [Info] Calculating BLEU 1...
# [Info] Calculating BLEU 2...
# [Info] Calculating BLEU 3...
# [Info] Calculating BLEU 4...
# [Info] Done
# [Info] BLEU1 Score: 0.6713653011859468
# [Info] BLEU2 Score: 0.558696733806091
# [Info] BLEU3 Score: 0.47540538989042375
# [Info] BLEU4 Score: 0.4124476632692333
# [Info] Rouge 1 score: 0.7170228625804743
# [Info] Rouge 2 score: 0.5242259085803892
# [Info] Rouge l score: 0.6980172886067941
# Writing to file: ../scores/fixseed/seed0/ori/transformer_key_enc_bert_val_attention_alpha0.5.txt
# ==============================
# Calculating file:  ./fixseed/seed0/test_DNPG_base_transformer.txt
# [Info] Calculating BLEU 1...
# [Info] Calculating BLEU 2...
# [Info] Calculating BLEU 3...
# [Info] Calculating BLEU 4...
# [Info] Done
# [Info] BLEU1 Score: 0.6523698355876207
# [Info] BLEU2 Score: 0.5365381074540992
# [Info] BLEU3 Score: 0.4522764285059227
# [Info] BLEU4 Score: 0.38920071843640996
# [Info] Rouge 1 score: 0.6955827185505631
# [Info] Rouge 2 score: 0.49787867015008425
# [Info] Rouge l score: 0.6784860043040876
# Writing to file: ../scores/fixseed/seed0/ori/test_DNPG_base_transformer.txt
# ==============================
# Calculating file:  ./fixseed/seed0/test_DNPG_base_transformer_epoch100.txt
# [Info] Calculating BLEU 1...
# [Info] Calculating BLEU 2...
# [Info] Calculating BLEU 3...
# [Info] Calculating BLEU 4...
# [Info] Done
# [Info] BLEU1 Score: 0.6333687457626945
# [Info] BLEU2 Score: 0.5105003653854867
# [Info] BLEU3 Score: 0.4235209642307071
# [Info] BLEU4 Score: 0.35971712284517593
# [Info] Rouge 1 score: 0.671855957443526
# [Info] Rouge 2 score: 0.46551229386416054
# [Info] Rouge l score: 0.6527966664282034
# Writing to file: ../scores/fixseed/seed0/ori/test_DNPG_base_transformer_epoch100.txt
# ==============================
# ### Evaluating seed 777 ###
# [['What', 'was', 'the', 'first', 'thing', 'you', 'did', 'when', 'you', 'found', 'out', 'Donald', 'Trump', 'won', 'the', 'election', '?']]
# Calculating file:  ./fixseed/seed777/test_DNPG_base_transformer_epoch70.txt
# [Info] Calculating BLEU 1...
# [Info] Calculating BLEU 2...
# [Info] Calculating BLEU 3...
# [Info] Calculating BLEU 4...
# [Info] Done
# [Info] BLEU1 Score: 0.6456146022863282
# [Info] BLEU2 Score: 0.527211188630728
# [Info] BLEU3 Score: 0.44268889131972333
# [Info] BLEU4 Score: 0.37986491363842
# [Info] Rouge 1 score: 0.6854189052031499
# [Info] Rouge 2 score: 0.4852839276202933
# [Info] Rouge l score: 0.6671317333385508
# Writing to file: ../scores/fixseed/seed777/ori/test_DNPG_base_transformer_epoch70.txt
# ==============================
# Calculating file:  ./fixseed/seed777/transformer_key_enc_bert_val_attention_alpha0.5.txt
# [Info] Calculating BLEU 1...
# [Info] Calculating BLEU 2...
# [Info] Calculating BLEU 3...
# [Info] Calculating BLEU 4...
# [Info] Done
# [Info] BLEU1 Score: 0.6666275610814195
# [Info] BLEU2 Score: 0.5570336224154766
# [Info] BLEU3 Score: 0.476173478594816
# [Info] BLEU4 Score: 0.4146859034078019
# [Info] Rouge 1 score: 0.7175951504998639
# [Info] Rouge 2 score: 0.5281718544246513
# [Info] Rouge l score: 0.6997602418825418
# Writing to file: ../scores/fixseed/seed777/ori/transformer_key_enc_bert_val_attention_alpha0.5.txt
# ==============================
# Calculating file:  ./fixseed/seed777/test_DNPG_base_transformer.txt
# [Info] Calculating BLEU 1...
# [Info] Calculating BLEU 2...
# [Info] Calculating BLEU 3...
# [Info] Calculating BLEU 4...
# [Info] Done
# [Info] BLEU1 Score: 0.6476801769459142
# [Info] BLEU2 Score: 0.5329880140696664
# [Info] BLEU3 Score: 0.4504706110774829
# [Info] BLEU4 Score: 0.3885547258215713
# [Info] Rouge 1 score: 0.6957822898704894
# [Info] Rouge 2 score: 0.49934596773683854
# [Info] Rouge l score: 0.6790263121743406
# Writing to file: ../scores/fixseed/seed777/ori/test_DNPG_base_transformer.txt
# ==============================
# Calculating file:  ./fixseed/seed777/test_DNPG_base_transformer_epoch100.txt
# [Info] Calculating BLEU 1...
# [Info] Calculating BLEU 2...
# [Info] Calculating BLEU 3...
# [Info] Calculating BLEU 4...
# [Info] Done
# [Info] BLEU1 Score: 0.630475739887745
# [Info] BLEU2 Score: 0.508013860357317
# [Info] BLEU3 Score: 0.4209987384087393
# [Info] BLEU4 Score: 0.35693346348089855
# [Info] Rouge 1 score: 0.6698014953266352
# [Info] Rouge 2 score: 0.4639734977443742
# [Info] Rouge l score: 0.6510304926532163
# Writing to file: ../scores/fixseed/seed777/ori/test_DNPG_base_transformer_epoch100.txt
# ==============================
# ### Evaluating seed 33333 ###
# [['What', 'is', 'the', 'assumed', 'walking', 'speed', 'in', 'Google', "Maps's", 'time', 'estimates', '?']]
# Calculating file:  ./fixseed/seed33333/test_DNPG_base_transformer_epoch70.txt
# [Info] Calculating BLEU 1...
# [Info] Calculating BLEU 2...
# [Info] Calculating BLEU 3...
# [Info] Calculating BLEU 4...
# [Info] Done
# [Info] BLEU1 Score: 0.6391524219862852
# [Info] BLEU2 Score: 0.5205828046836148
# [Info] BLEU3 Score: 0.43543653354244827
# [Info] BLEU4 Score: 0.3722800961101591
# [Info] Rouge 1 score: 0.6825433994578338
# [Info] Rouge 2 score: 0.4803611482982917
# [Info] Rouge l score: 0.6642291462732164
# Writing to file: ../scores/fixseed/seed33333/ori/test_DNPG_base_transformer_epoch70.txt
# ==============================
# Calculating file:  ./fixseed/seed33333/transformer_key_enc_bert_val_attention_alpha0.5.txt
# [Info] Calculating BLEU 1...
# [Info] Calculating BLEU 2...
# [Info] Calculating BLEU 3...
# [Info] Calculating BLEU 4...
# [Info] Done
# [Info] BLEU1 Score: 0.6592329837911626
# [Info] BLEU2 Score: 0.5455138547120939
# [Info] BLEU3 Score: 0.46233545271767135
# [Info] BLEU4 Score: 0.39942800023862346
# [Info] Rouge 1 score: 0.7063585531825753
# [Info] Rouge 2 score: 0.512846142668527
# [Info] Rouge l score: 0.6880314255114123
# Writing to file: ../scores/fixseed/seed33333/ori/transformer_key_enc_bert_val_attention_alpha0.5.txt
# ==============================
# Calculating file:  ./fixseed/seed33333/test_DNPG_base_transformer.txt
# [Info] Calculating BLEU 1...
# [Info] Calculating BLEU 2...
# [Info] Calculating BLEU 3...
# [Info] Calculating BLEU 4...
# [Info] Done
# [Info] BLEU1 Score: 0.650545198917251
# [Info] BLEU2 Score: 0.5350960237427126
# [Info] BLEU3 Score: 0.4517866948243618
# [Info] BLEU4 Score: 0.38943159906086244
# [Info] Rouge 1 score: 0.6975896267068186
# [Info] Rouge 2 score: 0.4984950617733773
# [Info] Rouge l score: 0.6798622085409204
# Writing to file: ../scores/fixseed/seed33333/ori/test_DNPG_base_transformer.txt
# ==============================
# Calculating file:  ./fixseed/seed33333/test_DNPG_base_transformer_epoch100.txt
# [Info] Calculating BLEU 1...
# [Info] Calculating BLEU 2...
# [Info] Calculating BLEU 3...
# [Info] Calculating BLEU 4...
# [Info] Done
# [Info] BLEU1 Score: 0.6304915842160912
# [Info] BLEU2 Score: 0.5061247007994472
# [Info] BLEU3 Score: 0.41892825307677134
# [Info] BLEU4 Score: 0.35507503867113144
# [Info] Rouge 1 score: 0.6656387425206524
# [Info] Rouge 2 score: 0.4582806319792895
# [Info] Rouge l score: 0.6457568381282005
# Writing to file: ../scores/fixseed/seed33333/ori/test_DNPG_base_transformer_epoch100.txt
# ==============================
